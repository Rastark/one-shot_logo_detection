# %%
# !nvidia-smi
# Out:
# Tue Dec 29 03:48:56 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.48                 Driver Version: 410.48                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-SXM2...  Off  | 00000000:05:00.0 Off |                    0 |
# | N/A   31C    P0    40W / 300W |   8035MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla P100-SXM2...  Off  | 00000000:06:00.0 Off |                    0 |
# | N/A   50C    P0   192W / 300W |   4415MiB / 16280MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla P100-SXM2...  Off  | 00000000:84:00.0 Off |                    0 |
# | N/A   48C    P0   139W / 300W |   4371MiB / 16280MiB |     82%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla P100-SXM2...  Off  | 00000000:85:00.0 Off |                    0 |
# | N/A   34C    P0    41W / 300W |   7462MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     30814      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  2761MiB |
# |    0     48618      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  1921MiB |
# |    0     48784      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  3343MiB |
# |    1     87849      C   python3                                     4405MiB |
# |    2     32743      C   python3                                     4361MiB |
# |    3     26354      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  1671MiB |
# |    3     64350      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  5781MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Model parts

# %%
""" Parts of the U-Net model """

import torch
import torch.nn as nn
import torch.nn.functional as F


class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.double_conv(x)


class Downscaler(nn.Module):
    """Double conv 3x3, then max pool 2x2 stride 2"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            DoubleConv(in_channels, out_channels),
            nn.MaxPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Upscaler(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.upscale = nn.Sequential(
            DoubleConv(in_channels, in_channels),
            nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2),
#            nn.BatchNorm2d(out_channels)
        )

    def forward(self, x):
        return self.upscale(x)        
    
        
class OutSoftmax(nn.Module):
    def __init__(self):
        super(OutSoftmax, self).__init__()
        self.sigmoid = nn.Sequential(
            nn.BatchNorm2d(1),
            nn.ReLU(inplace=True),
            nn.Sigmoid(), 
        )

    def forward(self, x):
        #x = self.softmax(x)
        logging.info(f"Pre-Sigmoid: {x}")
        return self.sigmoid(x)


# Conditioning Branch
class OneOneConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OneOneConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1),
            # nn.Conv2d(out_channels, out_channels, kernel_size=1), # kernel_size=3, padding=1
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
#        max_x = torch.max(x)
#        x = torch.div(x, max_x)
        return x

# class ConditioningConcat(nn.Module):
#     def __init__(self, tile_concat):
#         super(ConditioningConcat, self).__init__()
#         self.filtered_tile = OneOneConv(self.tile_concat)       # Here or in forward method?

#     def forward(self, x):
#         return torch.cat(x, self.filtered_tile, dim=-1)


class VGG16(nn.Module):
    def __init__(self, batch_norm=True, cfg='A', in_channels=3):
        super(VGG16, self).__init__()
        self.batch_norm = batch_norm

        self.cfgs = {
            'A': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M', 512, 512, 512, 'M'],     # 6 "evenly" distributed maxpools to reduce dims to 1x1x512 
            'B': [32, 32, 'M', 64, 64, 'M', 128, 'M', 256, 'M', 512, 'M', 'OutConv'], # From the paper's git
            'C': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M', 'M']     # 6 maxpools to reduce dims to 1x1x512
        }
        self.cfg = self.cfgs[cfg]

        self.layers = []
        for v in self.cfg:
            if v == 'M':
                self.layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            elif v == 'OutConv':
                outConv = nn.Conv2d(in_channels, 512, kernel_size=2, stride=1)
                if self.batch_norm:
                    self.layers += [outConv, nn.BatchNorm2d(512), nn.ReLU(inplace=True)]
                else:
                    self.layers += [outConv, nn.ReLU(inplace=True)]
            else:
                conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
                if self.batch_norm:
                    self.layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
                else:
                    self.layers += [conv2d, nn.ReLU(inplace=True)]
                in_channels = v
        self.vgg16 = nn.Sequential(*self.layers)

    def forward(self, x):
        return self.vgg16(x)

# %%
# Model

# %%
import torch
from torch import nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
import numpy as np
import logging


class LogoDetection(nn.Module):
    def __init__(self,
                 n_channels: int = 3,
                 batch_norm=False,
                 vgg_cfg: str = 'A'):
        super(LogoDetection, self).__init__()
        self.n_channels = n_channels

        # Encoder steps
        self.input_layer = Downscaler(self.n_channels, 64)
        # self.input_layer.wei
        self.down_layer1 = Downscaler(64, 128)
        self.down_layer2 = Downscaler(128, 256)
        self.down_layer3 = Downscaler(256, 512)
        self.down_layer4 = Downscaler(512, 512)  # 1/(2^5)*(width x height) x 512

        # Conditioning Module
        self.latent_repr = VGG16(batch_norm, vgg_cfg)
        self.one_conv1 = OneOneConv(576, 64)  # 64+512
        self.one_conv2 = OneOneConv(640, 128)  # 128+512
        self.one_conv3 = OneOneConv(768, 256)  # 256+512
        self.one_conv4 = OneOneConv(1024, 512)  # 512+512

        # Decoder steps
        self.up1 = Upscaler(1024, 512)  # 512+512
        self.up2 = Upscaler(1024, 256)  # 512*2
        self.up3 = Upscaler(512, 128)  # 256*2
        self.up4 = Upscaler(256, 64)  # 128*2
        self.up5 = Upscaler(128, 1)  # 64*2
        self.output_layer = OutSoftmax()

        # with torch.no_grad():
        #     self.input_layer.weight = torch.nn.Parameter()

    def forward(self, query, target):
        # query = samples[:, 0]
        # target = samples[:, 1]
#         logging.info(f"query: {query}")
#        print(f"query: {query}")
#         logging.info(f"target: {target}")
#        print(f"target: {target}")
        z = self.latent_repr(query)
#         logging.info(f"z: {z}")
#         print(f"z: {z}")
        # print(z.shape)

        # Encoder + Conditioning
        x = self.input_layer(target)
#         logging.info(f"input_layer: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 128, 128)
        # print(tile.shape)
#         logging.info(f"tile1: {tile}")
        x1 = torch.cat((x, tile), dim=1)
#         logging.info(f"x1: {x1}")
        x = self.down_layer1(x)
#         logging.info(f"down1: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 64, 64)
        x2 = torch.cat((x, tile), dim=1)
#         logging.info(f"x2: {x2}")
        x = self.down_layer2(x)
#         logging.info(f"down2: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 32, 32)
        x3 = torch.cat((x, tile), dim=1)
#         logging.info(f"x3: {x3}")
        x = self.down_layer3(x)
#         logging.info(f"down3: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 16, 16)
        x4 = torch.cat((x, tile), dim=1)
#         logging.info(f"x4: {x4}")
        x = self.down_layer4(x)
#         logging.info(f"down4: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 8, 8)
        x5 = torch.cat((x, tile), dim=1)
#         logging.info(f"x5: {x5}")
        # print(x.shape)

        # Decoder + Conditioning
#        x = torch.cat((x, x5), dim=1)
#        logging.info(f"cond5: {x}")
        # print(x.shape)
        x = self.up1(x5)
#         logging.info(f"up1: {x}")
        # print(x.shape)

        x4 = self.one_conv4(x4)
#         logging.info(f"cnv4: {x4}")
        x = torch.cat((x, x4), dim=1)
#         logging.info(f"cond4: {x}")
        # del x4
        x = self.up2(x)
#         logging.info(f"up2: {x}")

        x3 = self.one_conv3(x3)
#         logging.info(f"cnv3: {x3}")
        x = torch.cat((x, x3), dim=1)
#         logging.info(f"cond3: {x}")
        # del x3
        x = self.up3(x)
#         logging.info(f"up3: {x}")

        x2 = self.one_conv2(x2)
#         logging.info(f"cnv2: {x2}")
        x = torch.cat((x, x2), dim=1)
#         logging.info(f"cond2: {x}")
        # del x2
        x = self.up4(x)
#         logging.info(f"up4: {x}")

        x1 = self.one_conv1(x1)
#         logging.info(f"cnv1: {x1}")
        x = torch.cat((x, x1), dim=1)
#         logging.info(f"cond1: {x}")
        # del x1
        x = self.up5(x)
#         logging.info(f"up5: {x}")

        output = self.output_layer(x)
        logging.info(f"output: {output}")
        return output

    def predict_mask(self, query, target):
        return self.forward(query, target)

# %%
# eval

# %%
import functools, operator, collections
import torch
import torch.nn.functional as F
import numpy as np

from sklearn.metrics import jaccard_score as jsc
from sklearn.metrics import average_precision_score as avg_pr
from sklearn.cluster import DBSCAN
from sklearn import metrics

import matplotlib.pyplot as plt

from tqdm import tqdm

from skimage.measure import label, regionprops


def eval_net(model,
         loader, 
         device, 
         bbox: bool, 
         verbose: bool,
         iou_thr: int = 0.5
         ):
#     logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s: %(message)s", filename='oneshot_eval.log')
    model.eval()
    logging.info("Validating")

    # Number of batches
    n_val = len(loader)

#     logging.info(f"n_val: {n_val}")
    
    matches = 0

    # Number of bboxes
    max_matches = 0

    if bbox:
        truth_type = "bbox"
    else:
        truth_type = "mask"
    
#     logging.info(f"type of ground truth: {truth_type}")

    precisions, recalls, accuracies = [], [], []

    batch_results = []

    with tqdm(total=n_val, desc='Validation round', unit='img', leave=False, disable=not verbose) as bar:
        for batch in loader:
#             logging.info(f"New batch!")
            queries, targets, truth = batch['query'], batch['target'], batch[truth_type]
            queries = queries.to(device=device, dtype=torch.float32)
            targets = targets.to(device=device, dtype=torch.float32)
            # truth = truth.to(device=device, dtype=torch.float32)

            with torch.no_grad():
                pred = model(queries, targets)
#                 logging.info(f"Masks predicted")
#                 print(f"pred: {pred}")
                pred_masks = pred.cpu().numpy()
#                 print(f"pred_masks: {pred_masks}")
#                 logging.info(f"Masks to CPU")
#                 print(f"pred_masks_shape_0: {pred_masks.shape[0]}")
#                 print(f"pred_masks: {pred_masks}")
                # assunzione: gli indici della true e pred masks sono gli stessi
                for mask_index in range(pred_masks.shape[0]):
                    pred_mask = np.asarray(pred_masks[mask_index])
#                     print(f"pred_mask: {pred_mask}")
                    pred_mask = masks_as_image([rle_encode(pred_mask)])
#                     print(f"pred_mask.mask_as_image: {pred_mask}")
                    
                    # mask labeling and conversion to bboxes
                    pred_labels = label(pred_mask)
#                     print(f"pred_labels: {pred_labels}")
                    pred_bboxes_coords = list(map(lambda x: x.bbox, regionprops(pred_labels)))
                    pred_bboxes = calc_bboxes_from_coords(pred_bboxes_coords)
#                     print("pred_bboxes: ", pred_bboxes)

                    # computes truth bboxes in the same way as the pred
                    if bbox:
                        truth_bboxes = np.array(truth[mask_index])
                    else:
                        truth_mask = np.asarray(truth[mask_index])
                        truth_mask = masks_as_image([rle_encode(truth_mask)])
                        true_mask_labels = label(truth_mask)
                        truth_bboxes_coords = list(map(lambda x: x.bbox, regionprops(true_mask_labels)))
                        truth_bboxes = calc_bboxes_from_coords(truth_bboxes_coords)
#                         print("truth_bboxes: ", truth_bboxes)

                    max_matches += len(truth_bboxes)
    
                    logging.info(f"pred_bboxes: {pred_bboxes}")
                    logging.info(f"truth_bboxes: {truth_bboxes}")
                    
                    b_result = get_pred_results(truth_bboxes, pred_bboxes, iou_thr)
                    logging.info(f"b_result: {b_result}")
#                     print(f"b_result: {b_result}")
                    batch_results.append(b_result)
                    bar.update(pred_masks.shape[0])
                
#                 logging.info(f"Batch finished. batch_results: {batch_results}")

#     print(f"Validation from eval completed")
    # Should not be here, since the eval method is used in both validation and test -> TODO: better handling of the flag.
    model.train()
    
#     print(f"Batch results: {batch_results}")
    
    result = dict(functools.reduce(operator.add, map(collections.Counter, batch_results)))
    logging.info(f"result: {result}")
#     print("result: ", str(result))
    # TODO: KeyError è troppo generico
    try:
        true_pos = result['true_pos']
    except KeyError:
        true_pos = 0
    try:
        false_pos = result['false_pos']
    except KeyError:
        false_pos = 0
    try:
        false_neg = result['false_neg']
    except KeyError:
        false_neg = 0

    precision = calc_precision(true_pos, false_pos)
    recall = calc_recall(true_pos, false_neg)
    accuracy = calc_accuracy(true_pos, false_pos, false_neg)
    output = f"Precision: {precision}    Recall: {recall}    Accuracy: {accuracy}"
    print(output)
    logging.info(output)

    return accuracy


def calc_bboxes_from_coords(bboxes_coords):
    """Calculate all bounding boxes from a set of bounding boxes coordinates"""
    bboxes = []
#     print(f"bboxes_coords: {bboxes_coords}")
    for coord_idx in range(len(bboxes_coords)):
#         print(f"coord_idx: {coord_idx}")
        coord = bboxes_coords[coord_idx]
#         print(f"coord: {coord}")
        bbox = (coord[1], coord[0], int(coord[4])-int(coord[1]), int(coord[3])-int(coord[0]))
        bboxes.append(bbox)
    return bboxes


def get_pred_results(truth_bboxes, pred_bboxes, iou_thr = 0.5):
    """Calculates true_pos, false_pos and false_neg from the input bounding boxes. """
    n_pred_idxs = range(len(pred_bboxes))
    n_truth_idxs = range(len(truth_bboxes))
    if len(n_pred_idxs) == 0:
#         print(f"n_pred_idxs = 0")
        tp = 0
        fp = 0
        fn = len(truth_bboxes)
        return {'true_pos': tp, 'false_pos': fp, 'false_neg': fn}
    if len(n_truth_idxs) == 0:
#         print(f"n_truth_idxs = 0")
        tp = 0
        fp = len(pred_bboxes)
        fn = 0
        return {'true_pos': tp, 'false_pos': fp, 'false_neg': fn}

    truth_idx_thr = []
    pred_idx_thr = []
    ious = []
    for pred_idx, pred_bbox in enumerate(pred_bboxes):
        for truth_idx, truth_bbox in enumerate(truth_bboxes):
            iou = get_jaccard(pred_bbox, truth_bbox)
            if iou > iou_thr:
                truth_idx_thr.append(truth_idx)
                pred_idx_thr.append(pred_idx)
                ious.append(iou)
#     print(f"ious: {ious}")
    # ::-1 reverses the list
    ious_desc = np.argsort(ious)[::-1]
    if len(ious_desc) == 0:
        # No matches
        tp = 0
        fp = len(pred_bboxes)
        fn = len(truth_bboxes)
    else:
        truth_match_idxes = []
        pred_match_idxes = []
        for idx in ious_desc:
            truth_idx = truth_idx_thr[idx]
            pred_idx = pred_idx_thr[idx]
            # If the bboxes are unmatched, add them to matches
            if (truth_idx not in truth_match_idxes) and (pred_idx not in pred_match_idxes):
                truth_match_idxes.append(truth_idx)
                pred_match_idxes.append(pred_match_idxes)
        tp = len(truth_match_idxes)
        fp = len(pred_bboxes) - len(pred_match_idxes)
        fn = len(truth_bboxes) - len(truth_match_idxes)
    return {'true_pos': tp, 'false_pos': fp, 'false_neg': fn}


def calc_precision(true_pos, false_neg):
    try:
        precision = true_pos / (true_pos + false_neg)
    except ZeroDivisionError:
        precision = 0.0
    return precision


def calc_recall(true_pos, false_pos):
    try:
        recall = true_pos / (true_pos + false_pos)
    except ZeroDivisionError:
        recall = 0.0
    return recall


def calc_accuracy(true_pos, false_pos, false_neg):
    try:
        accuracy = true_pos / (true_pos + false_pos + false_neg)
    except ZeroDivisionError:
        accuracy = 0.0
    return accuracy 


def calc_mavg_precision(precision_array):
    return 


def get_jaccard(pred_bbox, truth_bbox):
    pred_mask = get_mask_from_bbox(pred_bbox)
    truth_mask = get_mask_from_bbox(truth_bbox)
    return get_jaccard_from_mask(pred_mask, truth_mask)


def get_jaccard_from_mask(pred_mask, truth):
#     print(f"jsc truth: {truth}")
#     print(f"jsc pred_mask: {pred_mask}")
    return jsc(y_true=truth, y_pred=pred_mask, average='micro')


def get_mask_from_bbox(bbox):
    mask = np.zeros((256, 256))
    x = bbox[0]
    y = bbox[1]
    for width in range(bbox[2]):
        for height in range(bbox[3]):
            mask[int(x) + int(width), int(y) + int(height)] = 1
    return mask


def get_bbox_batch(img):
    bbox = np.empty((img.shape[0], 4))
    for i in range(img.shape[0]):
        bbox[i] = get_bbox(img[i])
    return bbox


def get_bbox(img):
    # img.shape = [batch_size, 1, 256, 256]
    rows = np.any(img, axis=-1)
    cols = np.any(img, axis=-2)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    # X, Y, Width, Height
    return [cmin, rmin, cmax-cmin, rmax-rmin]


def rle_encode(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    logging.info(f"pred_img: {img}")
    pixels_old = img.T.flatten()
    pixels = img.T.flatten()
    for x in range(len(pixels_old)):
        if pixels_old[x] > 0.5:
            pixels[x] = 1
        else:
            pixels[x] = 0
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)


def rle_decode(mask_rle, shape=(256, 256)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0] * shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction


def masks_as_image(in_mask_list, all_masks=None):
    """
    Take the complete rle_encoded mask and create a mask array of the single masks
    """
    if all_masks is None:
        all_masks = np.zeros((256, 256), dtype=np.int16)
    # if isinstance(in_mask_list, list):
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks += rle_decode(mask)
    return np.expand_dims(all_masks, -1)
# Out:
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
# dataset_loader

# %%
import os
import numpy as np
from torch.utils.data import Dataset
import logging
from PIL import Image

import torch

import gzip
import shutil
import h5py
import tables


# TODO: Deve preprocessare anche le immagini di test
# TODO: Ha da funzionà co TorchVision, se hai tempo
# TODO: Visto che le maschere ci servono solo per estrapolare le bbox e confrontarle con quelle stimate, ha senso portarsi tutta la maschera e non le singole bbox?
class BasicDataset(Dataset):
    TARGET_IMAGE_PATH = "target_image_path"
    MASK_IMAGE_PATH = "mask_image_path"
    BBOX_PATH = "bbox_path"
    TARGET_IMAGE_BBOX_PATH = "target_image_bbox_path"

    # TODO: Check if the values are empty
    def __init__(self, imgs_dir: str, masks_dir: str, dataset_name: str, mask_image_dim: int = 256, query_dim: int = 64,
                 bbox_suffix: str = '.bboxes.txt', save_to_disk: bool = False, skip_bbox_lines: int = 0):
        self.imgs_dir = fix_input_dir(imgs_dir)
        self.masks_dir = fix_input_dir(masks_dir)
        self.processed_img_dir = str(self.imgs_dir[:self.imgs_dir.rindex(os.path.sep) + 1]) + "preprocessed"
        self.mask_img_dim = mask_image_dim
        self.query_dim = query_dim
        self.bbox_suffix = bbox_suffix
        self.save_to_disk = save_to_disk
        self.skip_bbox_lines = skip_bbox_lines
        assert mask_image_dim > 1, 'The dimension of mask and image must be higher than 1'
        assert query_dim > 1, 'The dimension of query image must be higher than 1'

        assert os.path.isdir(imgs_dir), f"Bad path for images directory: {imgs_dir}"

        assert os.path.isdir(masks_dir), f"Bad path for masks directory: {masks_dir}"

        if save_to_disk:
            # create processed image's directory, if not exists yet
            try:
                os.mkdir(self.processed_img_dir)
            except FileExistsError:
                # some previous instance generate this directory, no need to raise an exception
                pass

        # list of dict with the path of the images, which contains the paths for the following images:
        #       target, mask, bbox, target's bbox
        # every dict is defined by 4 str keys which have a str value
        # key = type of image
        # value = path of the image

        # List of dict. Every dict refers to an image with 4 keys:
        #       target, mask, bbox, query_target_bbox
        self.images_path = []

        # TODO: Fai in modo che preprocess calcoli sia la maschera che il bbox e poi, in base al dataset, togline uno
        if dataset_name == "FlickrLogos-32":
            self.flickrlogos32_load()
        elif dataset_name == "TopLogos-10":
            self.toplogos10_load()

    def __len__(self):
        return len(self.images_path)

    def toplogos10_load(self):

        # get bbox path
        bbox_path = None
        for bbox_paths, _, bbox_list in os.walk(self.masks_dir):
            for bbox_file in bbox_list:
                if self.bbox_suffix in bbox_file:
                    bbox_path = get_class_file_path(bbox_paths, bbox_file)
                    break
            if bbox_path:
                break

        # get query image path
        query_full_image_path = f"{bbox_path[:bbox_path.index(self.bbox_suffix)]}"

        # get target images path and fill "self.images_path"
        for target_images_paths, _, target_images_list in os.walk(self.imgs_dir):
            for target_image_name in target_images_list:
                target_image_root_path, target_image_extension = os.path.splitext(
                    os.path.join(target_images_paths, target_image_name))
                if target_image_extension == ".jpg":
                    self.images_path.append(
                        {self.TARGET_IMAGE_PATH: get_class_file_path(target_images_paths, target_image_name),
                         self.MASK_IMAGE_PATH: None,
                         self.BBOX_PATH: bbox_path,
                         self.TARGET_IMAGE_BBOX_PATH: query_full_image_path})

    def flickrlogos32_load(self):

        # dict with merged masks path
        # key = target image file name
        # value = merged mask's file path
        masks_dict = {}

        # put stuff into masks_dict
        for masks_paths, _, masks_files in os.walk(self.masks_dir):
            for mask_file_name in masks_files:
                _, mask_extension = os.path.splitext(os.path.join(masks_paths, mask_file_name))
                if mask_extension == ".png" and "merged" in mask_file_name:
                    masks_dict[mask_file_name[:mask_file_name.rindex(".mask")]] = get_class_file_path(masks_paths,
                                                                                                      mask_file_name)

        # dict with every image of every class
        # key = class name
        # value = dict with images type and path
        #       key = type of image (target, query, mask)
        #       value = path of the file
        image_path_element = {}

        # put stuff into image_path_element
        for target_images_paths, _, target_images_files in os.walk(self.imgs_dir):
            # TODO: Compare come classe la cartella padre "jpg", trova un modo per risolvere
            target_image_class = target_images_paths[target_images_paths.rindex(os.path.sep) + 1:]
            for target_image_name in target_images_files:
                target_image_root_path, target_image_extension = os.path.splitext(
                    os.path.join(target_images_paths, target_image_name))
                if target_image_extension == ".jpg" and "no-logo" not in target_image_root_path:
                    x = {self.TARGET_IMAGE_PATH: get_class_file_path(target_images_paths, target_image_name),
                         self.MASK_IMAGE_PATH: masks_dict[target_image_name],
                         self.BBOX_PATH: f'{masks_dict[target_image_name][:masks_dict[target_image_name].rindex(".mask")]}{self.bbox_suffix}'}
                    try:
                        image_path_element[target_image_class].append(x)
                    except KeyError:
                        image_path_element[target_image_class] = [x]

        # fill "images_path" variable. it generate every couple (target image, query image) for the same class
        # for now, it only skips couple (target, query) of the same image
        for target_image_class in image_path_element:
            items_class = image_path_element[target_image_class]
            for outer_image in items_class:
                bbox_path = outer_image[self.BBOX_PATH]
                outer_target_image_path = outer_image[self.TARGET_IMAGE_PATH]
                for inner_image in items_class:
                    if not outer_image == inner_image:
                        target_image_path = inner_image[self.TARGET_IMAGE_PATH]
                        mask_image_path = inner_image[self.MASK_IMAGE_PATH]
                        self.images_path.append({self.TARGET_IMAGE_PATH: target_image_path,
                                                 self.MASK_IMAGE_PATH: mask_image_path,
                                                 self.BBOX_PATH: bbox_path,
                                                 self.TARGET_IMAGE_BBOX_PATH: outer_target_image_path})
        print(f"You have {len(self.images_path)} triplets")

    # preprocess the images. then save in file and return a list triplet [query image, target image, mask image]. how?
    # stretch the target image
    # stretch, crop and stretch again the query image
    # stretch the mask image
    # TODO: Check if the values are empty
    @classmethod
    def preprocess(cls, target_img_path: str, bbox_path: str, query_full_img_path: str, skip_bbox_lines: int = 0,
                   img_dim: int = 256, query_img_dim: int = 64, mask_img_path: str = None) -> dict:

        # Target image

        pil_target_img = Image.open(target_img_path)
        # stretch the image
        pil_resized_target_img = pil_target_img.resize((img_dim, img_dim))

        # Query image

        pil_target_img_bbox = Image.open(query_full_img_path)
        pil_resized_target_img_bbox = pil_target_img_bbox.resize((img_dim, img_dim))

        # we will resize, crop and resize again the image but we have the coordinates of the non resized bounding box
        target_img_width, target_img_height = pil_target_img_bbox.size
        resized_target_img_width, resized_target_img_height = pil_resized_target_img_bbox.size
        percent_width = round(100 * int(resized_target_img_width) / (int(target_img_width)), 2) / 100
        percent_height = round(100 * int(resized_target_img_height) / (int(target_img_height)), 2) / 100

        # open the bounding box file
        with open(bbox_path) as bbox_file:
            # read only the first line of the bbox file
            bbox_lines = bbox_file.readlines()
            first_line_bbox = bbox_lines[1 - skip_bbox_lines].split(' ')
            # check if we correctly skipped the first line of the file, the one with no number,
            # and if all the elements are numeric, like every coordinate should be ;)
            if first_line_bbox[0].isnumeric() and first_line_bbox[1].isnumeric() and \
                    first_line_bbox[2].isnumeric() and first_line_bbox[3].rstrip().isnumeric():
                x, y, width, height = first_line_bbox
                # adapt the old coordinates to the new stretched dimension
                left = int(x.strip()) * percent_width
                upper = int(y.strip()) * percent_height
                right = int(int(x.strip()) + int(width)) * percent_width
                lower = int(int(y.strip()) + int(height)) * percent_height
                # crop and resize the query image
                pil_query_img = pil_resized_target_img_bbox.crop((left, upper, right, lower))
                pil_resized_query_img = pil_query_img.resize((query_img_dim, query_img_dim))
            else:
                # TODO: nel traceback compare "error_string" e poi successivamente spiega l'eccezione. Trova un modo per togliere quel "error_string"
                error_string = f"Bounding box file's first line should have 4 groups of integers with whitespace " \
                               f"separator. Check {bbox_path}"
                raise Exception(error_string)

        # Mask

        if mask_img_path:
            pil_mask = Image.open(mask_img_path)
            pil_resized_mask = pil_mask.resize((img_dim, img_dim))
        else:
            pil_resized_mask = None

        # get the size of the images
        # print(f"query image dim: {pil_resized_query_img.size}")
        # print(f"target image dim: {pil_resized_target_img.size}")
        # if pil_resized_mask:
        #     print(f"mask image dim: {pil_resized_mask.size}")

        # just to test if everything works. don't look at these :)
        # if pil_resized_target_img:
        #     pil_resized_target_img.save('target.jpg')
        # if pil_resized_query_img:
        #     pil_resized_query_img.save('query.jpg')
        # if pil_resized_mask:
        #     pil_resized_mask.save('mask.jpg')

        # return the triplet (Dq, Dt, Dm) where Dq is the query image, Dt is the target image and Dm is the mask image
        return create_triplet_with_torch_representation(pil_resized_query_img,
                                                        pil_resized_target_img,
                                                        pil_resized_mask)

    # def h5py_with_pytorch(self, pil_img, index, type):
    #     x = self.h5py_compression(to_pytorch(pil_img), index, type)
    #     return x
    #
    # def h5py_without_pytorch(self, pil_img, index, type):
    #     x = self.h5py_compression(pil_img, index, type)
    #     return x

    # def store_hdf5_file_with_compression(self, image, image_index, image_type):
    #     file_name = f'{self.processed_img_dir}{os.path.sep}{image_index}_{image_type}.hdf5'
    #     f = h5py.File(file_name, "w")
    #     # TODO: Esistono altri algoritmi di compressione come Mafisc. Una roba figa che puoi usare è Bitshuffle
    #     f.create_dataset("init", compression="gzip", compression_opts=9, data=image)
    #     f.close()
    #     return file_name

    def store_hdf5_file_with_compression(self, images, image_index):
        image_type = ["query", "target", "mask"]
        image_type_index = 0
        for image in images:
            file_name = f'{self.processed_img_dir}{os.path.sep}{image_index}_{image}.hdf5'
            f = h5py.File(file_name, "w")
            # TODO: Esistono altri algoritmi di compressione come Mafisc. Una roba figa che puoi usare è Bitshuffle
            f.create_dataset("init", compression="gzip", compression_opts=9, data=images[image])
            f.close()
            image_type_index += 1
        # for image in images:
        #     file_name = f'{self.processed_img_dir}{os.path.sep}{image_index}_{image_type[image_type_index]}.hdf5'
        #     f = h5py.File(file_name, "w")
        #     # TODO: Esistono altri algoritmi di compressione come Mafisc. Una roba figa che puoi usare è Bitshuffle
        #     f.create_dataset("init", compression="gzip", compression_opts=9, data=image)
        #     f.close()
        #     image_type_index += 1
        # return file_name

    # def gzip_compress(self, index, input_file):
    #     # input_file = f'{self.processed_img_dir}{os.path.sep}{index}.npz'
    #     with open(input_file, 'rb') as f_in:
    #         output_file = f'{input_file}.gz'
    #         with gzip.open(output_file, 'wb', compresslevel=9) as f_out:
    #             shutil.copyfileobj(f_in, f_out)
    #     # if os.path.exists(input_file):
    #     #     os.remove(input_file)
    #     return output_file

    # def gzip_compress(self, index, input_file):
    #     # input_file = f'{self.processed_img_dir}{os.path.sep}{index}.npz'
    #     output_file = f'{input_file}.gz'
    #     with gzip.open(output_file, 'wb', compresslevel=1) as f_out:
    #         with open(input_file, 'rb') as f_in:
    #             shutil.copyfileobj(f_in, f_out)
    #     # if os.path.exists(input_file):
    #     #     os.remove(input_file)
    #     return output_file

    # def gzip_uncompress(self, input_file):
    #     with gzip.open(input_file, 'rb') as f:
    #         file_content = f.read()
    #     output_file = input_file[:input_file.rindex('.')]
    #     with open(output_file, mode='wb') as fp:
    #         fp.write(file_content)
    #     return output_file

    def read_hdf5_file(self, hdf5_file):
        with h5py.File(hdf5_file, 'r') as hf:
            data = hf.get('init')
            data = np.array(data)
        return data

    # def np_save_compressed(self, index, triplet_list_in_torch_representation):
    #     file_name = f'{self.processed_img_dir}{os.path.sep}{index}'
    #     # save the file so the next time you don't have to preprocess again
    #     np.savez_compressed(file_name,
    #                         query=triplet_list_in_torch_representation[0],
    #                         target=triplet_list_in_torch_representation[1],
    #                         mask=triplet_list_in_torch_representation[2])
    #     return f'{file_name}.npz'

    def __getitem__(self, item_index):
#         print(f"Getting item {item_index}")
        # get the path of the preprocessed file, if exists
        mask_file_path = f'{self.processed_img_dir}{os.path.sep}{item_index}_mask.hdf5'
        query_file_path = f'{self.processed_img_dir}{os.path.sep}{item_index}_query.hdf5'
        target_file_path = f'{self.processed_img_dir}{os.path.sep}{item_index}_target.hdf5'

        correct_order_triplet = [query_file_path, target_file_path, mask_file_path]
        triplet_element_order = ["query", "target", "mask"]

        return_dict = {}
        for file in correct_order_triplet:
            if not os.path.exists(file):
                # triplet = self.preprocess(item_index, self.images_path[item_index])
                return_dict = self.preprocess(
                    target_img_path=get_full_path(self.imgs_dir, self.images_path[item_index][self.TARGET_IMAGE_PATH]),
                    bbox_path=get_full_path(self.masks_dir, self.images_path[item_index][self.BBOX_PATH]),
                    query_full_img_path=get_full_path(self.imgs_dir,
                                                      self.images_path[item_index][self.TARGET_IMAGE_BBOX_PATH]),
                    mask_img_path=get_full_path(self.masks_dir, self.images_path[item_index][self.MASK_IMAGE_PATH]),
                    skip_bbox_lines=self.skip_bbox_lines)
                if self.save_to_disk:
                    self.store_hdf5_file_with_compression(return_dict, item_index)
                break
        else:
            triplet_index = 0
            for file in correct_order_triplet:
                if os.path.exists(file):
                    hdf5_file = self.read_hdf5_file(file)
                    return_dict[triplet_element_order[triplet_index]] = to_pytorch(hdf5_file)
                triplet_index += 1
#         print(f"Ciao, sono un fantastico {return_dict}")
        return return_dict

        # for file in correct_order_triplet:
        # # check if preprocessed file exists. if not, he will generate it. then return the triplet
        #     if os.path.exists(file):
        #         data = np.load(file, mmap_mode='r')
        #         return_tuple = np.array([data['query'], data['target'], data['mask']])
        #     else:
        #         return_tuple = self.preprocess(i, self.images_path[i])
        # return return_tuple


# something that will be deleted
# class CarvanaBasicDataset(BasicDataset):
#     def __init__(self, imgs_dir, masks_dir, scale=1):
#         super().__init__(imgs_dir, masks_dir, scale, mask_suffix='_mask')


def to_pytorch(image):
    if image:
        image_np = np.array(image)
        # mask image has only one channel, we need to explicit it
        if len(image_np.shape) == 2:
            image_np = np.expand_dims(image_np, axis=2)
        # HWC to CHW for pytorch
        img_trans = image_np.transpose((2, 0, 1))
        if img_trans.max() > 1:
            img_trans = img_trans / 255
        return torch.from_numpy(img_trans).type(torch.FloatTensor)
        # return img_trans
    else:
        return None


# dude, the name says all. just read it :/
# def create_triplet_without_torch_representation(pil_query, pil_target, pil_mask):
#     # return [np.array(pil_query), np.array(pil_target), np.array(pil_mask)]
#     # return np.array([np.array(pil_query), np.array(pil_target), np.array(pil_mask)])
#     return {
#         "query": np.array(pil_query),
#         "target": np.array(pil_target),
#         "mask": np.array(pil_mask)
#     }

def create_triplet_with_torch_representation(pil_query, pil_target, pil_mask):
    # return [to_pytorch(pil_query), to_pytorch(pil_target), to_pytorch(pil_mask)]
    # return np.array([to_pytorch(pil_query), to_pytorch(pil_target), to_pytorch(pil_mask)])
    return {
        "query": to_pytorch(pil_query),
        "target": to_pytorch(pil_target),
        "mask": to_pytorch(pil_mask)
    }


def get_class_file_path(class_name, file_name):
    class_file = f"{class_name[class_name.rindex(os.path.sep):]}{os.path.sep}{file_name}"
    if os.path.sep not in class_file[0:2]:
        class_file = f"{os.path.sep}{class_file}"
    return class_file


def get_full_path(root, file):
    try:
        if root[root.rindex(os.path.sep) + 1:].strip() == file[1:file.index(os.path.sep, 1)].strip():
            path = f"{root[:root.rindex(os.path.sep)]}{file}"
        else:
            path = f"{root}{file}"
        return path
    except AttributeError:
        return None


def fix_input_dir(dir):
    if not dir.strip()[-1:] == os.path.sep:
        return dir.strip()
    return dir.strip()[:-1]

# %%
# train

# %%
import argparse
import logging
import os
import sys
from tqdm import tqdm
import yaml

import numpy as np
import torch
from torch import optim
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
import torch.nn.functional as F

# from model.model import LogoDetection
from utils.dataset_loader import BasicDataset

# todo: when we add more models, we should move these variables to another location
MODEL_HOME = os.path.abspath("./stored_models/")
ALL_MODEL_NAMES = ["LogoDetection"]
ALL_DATASET_NAMES = ["FlickrLogos-32", "FlickrLogos-32-test", "TopLogos-10"]

with open(os.path.abspath("./config/config.yaml")) as config:
    config_list = yaml.load(config, Loader=yaml.FullLoader)


# # Appl.load_aly Gaussian normalization to the model
# def weights_init(model):
#     if isinstance(model, nn.Module):
#         nn.init.normal_(model.weight.data, mean=0.0, std=0.01)

def train(model,
          device,
          train_loader,
          val_loader,
          max_epochs,
          optimizer,
          vgg_cfg,
          verbose,
          checkpoint_dir,
          model_path,
          save_cp,
          n_train,
          n_val,
          step_eval
          ):
    batch_size = train_loader.batch_size

    # Logging for TensorBoard
    writer = SummaryWriter(
        comment=f'LR__BS_{batch_size}_OPT_{type(optimizer).__name__}')  # does optimizer.lr work? we're gonne find out
    global_step = 0

    ### ERROR: n_train e n_val? ###
    logging.info(f'''Starting training:
        Epochs:             {max_epochs}
        Batch size:         {batch_size}
        Learning rate:      
        Training size:      {n_train}
        Validation size:    {n_val}
        Device:             {device.type}
    ''')

    #    def criterion(pred, true):
    #        return torch.div(nn.BCELoss()(pred, true), 1*1) # L = (1/(H*W)) * BCELoss
    #        return nn.BCELoss()(pred, true)
    # TypeError: unsupported operand type(s) for /: 'BCELoss' and 'int'
    """    
    # now we don't want to train every time to save some minutes. we'll skip the train if there is a model file
    if os.path.exists(checkpoint_dir) and os.path.isdir(checkpoint_dir):
        if os.listdir(checkpoint_dir):
            model.load_state_dict(torch.load(checkpoint_dir + os.path.sep + "model.pt", map_location=device))
            return eval_net(model, val_loader, device, bbox=False, verbose=True)
    """
    criterion = nn.BCELoss()
    
    last_epoch_val_score = 0
    for epoch in range(max_epochs):
        logging.info(f"Epoch number {epoch}")
        model.train()  # set the model in training flag to True
        epoch_loss = 0  # resets the loss for the current epoch
        # epoch(batch_size, train_samples)

        # TODO
        with tqdm(total=n_train, desc=f'Epoch {epoch + 1}/{max_epochs}', unit='img', disable=not verbose) as bar:
            bar.set_description(f'train loss')

            for batch in train_loader:
#                 np.set_printoptions(threshold=sys.maxsize)
#                 print(f"Batch: {batch}")
#                 logging.info(f"Batch number #")
                queries = batch['query']  # Correct dimensions?
                targets = batch['target']
                true_masks = batch['mask']

                queries = queries.to(device=device, dtype=torch.float32)
                targets = targets.to(device=device, dtype=torch.float32)
                true_masks = true_masks.to(device=device, dtype=torch.float32)

#                 logging.info(f"Sending imgs to model")
#                 logging.info(f"queries: {queries}")
#                 logging.info(f"targets: {targets}")
                pred_masks = model(queries, targets)
#                 logging.info(f"model: {model}")
#                 logging.info(f"Mask predicted")
                # print(pred_masks.shape)
                loss = criterion(pred_masks, true_masks)
                epoch_loss += loss.detach().item()  # is the .detach() needed?

                # TensorBoard logging
                writer.add_scalar('Loss/train', loss.item(), global_step)

                bar.set_postfix(loss=f'{loss.item():.5f}')
                logging.info(f"Loss: {loss.item()}")

                optimizer.zero_grad()
                loss.backward()
                # nn.utils.clip_grad_value_(net.parameters(), 0.1) Gradient Clipping
                optimizer.step()

                bar.update(queries.shape[0])
                global_step += 1

                # if n_train % batch_size == 0: 
                #     n_batch = n_train // batch_size
                # else:
                #     n_batch = n_train // batch_size + 1

                ### DOMANDA: Dove lo volevamo usare? ###
                ### ALTRA DOMANDA: Non conviene farlo fuori dai cicli? ###
#                 n_batch = len(train_loader)
                # Deve farlo sia in mezzo ai batch che a fine epoca. Modifica la condizione dell'if
#                 if global_step % (n_train // (10 * batch_size)) == 0 or global_step == n_batch:
#                     for tag, value in model.named_parameters():
#                         tag = tag.replace('.', '/')
#                         writer.add_histogram('weights/' + tag, value.data.cpu().numpy(), global_step)
#                         writer.add_histogram('grads/' + tag, value.grad.cpu().numpy(), global_step)
#                     writer.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], global_step)

#                     writer.add_images('query_images', queries, global_step)
#                     writer.add_images('target_images', targets, global_step)
#                     writer.add_images('masks/true', true_masks, global_step)
#                     writer.add_images('masks/pred', pred_masks, global_step)

            # TODO: Se save_cp è false e non viene cambiato il val_split di default non va in train il 10% del dataset. Si potrebbe fare in modo che non sia così
            if save_cp and (epoch + 1) % step_eval == 0:
                """
                logging.info("Saving model")
                try:
                    os.mkdir(checkpoint_dir)
                    logging.info('Created checkpoint directory')
                except OSError:  # Maybe FileExistsError ?
                    pass
                model_files = [f for f in os.listdir(checkpoint_dir) if
                               os.path.isfile(os.path.join(checkpoint_dir, f))]
                torch.save(model.state_dict(), checkpoint_dir + os.path.sep + f'model.pt')
                for model_file in model_files:
                    os.remove(f'{checkpoint_dir}{os.path.sep}{model_file}')
                """
#                 logging.info(f"Next operation is validation")
#                 print(f"starting validation from train")
                logging.info(f"Validating")
                val_score = eval_net(model, val_loader, device, bbox=False, verbose=True)
#                 print(f"validation completed")
#                 logging.info(f"Validation complete")
                if val_score > last_epoch_val_score:
                    logging.info(f"This model is better the last one, I'm gonna save it")
                    try:
                        os.mkdir(checkpoint_dir)
                        logging.info('Created checkpoint directory')
                    except OSError:  # Maybe FileExistsError ?
                        pass
                    model_files = [f for f in os.listdir(checkpoint_dir) if
                                   os.path.isfile(os.path.join(checkpoint_dir, f))]
                    torch.save(model.state_dict(), checkpoint_dir + os.path.sep + f'CP_epoch{epoch + 1}.pt')
                    logging.info(f'Checkpoint {epoch + 1} saved!')
                    for model_file in model_files:
                        os.remove(f'{checkpoint_dir}{os.path.sep}{model_file}')
                    last_epoch_val_score = val_score

    writer.close()
    torch.save(model.state_dict(), model_path)

    # # WIP
    # # Launches evaluation on the model every evaluate_every steps.
    # # We need to change to appropriate evaluation metrics.
    # if evaluate_every > 0 and valid_samples is not None and (e + 1) % evaluate_every == 0:
    #     self.model.eval()
    #     with torch.no_grad():
    #         mrr, h1 = self.evaluator.eval(samples=valid_samples, write_output= False)

    #     # Metrics printing
    #     print("\tValidation: %f" % h1)

    # if save_path is not None:
    #     print("\tSaving model...")
    #     torch.save(self.model.state_dict(), save_path)
    # print("\tDone.")


# print("\nEvaluating model...")
# model.eval()
# mrr, h1 = Evaluator(model=model).eval(samples=dataset.test_samples, write_output=False)
# print("\tTest Hits@1: %f" % h1)
# print("\tTest Mean Reciprocal Rank: %f" % mrr)


# def get_args():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--dataset',
#                         choices=ALL_DATASET_NAMES,
#                         default="FlickrLogos-32",
#                         type=str,
#                         help="Dataset in {}".format(ALL_DATASET_NAMES)
#                         )

#     parser.add_argument('--model',
#                         choices=ALL_MODEL_NAMES,
#                         default="LogoDetection",
#                         type=str,
#                         help="Model in {}".format(ALL_MODEL_NAMES)
#                         )

#     optimizers = ['Adam', 'SGD']
#     parser.add_argument('--optimizer',
#                         choices=optimizers,
#                         default='Adam',
#                         help="Optimizer in {}".format(optimizers)
#                         )

#     parser.add_argument('--max_epochs',
#                         default=500,
#                         type=int,
#                         help="Number of epochs"
#                         )

#     parser.add_argument('--valid',
#                         default=-1,
#                         type=float,
#                         help="Number of epochs before valid"
#                         )

#     parser.add_argument('--batch_size',
#                         default=32,
#                         type=int,
#                         help="Number of samples in each mini-batch in SGD and Adam optimization"
#                         )

#     parser.add_argument('--weight_decay',
#                         default=5e-4,
#                         type=float,
#                         help="L2 weight regularization of the optimizer"
#                         )

#     parser.add_argument('--learning_rate',
#                         default=4e-4,
#                         type=float,
#                         help="Learning rate of the optimizer"
#                         )

#     parser.add_argument('--label_smooth',
#                         default=0.1,
#                         type=float,
#                         help="Label smoothing for true labels"
#                         )

#     parser.add_argument('--decay1',
#                         default=0.9,
#                         type=float,
#                         help="Decay rate for the first momentum estimate in Adam"
#                         )

#     parser.add_argument('--decay2',
#                         default=0.999,
#                         type=float,
#                         help="Decay rate for second momentum estimate in Adam"
#                         )

#     parser.add_argument('--verbose',
#                         default=True,
#                         type=bool,
#                         help="Verbose"
#                         )

#     parser.add_argument('--load',
#                         type=str,
#                         required=False,
#                         help="Path to the model to load"
#                         )

#     parser.add_argument('--batch_norm',
#                         default=False,
#                         type=bool,
#                         help="If True, apply batch normalization",
#                         )

#     parser.add_argument('--vgg_cfg',
#                         type=str,
#                         default='A',
#                         help="VGG architecture config",
#                         )

#     parser.add_argument('--step_eval',
#                         type=int,
#                         default=0,
#                         help="Enables automatic evaluation checks every X step",
#                         )

#     parser.add_argument('--val_split',
#                         type=float,
#                         default=0.1,
#                         help="Forces the validation subset to be split according to the set value. Must a value in the [0-1] or the sofware WILL break",
#                         )

#     parser.add_argument('--save_cp',
#                         type=bool,
#                         default=True,
#                         help="If True, saves model checkponts",
#                         )

#     return parser.parse_args()


def train_main(dataset='FlickrLogos-32',
     model='LogoDetection',
     optimizer='Adam',
     vgg_cfg='A',
     max_epochs=1, 
     batch_size=4,
     weight_decay=5e-4,
     learning_rate=4e-4,
     decay1=0.9, 
     decay2=0.999,
     verbose=True,
     batch_norm=True,
     load=None,
     val_split=0.1,
     step_eval=10,
     save_cp=True,
     ):
    # TODO: Add filename
    logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s: %(message)s", filename='oneshot.log', filemode='w')
#     args = get_args()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    logging.info(f'Using device {device}')

    # Modularized paths with respect to the current Dataset
    imgs_dir = config_list['datasets'][dataset]['paths']['images']
    masks_dir = config_list['datasets'][dataset]['paths']['masks']
    checkpoint_dir = config_list['models'][model]['paths']['train_cp']

    model_path = config_list['models'][model]['paths']['model']+ os.path.sep + "_".join([model, dataset]) + ".pt"
    
    # create checkpoint dir
    try:
        os.makedirs(checkpoint_dir, exist_ok=True)
    except FileExistsError:
        pass
    
    # create the model dir
    try:
        os.makedirs(config_list['models'][model]['paths']['model'], exist_ok=True)
    except FileExistsError:
        pass

    print("Loading %s dataset..." % dataset)
    # you can delete this "save_to_disk" to preserve the ssd :like:
    dataset = BasicDataset(imgs_dir=imgs_dir, masks_dir=masks_dir, dataset_name=dataset)

    # Splitting dataset
    n_val = int(len(dataset) * val_split)
    n_train = len(dataset) - n_val
    # TODO: Il validation set dovrebbe avere il 10% di ogni classe e non il 10% del totale altrimenti verrebbe sbilanciato
    train_set, val_set = random_split(dataset, [n_train, n_val])

    # Loading dataset
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True,
                            drop_last=True)

    # Change here to adapt your data
    print("Initializing model...")
    model = LogoDetection(batch_norm=batch_norm, vgg_cfg=vgg_cfg)

    # Optimizer selection
    # build all the supported optimizers using the passed params (learning rate and decays if Adam)
    supported_optimizers = {
        'Adam': optim.Adam(params=model.parameters(), lr=learning_rate, betas=(decay1, decay2),
                           weight_decay=weight_decay),
        'SGD': optim.SGD(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    }
    # Choose which Torch Optimizer object to use, based on the passed name
    optimizer = supported_optimizers[optimizer]

    # stiamo dando ad "args.load" due compiti, quello di dirci il path e quello di dirci se caricare vecchi checkpoint
    if load is not None:
        model.load_state_dict(
            torch.load(load, map_location=device)
        )
        logging.info(f'Model loaded from {load}')
    model.to(device=device)

    try:
        train(model=model,
              device=device,
              train_loader=train_loader,
              val_loader=val_loader,
              max_epochs=max_epochs,
              optimizer=optimizer,
              vgg_cfg=vgg_cfg,
              verbose=verbose,
              checkpoint_dir=checkpoint_dir,
              model_path=model_path,
              save_cp=save_cp,
              n_train=n_train,
              step_eval=step_eval,
              n_val=n_val
              )
    except KeyboardInterrupt:
        torch.save(model.state_dict(), config_list['models'][model]['paths']['model'] + os.path.sep + 'INTERRUPTED.pt')
        logging.info('Interrupt saved')
        try:
            sys.exit(0)
        except SystemExit:
            os._exit(0)
# Out:
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train_main(dataset='FlickrLogos-32',
     model='LogoDetection',
     optimizer='Adam',
     vgg_cfg='B',
     max_epochs=500, 
     batch_size=16, 
     weight_decay=5e-4,
     learning_rate=4e-4,
     decay1=0.9, 
     decay2=0.999,
     verbose=True,
     batch_norm=True,
     load=None,
     val_split=0.1,
     step_eval=10,
     save_cp=True,
     )
# Out:
# Loading FlickrLogos-32 dataset...
# You have 154560 triplets
# Initializing model...
# train loss: 100%|██████████| 139104/139104 [51:15<00:00, 45.23img/s, loss=0.70392]
# train loss: 100%|██████████| 139104/139104 [51:42<00:00, 44.83img/s, loss=0.67572]
# train loss: 100%|██████████| 139104/139104 [52:01<00:00, 44.56img/s, loss=0.64631]
# train loss: 100%|██████████| 139104/139104 [52:02<00:00, 44.54img/s, loss=0.65884]
# train loss: 100%|██████████| 139104/139104 [51:54<00:00, 44.66img/s, loss=0.67195]
# train loss: 100%|██████████| 139104/139104 [51:53<00:00, 44.67img/s, loss=0.63531]
# train loss: 100%|██████████| 139104/139104 [51:42<00:00, 44.83img/s, loss=0.67512]
# train loss: 100%|██████████| 139104/139104 [51:39<00:00, 44.88img/s, loss=0.64622]
# train loss: 100%|██████████| 139104/139104 [51:57<00:00, 44.62img/s, loss=0.66710]
# train loss: 100%|██████████| 139104/139104 [51:53<00:00, 46.13img/s, loss=0.65860]
# Validation round:   0%|          | 0/966 [00:00<?, ?img/s]
# Validation round:   2%|▏         | 16/966 [00:01<01:54,  8.32img/s]
# Validation round:   3%|▎         | 32/966 [00:02<01:23, 11.24img/s]
# Validation round:   5%|▍         | 48/966 [00:02<01:03, 14.45img/s]
# Validation round:   7%|▋         | 64/966 [00:02<00:48, 18.66img/s]
# Validation round:   8%|▊         | 80/966 [00:03<00:38, 22.81img/s]
# Validation round:  10%|▉         | 96/966 [00:03<00:32, 26.64img/s]
# Validation round:  12%|█▏        | 112/966 [00:04<00:31, 26.90img/s]
# Validation round:  13%|█▎        | 128/966 [00:04<00:30, 27.19img/s]
# Validation round:  15%|█▍        | 144/966 [00:05<00:38, 21.54img/s]
# Validation round:  17%|█▋        | 160/966 [00:06<00:30, 26.02img/s]
# Validation round:  18%|█▊        | 176/966 [00:06<00:25, 31.52img/s]
# Validation round:  20%|█▉        | 192/966 [00:07<00:26, 28.74img/s]
# Validation round:  22%|██▏       | 208/966 [00:07<00:22, 33.74img/s]
# Validation round:  23%|██▎       | 224/966 [00:07<00:18, 40.84img/s]
# Validation round:  25%|██▍       | 240/966 [00:07<00:15, 46.55img/s]
# Validation round:  27%|██▋       | 256/966 [00:08<00:14, 49.16img/s]
# Validation round:  28%|██▊       | 272/966 [00:08<00:14, 49.45img/s]
# Validation round:  30%|██▉       | 288/966 [00:08<00:15, 43.24img/s]
# Validation round:  31%|███▏      | 304/966 [00:09<00:14, 45.69img/s]
# Validation round:  33%|███▎      | 320/966 [00:09<00:16, 39.90img/s]
# Validation round:  35%|███▍      | 336/966 [00:10<00:19, 31.93img/s]
# Validation round:  36%|███▋      | 352/966 [00:10<00:15, 39.32img/s]
# Validation round:  38%|███▊      | 368/966 [00:11<00:17, 33.91img/s]
# Validation round:  40%|███▉      | 384/966 [00:11<00:16, 34.35img/s]
# Validation round:  41%|████▏     | 400/966 [00:11<00:13, 41.80img/s]
# Validation round:  43%|████▎     | 416/966 [00:12<00:14, 38.35img/s]
# Validation round:  45%|████▍     | 432/966 [00:13<00:25, 20.72img/s]
# Validation round:  46%|████▋     | 448/966 [00:14<00:25, 19.96img/s]
# Validation round:  48%|████▊     | 464/966 [00:15<00:20, 25.08img/s]
# Validation round:  50%|████▉     | 480/966 [00:15<00:15, 30.83img/s]
# Validation round:  51%|█████▏    | 496/966 [00:15<00:13, 34.12img/s]
# Validation round:  53%|█████▎    | 512/966 [00:15<00:12, 37.41img/s]
# train loss: 100%|██████████| 139104/139104 [52:10<00:00, 46.13img/s, loss=0.65860]
# Validation round:  56%|█████▋    | 544/966 [00:16<00:11, 36.79img/s]
# Validation round:  58%|█████▊    | 560/966 [00:18<00:21, 18.88img/s]
# Validation round:  60%|█████▉    | 576/966 [00:19<00:18, 20.85img/s]
# Validation round:  61%|██████▏   | 592/966 [00:20<00:17, 20.95img/s]
# Validation round:  63%|██████▎   | 608/966 [00:20<00:13, 26.27img/s]
# Validation round:  65%|██████▍   | 624/966 [00:20<00:10, 32.17img/s]
# Validation round:  66%|██████▋   | 640/966 [00:20<00:08, 38.82img/s]
# Validation round:  68%|██████▊   | 656/966 [00:20<00:06, 44.31img/s]
# Validation round:  70%|██████▉   | 672/966 [00:21<00:05, 49.75img/s]
# Validation round:  71%|███████   | 688/966 [00:21<00:05, 54.20img/s]
# Validation round:  73%|███████▎  | 704/966 [00:21<00:04, 57.12img/s]
# Validation round:  75%|███████▍  | 720/966 [00:21<00:04, 54.49img/s]
# Validation round:  76%|███████▌  | 736/966 [00:22<00:05, 42.87img/s]
# Validation round:  78%|███████▊  | 752/966 [00:22<00:04, 46.86img/s]
# Validation round:  80%|███████▉  | 768/966 [00:23<00:04, 42.93img/s]
# Validation round:  81%|████████  | 784/966 [00:23<00:04, 45.10img/s]
# Validation round:  83%|████████▎ | 800/966 [00:23<00:03, 48.48img/s]
# Validation round:  84%|████████▍ | 816/966 [00:24<00:03, 48.35img/s]
# Validation round:  86%|████████▌ | 832/966 [00:24<00:03, 39.07img/s]
# Validation round:  88%|████████▊ | 848/966 [00:25<00:02, 41.00img/s]
# Validation round:  89%|████████▉ | 864/966 [00:25<00:02, 44.69img/s]
# Validation round:  91%|█████████ | 880/966 [00:25<00:01, 47.39img/s]
# Validation round:  93%|█████████▎| 896/966 [00:25<00:01, 54.57img/s]
# Validation round:  94%|█████████▍| 912/966 [00:26<00:01, 35.77img/s]
# Validation round:  96%|█████████▌| 928/966 [00:26<00:00, 42.21img/s]
# Validation round:  98%|█████████▊| 944/966 [00:27<00:00, 44.35img/s]
# Validation round:  99%|█████████▉| 960/966 [00:28<00:00, 24.91img/s]
# Validation round: 976img [00:29, 26.65img/s]
# Validation round: 992img [00:29, 32.78img/s]
# Validation round: 1008img [00:29, 30.96img/s]
# Validation round: 1024img [00:30, 33.97img/s]
# Validation round: 1040img [00:30, 37.47img/s]
# Validation round: 1056img [00:31, 25.94img/s]
# Validation round: 1072img [00:32, 27.38img/s]
# Validation round: 1088img [00:32, 33.96img/s]
# Validation round: 1104img [00:32, 40.92img/s]
# Validation round: 1120img [00:32, 45.86img/s]
# Validation round: 1136img [00:33, 47.11img/s]
# Validation round: 1152img [00:33, 54.05img/s]
# Validation round: 1168img [00:33, 39.59img/s]
# Validation round: 1184img [00:34, 42.51img/s]
# Validation round: 1200img [00:34, 44.26img/s]
# Validation round: 1216img [00:34, 47.63img/s]
# Validation round: 1232img [00:35, 54.40img/s]
# Validation round: 1248img [00:35, 56.21img/s]
# Validation round: 1264img [00:35, 61.95img/s]
# Validation round: 1280img [00:35, 65.01img/s]
# Validation round: 1296img [00:36, 58.35img/s]
# Validation round: 1312img [00:36, 57.64img/s]
# Validation round: 1328img [00:36, 58.23img/s]
# Validation round: 1344img [00:37, 50.53img/s]
# Validation round: 1360img [00:37, 45.45img/s]
# Validation round: 1376img [00:37, 49.96img/s]
# Validation round: 1392img [00:37, 52.68img/s]
# Validation round: 1408img [00:38, 57.73img/s]
# Validation round: 1424img [00:38, 42.88img/s]
# Validation round: 1440img [00:39, 43.50img/s]
# Validation round: 1456img [00:39, 46.07img/s]
# Validation round: 1472img [00:39, 53.57img/s]
# Validation round: 1488img [00:39, 54.54img/s]
# Validation round: 1504img [00:40, 51.47img/s]
# Validation round: 1520img [00:40, 48.02img/s]
# Validation round: 1536img [00:40, 52.60img/s]
# Validation round: 1552img [00:41, 50.11img/s]
# Validation round: 1568img [00:41, 55.02img/s]
# Validation round: 1584img [00:42, 41.57img/s]
# Validation round: 1600img [00:42, 47.32img/s]
# Validation round: 1616img [00:42, 52.44img/s]
# Validation round: 1632img [00:42, 57.51img/s]
# Validation round: 1648img [00:42, 62.70img/s]
# Validation round: 1664img [00:43, 45.50img/s]
# Validation round: 1680img [00:45, 21.69img/s]
# Validation round: 1696img [00:45, 25.07img/s]
# Validation round: 1712img [00:45, 31.53img/s]
# Validation round: 1728img [00:46, 32.97img/s]
# Validation round: 1744img [00:46, 33.68img/s]
# Validation round: 1760img [00:47, 34.17img/s]
# Validation round: 1776img [00:47, 41.02img/s]
# Validation round: 1792img [00:47, 45.20img/s]
# Validation round: 1808img [00:48, 38.21img/s]
# Validation round: 1824img [00:48, 39.31img/s]
# Validation round: 1840img [00:48, 46.03img/s]
# Validation round: 1856img [00:49, 49.17img/s]
# Validation round: 1872img [00:49, 33.53img/s]
# Validation round: 1888img [00:50, 30.48img/s]
# Validation round: 1904img [00:50, 33.73img/s]
# Validation round: 1920img [00:51, 38.48img/s]
# Validation round: 1936img [00:51, 44.28img/s]
# Validation round: 1952img [00:51, 39.11img/s]
# Validation round: 1968img [00:52, 39.91img/s]
# Validation round: 1984img [00:52, 46.26img/s]
# Validation round: 2000img [00:52, 52.75img/s]
# Validation round: 2016img [00:52, 58.58img/s]
# Validation round: 2032img [01:00,  6.79img/s]
# Validation round: 2048img [01:00,  9.26img/s]
# Validation round: 2064img [01:01, 11.23img/s]
# Validation round: 2080img [01:01, 14.35img/s]
# Validation round: 2096img [01:01, 19.11img/s]
# Validation round: 2112img [01:01, 24.42img/s]
# Validation round: 2128img [01:04, 14.44img/s]
# Validation round: 2144img [01:04, 18.69img/s]
# Validation round: 2160img [01:04, 22.52img/s]
# Validation round: 2176img [01:05, 23.07img/s]
# Validation round: 2192img [01:05, 27.90img/s]
# Validation round: 2208img [01:05, 33.83img/s]
# Validation round: 2224img [01:06, 38.04img/s]
# Validation round: 2240img [01:08, 17.91img/s]
# Validation round: 2256img [01:08, 21.13img/s]
# Validation round: 2272img [01:08, 27.06img/s]
# Validation round: 2288img [01:09, 30.75img/s]
# Validation round: 2304img [01:09, 37.91img/s]
# Validation round: 2320img [01:09, 40.44img/s]
# Validation round: 2336img [01:10, 42.36img/s]
# Validation round: 2352img [01:10, 45.49img/s]
# Validation round: 2368img [01:10, 47.58img/s]
# Validation round: 2384img [01:10, 49.47img/s]
# Validation round: 2400img [01:11, 49.57img/s]
# Validation round: 2416img [01:11, 47.44img/s]
# Validation round: 2432img [01:13, 18.79img/s]
# Validation round: 2448img [01:13, 24.04img/s]
# Validation round: 2464img [01:14, 29.68img/s]
# Validation round: 2480img [01:15, 18.14img/s]
# Validation round: 2496img [01:16, 23.66img/s]
# Validation round: 2512img [01:16, 29.38img/s]
# Validation round: 2528img [01:16, 36.08img/s]
# Validation round: 2544img [01:16, 38.64img/s]
# Validation round: 2560img [01:17, 41.06img/s]
# Validation round: 2576img [01:17, 37.39img/s]
# Validation round: 2592img [01:18, 27.03img/s]
# Validation round: 2608img [01:18, 32.66img/s]
# Validation round: 2624img [01:19, 39.23img/s]
# Validation round: 2640img [01:19, 43.71img/s]
# Validation round: 2656img [01:19, 45.22img/s]
# Validation round: 2672img [01:19, 49.75img/s]
# Validation round: 2688img [01:20, 49.63img/s]
# Validation round: 2704img [01:20, 37.84img/s]
# Validation round: 2720img [01:21, 41.32img/s]
# Validation round: 2736img [01:21, 45.50img/s]
# Validation round: 2752img [01:21, 48.44img/s]
# Validation round: 2768img [01:22, 47.99img/s]
# Validation round: 2784img [01:22, 51.46img/s]
# Validation round: 2800img [01:22, 56.61img/s]
# Validation round: 2816img [01:22, 60.25img/s]
# Validation round: 2832img [01:23, 46.12img/s]
# Validation round: 2848img [01:23, 49.60img/s]
# Validation round: 2864img [01:24, 36.50img/s]
# Validation round: 2880img [01:24, 42.76img/s]
# Validation round: 2896img [01:24, 43.55img/s]
# Validation round: 2912img [01:25, 46.48img/s]
# Validation round: 2928img [01:25, 51.15img/s]
# Validation round: 2944img [01:25, 53.95img/s]
# Validation round: 2960img [01:26, 49.29img/s]
# Validation round: 2976img [01:27, 20.20img/s]
# Validation round: 2992img [01:28, 24.94img/s]
# Validation round: 3008img [01:28, 29.83img/s]
# Validation round: 3024img [01:28, 31.14img/s]
# Validation round: 3040img [01:29, 31.40img/s]
# Validation round: 3056img [01:31, 15.26img/s]
# Validation round: 3072img [01:32, 19.65img/s]
# Validation round: 3088img [01:34, 11.10img/s]
# Validation round: 3104img [01:35, 14.38img/s]
# Validation round: 3120img [01:35, 18.29img/s]
# Validation round: 3136img [01:35, 23.59img/s]
# Validation round: 3152img [01:36, 28.31img/s]
# Validation round: 3168img [01:36, 34.13img/s]
# Validation round: 3184img [01:38, 18.91img/s]
# Validation round: 3200img [01:38, 23.94img/s]
# Validation round: 3216img [01:39, 23.61img/s]
# Validation round: 3232img [01:39, 29.90img/s]
# Validation round: 3248img [01:39, 35.24img/s]
# Validation round: 3264img [01:39, 42.62img/s]
# Validation round: 3280img [01:39, 49.88img/s]
# Validation round: 3296img [01:40, 52.91img/s]
# Validation round: 3312img [01:40, 55.89img/s]
# Validation round: 3328img [01:40, 59.37img/s]
# Validation round: 3344img [01:41, 54.14img/s]
# Validation round: 3360img [01:42, 23.05img/s]
# Validation round: 3376img [01:43, 18.48img/s]
# Validation round: 3392img [01:44, 23.98img/s]
# Validation round: 3408img [01:44, 28.05img/s]
# Validation round: 3424img [01:44, 34.24img/s]
# Validation round: 3440img [01:45, 34.35img/s]
# Validation round: 3456img [01:45, 32.38img/s]
# Validation round: 3472img [01:46, 34.93img/s]
# Validation round: 3488img [01:46, 31.14img/s]
# Validation round: 3504img [01:46, 37.95img/s]
# Validation round: 3520img [01:47, 43.31img/s]
# Validation round: 3536img [01:47, 45.91img/s]
# Validation round: 3552img [01:49, 18.89img/s]
# Validation round: 3568img [01:49, 24.14img/s]
# Validation round: 3584img [01:49, 30.63img/s]
# Validation round: 3600img [01:50, 34.61img/s]
# Validation round: 3616img [01:50, 37.47img/s]
# Validation round: 3632img [01:50, 43.49img/s]
# Validation round: 3648img [01:51, 46.52img/s]
# Validation round: 3664img [01:51, 53.24img/s]
# Validation round: 3680img [01:51, 39.42img/s]
# Validation round: 3696img [01:52, 44.57img/s]
# Validation round: 3712img [01:52, 47.21img/s]
# Validation round: 3728img [01:52, 42.47img/s]
# Validation round: 3744img [01:53, 43.99img/s]
# Validation round: 3760img [01:53, 44.98img/s]
# Validation round: 3776img [01:53, 52.07img/s]
# Validation round: 3792img [01:54, 39.74img/s]
# Validation round: 3808img [01:54, 45.82img/s]
# Validation round: 3824img [01:54, 50.51img/s]
# Validation round: 3840img [01:55, 56.12img/s]
# Validation round: 3856img [01:55, 36.93img/s]
# Validation round: 3872img [01:56, 40.69img/s]
# Validation round: 3888img [01:56, 40.88img/s]
# Validation round: 3904img [01:56, 43.86img/s]
# Validation round: 3920img [01:57, 46.01img/s]
# Validation round: 3936img [01:57, 37.85img/s]
# Validation round: 3952img [01:58, 43.56img/s]
# Validation round: 3968img [01:58, 49.42img/s]
# Validation round: 3984img [01:58, 46.23img/s]
# Validation round: 4000img [01:58, 47.29img/s]
# Validation round: 4016img [01:59, 43.20img/s]
# Validation round: 4032img [01:59, 49.22img/s]
# Validation round: 4048img [01:59, 54.37img/s]
# Validation round: 4064img [02:01, 28.58img/s]
# Validation round: 4080img [02:01, 34.77img/s]
# Validation round: 4096img [02:01, 41.39img/s]
# Validation round: 4112img [02:01, 39.15img/s]
# Validation round: 4128img [02:02, 32.13img/s]
# Validation round: 4144img [02:02, 38.46img/s]
# Validation round: 4160img [02:03, 46.13img/s]
# Validation round: 4176img [02:03, 46.02img/s]
# Validation round: 4192img [02:05, 20.99img/s]
# Validation round: 4208img [02:05, 26.49img/s]
# Validation round: 4224img [02:05, 33.14img/s]
# Validation round: 4240img [02:06, 33.48img/s]
# Validation round: 4256img [02:06, 37.21img/s]
# Validation round: 4272img [02:06, 41.00img/s]
# Validation round: 4288img [02:06, 47.90img/s]
# Validation round: 4304img [02:07, 41.92img/s]
# Validation round: 4320img [02:09, 20.72img/s]
# Validation round: 4336img [02:09, 22.53img/s]
# Validation round: 4352img [02:09, 27.56img/s]
# Validation round: 4368img [02:10, 30.99img/s]
# Validation round: 4384img [02:10, 32.20img/s]
# Validation round: 4400img [02:11, 33.14img/s]
# Validation round: 4416img [02:11, 38.20img/s]
# Validation round: 4432img [02:11, 41.43img/s]
# Validation round: 4448img [02:11, 48.12img/s]
# Validation round: 4464img [02:12, 54.10img/s]
# Validation round: 4480img [02:12, 52.37img/s]
# Validation round: 4496img [02:12, 49.16img/s]
# Validation round: 4512img [02:13, 50.53img/s]
# Validation round: 4528img [02:13, 55.49img/s]
# Validation round: 4544img [02:13, 52.42img/s]
# Validation round: 4560img [02:13, 57.67img/s]
# Validation round: 4576img [02:14, 50.29img/s]
# Validation round: 4592img [02:14, 55.49img/s]
# Validation round: 4608img [02:15, 42.46img/s]
# Validation round: 4624img [02:15, 42.46img/s]
# Validation round: 4640img [02:15, 48.38img/s]
# Validation round: 4656img [02:16, 40.46img/s]
# Validation round: 4672img [02:16, 42.97img/s]
# Validation round: 4688img [02:16, 45.81img/s]
# Validation round: 4704img [02:17, 34.42img/s]
# Validation round: 4720img [02:18, 36.45img/s]
# Validation round: 4736img [02:18, 41.46img/s]
# Validation round: 4752img [02:18, 44.90img/s]
# Validation round: 4768img [02:18, 48.71img/s]
# Validation round: 4784img [02:19, 53.98img/s]
# Validation round: 4800img [02:19, 47.60img/s]
# Validation round: 4816img [02:19, 52.39img/s]
# Validation round: 4832img [02:19, 58.71img/s]
# Validation round: 4848img [02:20, 55.84img/s]
# Validation round: 4864img [02:20, 61.62img/s]
# Validation round: 4880img [02:21, 33.19img/s]
# Validation round: 4896img [02:21, 39.56img/s]
# Validation round: 4912img [02:21, 47.17img/s]
# Validation round: 4928img [02:22, 48.53img/s]
# Validation round: 4944img [02:22, 45.25img/s]
# Validation round: 4960img [02:22, 51.26img/s]
# Validation round: 4976img [02:23, 54.60img/s]
# Validation round: 4992img [02:23, 59.07img/s]
# Validation round: 5008img [02:24, 23.76img/s]
# Validation round: 5024img [02:25, 29.91img/s]
# Validation round: 5040img [02:25, 36.35img/s]
# Validation round: 5056img [02:25, 36.62img/s]
# Validation round: 5072img [02:25, 43.80img/s]
# Validation round: 5088img [02:26, 50.28img/s]
# Validation round: 5104img [02:26, 54.97img/s]
# Validation round: 5120img [02:26, 59.37img/s]
# Validation round: 5136img [02:26, 53.48img/s]
# Validation round: 5152img [02:27, 44.32img/s]
# Validation round: 5168img [02:27, 45.33img/s]
# Validation round: 5184img [02:28, 43.19img/s]
# Validation round: 5200img [02:28, 50.10img/s]
# Validation round: 5216img [02:28, 41.07img/s]
# Validation round: 5232img [02:29, 41.03img/s]
# Validation round: 5248img [02:29, 47.18img/s]
# Validation round: 5264img [02:29, 48.25img/s]
# Validation round: 5280img [02:30, 46.76img/s]
# Validation round: 5296img [02:30, 53.38img/s]
# Validation round: 5312img [02:30, 56.94img/s]
# Validation round: 5328img [02:30, 60.57img/s]
# Validation round: 5344img [02:31, 62.90img/s]
# Validation round: 5360img [02:31, 58.45img/s]
# Validation round: 5376img [02:31, 58.83img/s]
# Validation round: 5392img [02:32, 51.58img/s]
# Validation round: 5408img [02:32, 52.60img/s]
# Validation round: 5424img [02:32, 44.96img/s]
# Validation round: 5440img [02:33, 48.86img/s]
# Validation round: 5456img [02:33, 53.27img/s]
# Validation round: 5472img [02:33, 56.76img/s]
# Validation round: 5488img [02:33, 58.69img/s]
# Validation round: 5504img [02:34, 55.15img/s]
# Validation round: 5520img [02:35, 21.64img/s]
# Validation round: 5536img [02:36, 26.09img/s]
# Validation round: 5552img [02:37, 24.61img/s]
# Validation round: 5568img [02:37, 28.50img/s]
# Validation round: 5584img [02:38, 22.77img/s]
# Validation round: 5600img [02:38, 25.02img/s]
# Validation round: 5616img [02:39, 25.02img/s]
# Validation round: 5632img [02:39, 29.88img/s]
# Validation round: 5648img [02:40, 33.70img/s]
# Validation round: 5664img [02:40, 33.64img/s]
# Validation round: 5680img [02:42, 18.29img/s]
# Validation round: 5696img [02:42, 23.50img/s]
# Validation round: 5712img [02:42, 29.39img/s]
# Validation round: 5728img [02:44, 22.25img/s]
# Validation round: 5744img [02:44, 28.05img/s]
# Validation round: 5760img [02:44, 29.11img/s]
# Validation round: 5776img [02:45, 25.23img/s]
# Validation round: 5792img [02:45, 32.02img/s]
# Validation round: 5808img [02:46, 38.26img/s]
# Validation round: 5824img [02:46, 45.77img/s]
# Validation round: 5840img [02:46, 48.04img/s]
# Validation round: 5856img [02:46, 54.54img/s]
# Validation round: 5872img [02:46, 59.69img/s]
# Validation round: 5888img [02:47, 57.06img/s]
# Validation round: 5904img [02:47, 53.21img/s]
# Validation round: 5920img [02:47, 59.62img/s]
# Validation round: 5936img [02:48, 57.74img/s]
# Validation round: 5952img [02:48, 38.82img/s]
# Validation round: 5968img [02:49, 28.97img/s]
# Validation round: 5984img [02:49, 33.73img/s]
# Validation round: 6000img [02:52, 14.88img/s]
# Validation round: 6016img [02:52, 17.87img/s]
# Validation round: 6032img [02:53, 20.04img/s]
# Validation round: 6048img [02:53, 25.43img/s]
# Validation round: 6064img [02:53, 31.13img/s]
# Validation round: 6080img [02:54, 38.47img/s]
# Validation round: 6096img [02:54, 44.14img/s]
# Validation round: 6112img [02:54, 41.72img/s]
# Validation round: 6128img [02:55, 44.89img/s]
# Validation round: 6144img [02:55, 51.98img/s]
# Validation round: 6160img [02:55, 43.84img/s]
# Validation round: 6176img [02:56, 43.31img/s]
# Validation round: 6192img [02:56, 49.19img/s]
# Validation round: 6208img [02:56, 54.62img/s]
# Validation round: 6224img [02:56, 54.55img/s]
# Validation round: 6240img [02:57, 52.67img/s]
# Validation round: 6256img [02:57, 46.89img/s]
# Validation round: 6272img [02:58, 27.34img/s]
# Validation round: 6288img [02:59, 34.33img/s]
# Validation round: 6304img [02:59, 39.51img/s]
# Validation round: 6320img [02:59, 44.51img/s]
# Validation round: 6336img [02:59, 49.15img/s]
# Validation round: 6352img [03:00, 44.53img/s]
# Validation round: 6368img [03:00, 41.55img/s]
# Validation round: 6384img [03:01, 32.33img/s]
# Validation round: 6400img [03:01, 37.92img/s]
# Validation round: 6416img [03:02, 34.00img/s]
# Validation round: 6432img [03:02, 35.04img/s]
# Validation round: 6448img [03:02, 41.33img/s]
# Validation round: 6464img [03:03, 48.14img/s]
# Validation round: 6480img [03:03, 37.04img/s]
# Validation round: 6496img [03:04, 42.45img/s]
# Validation round: 6512img [03:04, 47.64img/s]
# Validation round: 6528img [03:04, 50.85img/s]
# Validation round: 6544img [03:04, 56.91img/s]
# Validation round: 6560img [03:05, 47.70img/s]
# Validation round: 6576img [03:05, 53.56img/s]
# Validation round: 6592img [03:05, 49.97img/s]
# Validation round: 6608img [03:05, 57.06img/s]
# Validation round: 6624img [03:06, 51.98img/s]
# Validation round: 6640img [03:06, 58.13img/s]
# Validation round: 6656img [03:07, 29.90img/s]
# Validation round: 6672img [03:08, 32.37img/s]
# Validation round: 6688img [03:08, 39.62img/s]
# Validation round: 6704img [03:09, 31.83img/s]
# Validation round: 6720img [03:09, 39.24img/s]
# Validation round: 6736img [03:09, 46.70img/s]
# Validation round: 6752img [03:09, 48.09img/s]
# Validation round: 6768img [03:09, 54.58img/s]
# Validation round: 6784img [03:10, 57.78img/s]
# Validation round: 6800img [03:10, 63.21img/s]
# Validation round: 6816img [03:10, 65.94img/s]
# Validation round: 6832img [03:10, 64.17img/s]
# Validation round: 6848img [03:11, 55.45img/s]
# Validation round: 6864img [03:11, 58.25img/s]
# Validation round: 6880img [03:11, 60.31img/s]
# Validation round: 6896img [03:12, 52.32img/s]
# Validation round: 6912img [03:12, 58.74img/s]
# Validation round: 6928img [03:12, 51.19img/s]
# Validation round: 6944img [03:13, 50.73img/s]
# Validation round: 6960img [03:13, 47.75img/s]
# Validation round: 6976img [03:13, 50.14img/s]
# Validation round: 6992img [03:13, 56.13img/s]
# Validation round: 7008img [03:14, 59.23img/s]
# Validation round: 7024img [03:14, 37.09img/s]
# Validation round: 7040img [03:15, 26.73img/s]
# Validation round: 7056img [03:16, 31.78img/s]
# Validation round: 7072img [03:16, 38.75img/s]
# Validation round: 7088img [03:16, 40.54img/s]
# Validation round: 7104img [03:16, 47.19img/s]
# Validation round: 7120img [03:17, 49.34img/s]
# Validation round: 7136img [03:17, 52.13img/s]
# Validation round: 7152img [03:17, 48.61img/s]
# Validation round: 7168img [03:18, 49.73img/s]
# Validation round: 7184img [03:19, 27.54img/s]
# Validation round: 7200img [03:19, 27.19img/s]
# Validation round: 7216img [03:20, 30.07img/s]
# Validation round: 7232img [03:20, 31.62img/s]
# Validation round: 7248img [03:21, 37.97img/s]
# Validation round: 7264img [03:21, 43.72img/s]
# Validation round: 7280img [03:21, 48.05img/s]
# Validation round: 7296img [03:21, 48.60img/s]
# Validation round: 7312img [03:22, 52.87img/s]
# Validation round: 7328img [03:22, 58.62img/s]
# Validation round: 7344img [03:22, 60.76img/s]
# Validation round: 7360img [03:22, 64.36img/s]
# Validation round: 7376img [03:22, 68.55img/s]
# Validation round: 7392img [03:23, 65.30img/s]
# Validation round: 7408img [03:23, 50.22img/s]
# Validation round: 7424img [03:24, 50.01img/s]
# Validation round: 7440img [03:24, 49.93img/s]
# Validation round: 7456img [03:24, 55.74img/s]
# Validation round: 7472img [03:24, 53.19img/s]
# Validation round: 7488img [03:25, 55.68img/s]
# Validation round: 7504img [03:25, 56.82img/s]
# Validation round: 7520img [03:25, 62.63img/s]
# Validation round: 7536img [03:25, 55.70img/s]
# Validation round: 7552img [03:28, 19.50img/s]
# Validation round: 7568img [03:28, 25.22img/s]
# Validation round: 7584img [03:28, 30.19img/s]
# Validation round: 7600img [03:28, 33.83img/s]
# Validation round: 7616img [03:29, 36.85img/s]
# Validation round: 7632img [03:29, 38.81img/s]
# Validation round: 7648img [03:29, 41.13img/s]
# Validation round: 7664img [03:30, 42.92img/s]
# Validation round: 7680img [03:30, 48.17img/s]
# Validation round: 7696img [03:30, 47.83img/s]
# Validation round: 7712img [03:31, 50.83img/s]
# Validation round: 7728img [03:31, 44.95img/s]
# Validation round: 7744img [03:33, 17.77img/s]
# Validation round: 7760img [03:34, 16.67img/s]
# Validation round: 7776img [03:35, 21.84img/s]
# Validation round: 7792img [03:35, 26.99img/s]
# Validation round: 7808img [03:35, 34.02img/s]
# Validation round: 7824img [03:35, 38.45img/s]
# Validation round: 7840img [03:35, 45.11img/s]
# Validation round: 7856img [03:36, 41.17img/s]
# Validation round: 7872img [03:37, 29.65img/s]
# Validation round: 7888img [03:38, 27.13img/s]
# Validation round: 7904img [03:38, 30.58img/s]
# Validation round: 7920img [03:38, 33.60img/s]
# Validation round: 7936img [03:39, 37.35img/s]
# Validation round: 7952img [03:39, 39.92img/s]
# Validation round: 7968img [03:39, 38.68img/s]
# Validation round: 7984img [03:40, 41.79img/s]
# Validation round: 8000img [03:40, 48.64img/s]
# Validation round: 8016img [03:40, 48.10img/s]
# Validation round: 8032img [03:41, 50.36img/s]
# Validation round: 8048img [03:41, 51.74img/s]
# Validation round: 8064img [03:41, 51.20img/s]
# Validation round: 8080img [03:41, 55.15img/s]
# Validation round: 8096img [03:42, 58.37img/s]
# Validation round: 8112img [03:42, 59.22img/s]
# Validation round: 8128img [03:42, 63.74img/s]
# Validation round: 8144img [03:42, 66.10img/s]
# Validation round: 8160img [03:43, 57.18img/s]
# Validation round: 8176img [03:43, 59.54img/s]
# Validation round: 8192img [03:43, 54.03img/s]
# Validation round: 8208img [03:44, 51.71img/s]
# Validation round: 8224img [03:44, 54.65img/s]
# Validation round: 8240img [03:44, 50.45img/s]
# Validation round: 8256img [03:44, 54.91img/s]
# Validation round: 8272img [03:45, 52.45img/s]
# Validation round: 8288img [03:45, 56.63img/s]
# Validation round: 8304img [03:46, 45.86img/s]
# Validation round: 8320img [03:46, 50.70img/s]
# Validation round: 8336img [03:46, 46.66img/s]
# Validation round: 8352img [03:46, 50.72img/s]
# Validation round: 8368img [03:47, 52.06img/s]
# Validation round: 8384img [03:47, 54.36img/s]
# Validation round: 8400img [03:47, 58.50img/s]
# Validation round: 8416img [03:47, 64.79img/s]
# Validation round: 8432img [03:48, 67.91img/s]
# Validation round: 8448img [03:48, 54.73img/s]
# Validation round: 8464img [03:48, 51.20img/s]
# Validation round: 8480img [03:49, 33.17img/s]
# Validation round: 8496img [03:53, 11.67img/s]
# Validation round: 8512img [03:53, 15.06img/s]
# Validation round: 8528img [03:53, 19.94img/s]
# Validation round: 8544img [03:53, 25.38img/s]
# Validation round: 8560img [03:54, 31.53img/s]
# Validation round: 8576img [03:54, 38.18img/s]
# Validation round: 8592img [03:54, 34.37img/s]
# Validation round: 8608img [03:55, 41.44img/s]
# Validation round: 8624img [03:55, 49.00img/s]
# Validation round: 8640img [03:55, 44.35img/s]
# Validation round: 8656img [03:56, 48.49img/s]
# Validation round: 8672img [03:56, 54.43img/s]
# Validation round: 8688img [03:56, 55.68img/s]
# Validation round: 8704img [03:56, 61.05img/s]
# Validation round: 8720img [03:57, 53.89img/s]
# Validation round: 8736img [03:57, 53.80img/s]
# Validation round: 8752img [03:58, 34.54img/s]
# Validation round: 8768img [03:58, 32.70img/s]
# Validation round: 8784img [03:59, 33.22img/s]
# Validation round: 8800img [03:59, 38.45img/s]
# Validation round: 8816img [03:59, 37.57img/s]
# Validation round: 8832img [04:00, 37.96img/s]
# Validation round: 8848img [04:00, 40.01img/s]
# Validation round: 8864img [04:01, 42.36img/s]
# Validation round: 8880img [04:01, 36.78img/s]
# Validation round: 8896img [04:01, 39.28img/s]
# Validation round: 8912img [04:02, 45.65img/s]
# Validation round: 8928img [04:02, 45.55img/s]
# Validation round: 8944img [04:02, 51.12img/s]
# Validation round: 8960img [04:03, 46.92img/s]
# Validation round: 8976img [04:03, 37.54img/s]
# Validation round: 8992img [04:04, 36.58img/s]
# Validation round: 9008img [04:04, 33.78img/s]
# Validation round: 9024img [04:05, 38.85img/s]
# Validation round: 9040img [04:05, 45.31img/s]
# Validation round: 9056img [04:05, 46.35img/s]
# Validation round: 9072img [04:06, 45.43img/s]
# Validation round: 9088img [04:06, 52.71img/s]
# Validation round: 9104img [04:06, 58.39img/s]
# Validation round: 9120img [04:06, 63.57img/s]
# Validation round: 9136img [04:07, 53.48img/s]
# Validation round: 9152img [04:07, 46.91img/s]
# Validation round: 9168img [04:07, 48.44img/s]
# Validation round: 9184img [04:07, 55.68img/s]
# Validation round: 9200img [04:08, 61.38img/s]
# Validation round: 9216img [04:08, 59.26img/s]
# Validation round: 9232img [04:08, 54.94img/s]
# Validation round: 9248img [04:09, 34.63img/s]
# Validation round: 9264img [04:09, 38.80img/s]
# Validation round: 9280img [04:10, 41.12img/s]
# Validation round: 9296img [04:10, 48.79img/s]
# Validation round: 9312img [04:11, 24.93img/s]
# Validation round: 9328img [04:12, 28.38img/s]
# Validation round: 9344img [04:12, 32.12img/s]
# Validation round: 9360img [04:12, 37.70img/s]
# Validation round: 9376img [04:13, 45.29img/s]
# Validation round: 9392img [04:13, 41.54img/s]
# Validation round: 9408img [04:13, 43.42img/s]
# Validation round: 9424img [04:13, 50.29img/s]
# Validation round: 9440img [04:14, 41.45img/s]
# Validation round: 9456img [04:14, 47.57img/s]
# Validation round: 9472img [04:15, 39.62img/s]
# Validation round: 9488img [04:15, 39.50img/s]
# Validation round: 9504img [04:20,  9.52img/s]
# Validation round: 9520img [04:20, 12.80img/s]
# Validation round: 9536img [04:21, 12.81img/s]
# Validation round: 9552img [04:22, 16.47img/s]
# Validation round: 9568img [04:22, 21.74img/s]
# Validation round: 9584img [04:22, 26.91img/s]
# Validation round: 9600img [04:22, 31.62img/s]
# Validation round: 9616img [04:23, 34.26img/s]
# Validation round: 9632img [04:23, 40.27img/s]
# Validation round: 9648img [04:24, 32.55img/s]
# Validation round: 9664img [04:24, 35.49img/s]
# Validation round: 9680img [04:25, 34.77img/s]
# Validation round: 9696img [04:25, 41.02img/s]
# Validation round: 9712img [04:25, 42.37img/s]
# Validation round: 9728img [04:25, 49.87img/s]
# Validation round: 9744img [04:26, 39.02img/s]
# Validation round: 9760img [04:27, 29.62img/s]
# Validation round: 9776img [04:27, 34.54img/s]
# Validation round: 9792img [04:27, 39.92img/s]
# Validation round: 9808img [04:28, 45.04img/s]
# Validation round: 9824img [04:28, 51.11img/s]
# Validation round: 9840img [04:28, 57.53img/s]
# Validation round: 9856img [04:28, 59.91img/s]
# Validation round: 9872img [04:29, 47.84img/s]
# Validation round: 9888img [04:29, 46.01img/s]
# Validation round: 9904img [04:29, 49.57img/s]
# Validation round: 9920img [04:30, 55.78img/s]
# Validation round: 9936img [04:30, 49.63img/s]
# Validation round: 9952img [04:31, 37.50img/s]
# Validation round: 9968img [04:31, 41.66img/s]
# Validation round: 9984img [04:31, 41.81img/s]
# Validation round: 10000img [04:32, 43.93img/s]
# Validation round: 10016img [04:33, 25.72img/s]
# Validation round: 10032img [04:33, 26.34img/s]
# Validation round: 10048img [04:36, 15.04img/s]
# Validation round: 10064img [04:36, 19.57img/s]
# Validation round: 10080img [04:36, 25.05img/s]
# Validation round: 10096img [04:36, 31.75img/s]
# Validation round: 10112img [04:37, 24.49img/s]
# Validation round: 10128img [04:37, 30.64img/s]
# Validation round: 10144img [04:38, 36.82img/s]
# Validation round: 10160img [04:38, 42.52img/s]
# Validation round: 10176img [04:38, 46.11img/s]
# Validation round: 10192img [04:38, 50.52img/s]
# Validation round: 10208img [04:39, 52.11img/s]
# Validation round: 10224img [04:39, 51.23img/s]
# Validation round: 10240img [04:39, 51.95img/s]
# Validation round: 10256img [04:40, 48.42img/s]
# Validation round: 10272img [04:40, 52.43img/s]
# Validation round: 10288img [04:40, 46.65img/s]
# Validation round: 10304img [04:41, 44.21img/s]
# Validation round: 10320img [04:41, 42.24img/s]
# Validation round: 10336img [04:41, 48.83img/s]
# Validation round: 10352img [04:42, 54.91img/s]
# Validation round: 10368img [04:42, 56.95img/s]
# Validation round: 10384img [04:42, 62.52img/s]
# Validation round: 10400img [04:42, 57.40img/s]
# Validation round: 10416img [04:43, 41.07img/s]
# Validation round: 10432img [04:43, 47.66img/s]
# Validation round: 10448img [04:44, 50.93img/s]
# Validation round: 10464img [04:51,  6.31img/s]
# Validation round: 10480img [04:52,  8.36img/s]
# Validation round: 10496img [04:52, 11.32img/s]
# Validation round: 10512img [04:53, 14.06img/s]
# Validation round: 10528img [04:53, 16.70img/s]
# Validation round: 10544img [04:54, 17.53img/s]
# Validation round: 10560img [04:54, 21.92img/s]
# Validation round: 10576img [04:54, 27.45img/s]
# Validation round: 10592img [04:55, 33.93img/s]
# Validation round: 10608img [04:55, 34.54img/s]
# Validation round: 10624img [04:55, 40.38img/s]
# Validation round: 10640img [04:56, 46.27img/s]
# Validation round: 10656img [04:56, 36.47img/s]
# Validation round: 10672img [04:57, 33.36img/s]
# Validation round: 10688img [04:59, 14.18img/s]
# Validation round: 10704img [05:00, 17.37img/s]
# Validation round: 10720img [05:00, 22.32img/s]
# Validation round: 10736img [05:00, 28.15img/s]
# Validation round: 10752img [05:00, 35.21img/s]
# Validation round: 10768img [05:01, 35.59img/s]
# Validation round: 10784img [05:01, 39.26img/s]
# Validation round: 10800img [05:02, 42.55img/s]
# Validation round: 10816img [05:02, 45.46img/s]
# Validation round: 10832img [05:02, 51.79img/s]
# Validation round: 10848img [05:02, 51.46img/s]
# Validation round: 10864img [05:03, 33.87img/s]
# Validation round: 10880img [05:03, 40.77img/s]
# Validation round: 10896img [05:04, 48.00img/s]
# Validation round: 10912img [05:04, 55.18img/s]
# Validation round: 10928img [05:04, 52.58img/s]
# Validation round: 10944img [05:04, 51.38img/s]
# Validation round: 10960img [05:05, 45.23img/s]
# Validation round: 10976img [05:05, 47.33img/s]
# Validation round: 10992img [05:06, 37.50img/s]
# Validation round: 11008img [05:06, 40.44img/s]
# Validation round: 11024img [05:06, 42.87img/s]
# Validation round: 11040img [05:07, 38.36img/s]
# Validation round: 11056img [05:07, 43.96img/s]
# Validation round: 11072img [05:08, 45.96img/s]
# Validation round: 11088img [05:08, 49.24img/s]
# Validation round: 11104img [05:08, 53.49img/s]
# Validation round: 11120img [05:08, 56.22img/s]
# Validation round: 11136img [05:09, 60.34img/s]
# Validation round: 11152img [05:09, 54.97img/s]
# Validation round: 11168img [05:09, 52.12img/s]
# Validation round: 11184img [05:11, 20.61img/s]
# Validation round: 11200img [05:12, 24.06img/s]
# Validation round: 11216img [05:12, 29.74img/s]
# Validation round: 11232img [05:12, 35.95img/s]
# Validation round: 11248img [05:12, 40.83img/s]
# Validation round: 11264img [05:12, 46.99img/s]
# Validation round: 11280img [05:14, 24.65img/s]
# Validation round: 11296img [05:14, 31.32img/s]
# Validation round: 11312img [05:14, 36.22img/s]
# Validation round: 11328img [05:15, 42.59img/s]
# Validation round: 11344img [05:15, 44.97img/s]
# Validation round: 11360img [05:15, 42.31img/s]
# Validation round: 11376img [05:15, 49.33img/s]
# Validation round: 11392img [05:18, 18.81img/s]
# Validation round: 11408img [05:18, 23.88img/s]
# Validation round: 11424img [05:18, 24.02img/s]
# Validation round: 11440img [05:19, 24.26img/s]
# Validation round: 11456img [05:19, 28.86img/s]
# Validation round: 11472img [05:20, 22.58img/s]
# Validation round: 11488img [05:21, 20.08img/s]
# Validation round: 11504img [05:22, 24.68img/s]
# Validation round: 11520img [05:22, 26.39img/s]
# Validation round: 11536img [05:23, 30.91img/s]
# Validation round: 11552img [05:23, 30.72img/s]
# Validation round: 11568img [05:23, 35.92img/s]
# Validation round: 11584img [05:24, 43.09img/s]
# Validation round: 11600img [05:24, 42.25img/s]
# Validation round: 11616img [05:24, 40.19img/s]
# Validation round: 11632img [05:25, 42.62img/s]
# Validation round: 11648img [05:25, 49.34img/s]
# Validation round: 11664img [05:25, 52.70img/s]
# Validation round: 11680img [05:25, 58.61img/s]
# Validation round: 11696img [05:26, 62.51img/s]
# Validation round: 11712img [05:26, 62.08img/s]
# Validation round: 11728img [05:26, 57.50img/s]
# Validation round: 11744img [05:27, 55.01img/s]
# Validation round: 11760img [05:27, 61.78img/s]
# Validation round: 11776img [05:27, 42.30img/s]
# Validation round: 11792img [05:28, 44.13img/s]
# Validation round: 11808img [05:28, 43.61img/s]
# Validation round: 11824img [05:28, 42.55img/s]
# Validation round: 11840img [05:29, 36.32img/s]
# Validation round: 11856img [05:29, 43.86img/s]
# Validation round: 11872img [05:30, 49.00img/s]
# Validation round: 11888img [05:30, 54.41img/s]
# Validation round: 11904img [05:30, 58.38img/s]
# Validation round: 11920img [05:30, 61.87img/s]
# Validation round: 11936img [05:30, 61.80img/s]
# Validation round: 11952img [05:31, 65.38img/s]
# Validation round: 11968img [05:31, 66.66img/s]
# Validation round: 11984img [05:31, 60.59img/s]
# Validation round: 12000img [05:31, 61.44img/s]
# Validation round: 12016img [05:32, 45.16img/s]
# Validation round: 12032img [05:32, 49.41img/s]
# Validation round: 12048img [05:33, 45.12img/s]
# Validation round: 12064img [05:35, 17.88img/s]
# Validation round: 12080img [05:35, 22.31img/s]
# Validation round: 12096img [05:36, 25.00img/s]
# Validation round: 12112img [05:36, 31.50img/s]
# Validation round: 12128img [05:36, 36.03img/s]
# Validation round: 12144img [05:36, 39.75img/s]
# Validation round: 12160img [05:37, 42.57img/s]
# Validation round: 12176img [05:37, 42.03img/s]
# Validation round: 12192img [05:38, 34.86img/s]
# Validation round: 12208img [05:38, 39.66img/s]
# Validation round: 12224img [05:38, 39.93img/s]
# Validation round: 12240img [05:39, 47.52img/s]
# Validation round: 12256img [05:39, 52.53img/s]
# Validation round: 12272img [05:39, 59.49img/s]
# Validation round: 12288img [05:39, 61.73img/s]
# Validation round: 12304img [05:40, 54.91img/s]
# Validation round: 12320img [05:41, 32.43img/s]
# Validation round: 12336img [05:41, 32.68img/s]
# Validation round: 12352img [05:41, 36.28img/s]
# Validation round: 12368img [05:43, 19.81img/s]
# Validation round: 12384img [05:44, 20.91img/s]
# Validation round: 12400img [05:44, 25.25img/s]
# Validation round: 12416img [05:44, 31.40img/s]
# Validation round: 12432img [05:45, 30.47img/s]
# Validation round: 12448img [05:45, 37.31img/s]
# Validation round: 12464img [05:46, 33.86img/s]
# Validation round: 12480img [05:46, 40.70img/s]
# Validation round: 12496img [05:46, 46.73img/s]
# Validation round: 12512img [05:46, 46.21img/s]
# Validation round: 12528img [05:47, 44.72img/s]
# Validation round: 12544img [05:47, 51.87img/s]
# Validation round: 12560img [05:47, 51.78img/s]
# Validation round: 12576img [05:48, 56.27img/s]
# Validation round: 12592img [05:48, 57.46img/s]
# Validation round: 12608img [05:48, 53.67img/s]
# Validation round: 12624img [05:49, 32.36img/s]
# Validation round: 12640img [05:49, 37.19img/s]
# Validation round: 12656img [05:50, 38.50img/s]
# Validation round: 12672img [05:50, 42.21img/s]
# Validation round: 12688img [05:50, 49.81img/s]
# Validation round: 12704img [05:51, 51.71img/s]
# Validation round: 12720img [05:51, 57.99img/s]
# Validation round: 12736img [05:51, 56.55img/s]
# Validation round: 12752img [05:51, 59.83img/s]
# Validation round: 12768img [05:52, 60.15img/s]
# Validation round: 12784img [05:52, 55.65img/s]
# Validation round: 12800img [05:52, 62.14img/s]
# Validation round: 12816img [05:53, 29.05img/s]
# Validation round: 12832img [05:54, 34.87img/s]
# Validation round: 12848img [05:54, 39.50img/s]
# Validation round: 12864img [05:54, 44.54img/s]
# Validation round: 12880img [05:55, 40.54img/s]
# Validation round: 12896img [05:55, 41.40img/s]
# Validation round: 12912img [05:55, 47.63img/s]
# Validation round: 12928img [05:55, 48.82img/s]
# Validation round: 12944img [05:56, 52.23img/s]
# Validation round: 12960img [05:56, 57.51img/s]
# Validation round: 12976img [05:56, 50.29img/s]
# Validation round: 12992img [05:57, 54.24img/s]
# Validation round: 13008img [05:57, 54.76img/s]
# Validation round: 13024img [05:57, 56.99img/s]
# Validation round: 13040img [05:57, 57.02img/s]
# Validation round: 13056img [05:58, 46.44img/s]
# Validation round: 13072img [05:58, 47.04img/s]
# Validation round: 13088img [05:58, 52.86img/s]
# Validation round: 13104img [05:59, 34.08img/s]
# Validation round: 13120img [05:59, 39.89img/s]
# Validation round: 13136img [06:00, 39.83img/s]
# Validation round: 13152img [06:00, 43.77img/s]
# Validation round: 13168img [06:01, 35.83img/s]
# Validation round: 13184img [06:01, 39.49img/s]
# Validation round: 13200img [06:01, 46.71img/s]
# Validation round: 13216img [06:02, 51.45img/s]
# Validation round: 13232img [06:02, 51.38img/s]
# Validation round: 13248img [06:02, 57.50img/s]
# Validation round: 13264img [06:02, 56.97img/s]
# Validation round: 13280img [06:03, 61.48img/s]
# Validation round: 13296img [06:03, 56.40img/s]
# Validation round: 13312img [06:03, 59.27img/s]
# Validation round: 13328img [06:04, 51.02img/s]
# Validation round: 13344img [06:04, 53.51img/s]
# Validation round: 13360img [06:05, 37.39img/s]
# Validation round: 13376img [06:05, 37.81img/s]
# Validation round: 13392img [06:05, 42.91img/s]
# Validation round: 13408img [06:05, 49.07img/s]
# Validation round: 13424img [06:06, 40.80img/s]
# Validation round: 13440img [06:06, 44.89img/s]
# Validation round: 13456img [06:07, 48.47img/s]
# Validation round: 13472img [06:07, 54.04img/s]
# Validation round: 13488img [06:07, 49.78img/s]
# Validation round: 13504img [06:07, 47.92img/s]
# Validation round: 13520img [06:08, 53.91img/s]
# Validation round: 13536img [06:08, 57.79img/s]
# Validation round: 13552img [06:08, 53.68img/s]
# Validation round: 13568img [06:09, 54.27img/s]
# Validation round: 13584img [06:09, 46.56img/s]
# Validation round: 13600img [06:09, 52.62img/s]
# Validation round: 13616img [06:10, 46.14img/s]
# Validation round: 13632img [06:10, 49.31img/s]
# Validation round: 13648img [06:11, 23.90img/s]
# Validation round: 13664img [06:12, 29.93img/s]
# Validation round: 13680img [06:12, 36.85img/s]
# Validation round: 13696img [06:12, 43.91img/s]
# Validation round: 13712img [06:12, 41.45img/s]
# Validation round: 13728img [06:13, 35.80img/s]
# Validation round: 13744img [06:14, 30.44img/s]
# Validation round: 13760img [06:14, 35.98img/s]
# Validation round: 13776img [06:14, 42.95img/s]
# Validation round: 13792img [06:15, 34.91img/s]
# Validation round: 13808img [06:15, 40.27img/s]
# Validation round: 13824img [06:15, 48.08img/s]
# Validation round: 13840img [06:16, 31.94img/s]
# Validation round: 13856img [06:16, 37.46img/s]
# Validation round: 13872img [06:17, 40.86img/s]
# Validation round: 13888img [06:17, 45.68img/s]
# Validation round: 13904img [06:18, 31.82img/s]
# Validation round: 13920img [06:19, 28.12img/s]
# Validation round: 13936img [06:19, 34.22img/s]
# Validation round: 13952img [06:20, 30.54img/s]
# Validation round: 13968img [06:20, 29.76img/s]
# Validation round: 13984img [06:20, 33.01img/s]
# Validation round: 14000img [06:21, 35.55img/s]
# Validation round: 14016img [06:21, 42.93img/s]
# Validation round: 14032img [06:21, 47.86img/s]
# Validation round: 14048img [06:21, 54.18img/s]
# Validation round: 14064img [06:22, 52.02img/s]
# Validation round: 14080img [06:22, 57.83img/s]
# Validation round: 14096img [06:22, 55.53img/s]
# Validation round: 14112img [06:23, 35.90img/s]
# Validation round: 14128img [06:23, 42.41img/s]
# Validation round: 14144img [06:24, 48.76img/s]
# Validation round: 14160img [06:24, 54.24img/s]
# Validation round: 14176img [06:24, 55.34img/s]
# Validation round: 14192img [06:24, 55.55img/s]
# Validation round: 14208img [06:25, 29.86img/s]
# Validation round: 14224img [06:26, 37.08img/s]
# Validation round: 14240img [06:27, 28.44img/s]
# Validation round: 14256img [06:27, 26.40img/s]
# Validation round: 14272img [06:27, 32.40img/s]
# Validation round: 14288img [06:28, 39.20img/s]
# Validation round: 14304img [06:28, 33.56img/s]
# Validation round: 14320img [06:29, 35.63img/s]
# Validation round: 14336img [06:29, 40.64img/s]
# Validation round: 14352img [06:29, 42.74img/s]
# Validation round: 14368img [06:30, 37.11img/s]
# Validation round: 14384img [06:30, 43.34img/s]
# Validation round: 14400img [06:30, 49.11img/s]
# Validation round: 14416img [06:30, 55.57img/s]
# Validation round: 14432img [06:31, 59.99img/s]
# Validation round: 14448img [06:31, 50.19img/s]
# Validation round: 14464img [06:31, 55.12img/s]
# Validation round: 14480img [06:32, 43.70img/s]
# Validation round: 14496img [06:32, 37.45img/s]
# Validation round: 14512img [06:33, 41.45img/s]
# Validation round: 14528img [06:33, 47.67img/s]
# Validation round: 14544img [06:34, 25.77img/s]
# Validation round: 14560img [06:35, 26.28img/s]
# Validation round: 14576img [06:35, 32.50img/s]
# Validation round: 14592img [06:38, 13.77img/s]
# Validation round: 14608img [06:38, 17.68img/s]
# Validation round: 14624img [06:38, 22.92img/s]
# Validation round: 14640img [06:39, 23.57img/s]
# Validation round: 14656img [06:39, 27.34img/s]
# Validation round: 14672img [06:42, 13.00img/s]
# Validation round: 14688img [06:42, 16.13img/s]
# Validation round: 14704img [06:43, 20.60img/s]
# Validation round: 14720img [06:43, 25.34img/s]
# Validation round: 14736img [06:43, 29.94img/s]
# Validation round: 14752img [06:44, 35.85img/s]
# Validation round: 14768img [06:44, 41.89img/s]
# Validation round: 14784img [06:44, 47.13img/s]
# Validation round: 14800img [06:44, 49.75img/s]
# Validation round: 14816img [06:45, 42.42img/s]
# Validation round: 14832img [06:45, 48.50img/s]
# Validation round: 14848img [06:46, 32.45img/s]
# Validation round: 14864img [06:46, 32.58img/s]
# Validation round: 14880img [06:47, 35.89img/s]
# Validation round: 14896img [06:47, 38.98img/s]
# Validation round: 14912img [06:47, 46.45img/s]
# Validation round: 14928img [06:48, 48.90img/s]
# Validation round: 14944img [06:48, 48.98img/s]
# Validation round: 14960img [06:48, 43.19img/s]
# Validation round: 14976img [06:49, 38.88img/s]
# Validation round: 14992img [06:49, 42.03img/s]
# Validation round: 15008img [06:49, 46.44img/s]
# Validation round: 15024img [06:50, 53.19img/s]
# Validation round: 15040img [06:50, 60.10img/s]
# Validation round: 15056img [06:50, 56.71img/s]
# Validation round: 15072img [06:51, 48.95img/s]
# Validation round: 15088img [06:51, 53.60img/s]
# Validation round: 15104img [06:51, 49.32img/s]
# Validation round: 15120img [06:52, 46.50img/s]
# Validation round: 15136img [06:52, 51.39img/s]
# Validation round: 15152img [06:52, 38.46img/s]
# Validation round: 15168img [06:53, 36.84img/s]
# Validation round: 15184img [06:54, 30.66img/s]
# Validation round: 15200img [06:54, 34.19img/s]
# Validation round: 15216img [06:56, 17.93img/s]
# Validation round: 15232img [06:57, 19.41img/s]
# Validation round: 15248img [06:57, 24.13img/s]
# Validation round: 15264img [06:57, 28.32img/s]
# Validation round: 15280img [06:58, 31.41img/s]
# Validation round: 15296img [06:58, 34.97img/s]
# Validation round: 15312img [06:58, 33.44img/s]
# Validation round: 15328img [06:59, 35.46img/s]
# Validation round: 15344img [06:59, 37.90img/s]
# Validation round: 15360img [06:59, 44.90img/s]
# Validation round: 15376img [07:00, 46.33img/s]
# Validation round: 15392img [07:00, 53.34img/s]
# Validation round: 15408img [07:00, 53.41img/s]
# Validation round: 15424img [07:00, 54.26img/s]
# Validation round: 15440img [07:01, 52.75img/s]
# Validation round: 15456img [07:03, 19.23img/s]
# Validation round: 15472img [07:03, 24.10img/s]
# Validation round: 15488img [07:03, 30.11img/s]
# Validation round: 15504img [07:04, 30.29img/s]
# Validation round: 15520img [07:04, 35.86img/s]
# Validation round: 15536img [07:05, 34.56img/s]
# Validation round: 15552img [07:05, 35.80img/s]
# Validation round: 15568img [07:05, 43.33img/s]
# Validation round: 15584img [07:06, 45.04img/s]
# Validation round: 15600img [07:06, 36.45img/s]
# Validation round: 15616img [07:06, 43.21img/s]
# Validation round: 15632img [07:08, 21.24img/s]
# Validation round: 15648img [07:08, 27.13img/s]
# Validation round: 15664img [07:09, 33.19img/s]
# Validation round: 15680img [07:09, 39.33img/s]
# Validation round: 15696img [07:09, 41.51img/s]
# Validation round: 15712img [07:09, 43.79img/s]
# Validation round: 15728img [07:11, 24.96img/s]
# ...
# Validation round: 242336img [2:01:51, 35.79img/s]
# Validation round: 242352img [2:01:51, 37.67img/s]
# Validation round: 242368img [2:01:51, 39.06img/s]
# Validation round: 242384img [2:01:52, 39.26img/s]
# Validation round: 242400img [2:01:52, 39.29img/s]
# Validation round: 242416img [2:01:52, 43.22img/s]
# Validation round: 242432img [2:01:53, 40.54img/s]
# Validation round: 242448img [2:01:53, 40.29img/s]
# Validation round: 242464img [2:01:54, 33.31img/s]
# Validation round: 242480img [2:01:54, 35.07img/s]
# Validation round: 242496img [2:01:55, 37.72img/s]
# Validation round: 242512img [2:01:55, 40.46img/s]
# Validation round: 242528img [2:01:56, 39.83img/s]
# Validation round: 242544img [2:01:57, 25.47img/s]
# Validation round: 242560img [2:01:57, 30.55img/s]
# Validation round: 242576img [2:01:57, 32.96img/s]
# Validation round: 242592img [2:01:58, 35.59img/s]
# Validation round: 242608img [2:01:59, 26.25img/s]
# Validation round: 242624img [2:02:00, 23.43img/s]
# Validation round: 242640img [2:02:00, 25.74img/s]
# Validation round: 242656img [2:02:00, 30.79img/s]
# Validation round: 242672img [2:02:01, 35.07img/s]
# Validation round: 242688img [2:02:01, 31.82img/s]
# Validation round: 242704img [2:02:02, 31.97img/s]
# Validation round: 242720img [2:02:02, 30.58img/s]
# Validation round: 242736img [2:02:04, 20.79img/s]
# Validation round: 242752img [2:02:04, 20.54img/s]
# Validation round: 242768img [2:02:05, 24.70img/s]
# Validation round: 242784img [2:02:05, 24.40img/s]
# Validation round: 242800img [2:02:06, 27.40img/s]
# Validation round: 242816img [2:02:06, 29.62img/s]
# Validation round: 242832img [2:02:07, 32.06img/s]
# Validation round: 242848img [2:02:07, 32.38img/s]
# Validation round: 242864img [2:02:08, 28.04img/s]
# Validation round: 242880img [2:02:08, 31.32img/s]
# Validation round: 242896img [2:02:09, 36.53img/s]
# Validation round: 242912img [2:02:09, 34.98img/s]
# Validation round: 242928img [2:02:10, 33.34img/s]
# Validation round: 242944img [2:02:10, 36.20img/s]
# Validation round: 242960img [2:02:11, 27.41img/s]
# Validation round: 242976img [2:02:11, 30.74img/s]
# Validation round: 242992img [2:02:12, 35.09img/s]
# Validation round: 243008img [2:02:12, 35.64img/s]
# Validation round: 243024img [2:02:13, 34.55img/s]
# Validation round: 243040img [2:02:13, 39.88img/s]
# Validation round: 243056img [2:02:13, 44.69img/s]
# Validation round: 243072img [2:02:13, 48.79img/s]
# Validation round: 243088img [2:02:14, 51.78img/s]
# Validation round: 243104img [2:02:14, 50.74img/s]
# Validation round: 243120img [2:02:14, 52.22img/s]
# Validation round: 243136img [2:02:16, 20.56img/s]
# Validation round: 243152img [2:02:16, 25.28img/s]
# Validation round: 243168img [2:02:17, 22.56img/s]
# Validation round: 243184img [2:02:18, 20.92img/s]
# Validation round: 243200img [2:02:18, 25.16img/s]
# Validation round: 243216img [2:02:19, 26.50img/s]
# Validation round: 243232img [2:02:20, 25.13img/s]
# Validation round: 243248img [2:02:20, 28.87img/s]
# Validation round: 243264img [2:02:20, 34.21img/s]
# Validation round: 243280img [2:02:21, 38.70img/s]
# Validation round: 243296img [2:02:21, 39.54img/s]
# Validation round: 243312img [2:02:21, 43.53img/s]
# Validation round: 243328img [2:02:22, 35.70img/s]
# Validation round: 243344img [2:02:22, 41.50img/s]
# Validation round: 243360img [2:02:23, 36.87img/s]
# Validation round: 243376img [2:02:23, 42.05img/s]
# Validation round: 243392img [2:02:23, 42.99img/s]
# Validation round: 243408img [2:02:24, 46.92img/s]
# Validation round: 243424img [2:02:24, 37.05img/s]
# Validation round: 243440img [2:02:24, 41.41img/s]
# Validation round: 243456img [2:02:26, 25.88img/s]
# Validation round: 243472img [2:02:26, 29.55img/s]
# Validation round: 243488img [2:02:26, 33.12img/s]
# Validation round: 243504img [2:02:27, 35.69img/s]
# Validation round: 243520img [2:02:27, 39.56img/s]
# Validation round: 243536img [2:02:28, 37.03img/s]
# Validation round: 243552img [2:02:28, 39.78img/s]
# Validation round: 243568img [2:02:29, 32.32img/s]
# Validation round: 243584img [2:02:29, 35.86img/s]
# Validation round: 243600img [2:02:30, 28.02img/s]
# Validation round: 243616img [2:02:30, 33.13img/s]
# Validation round: 243632img [2:02:30, 38.52img/s]
# Validation round: 243648img [2:02:31, 42.77img/s]
# Validation round: 243664img [2:02:31, 43.86img/s]
# Validation round: 243680img [2:02:31, 49.01img/s]
# Validation round: 243696img [2:02:32, 34.03img/s]
# Validation round: 243712img [2:02:33, 32.19img/s]
# Validation round: 243728img [2:02:33, 32.19img/s]
# Validation round: 243744img [2:02:34, 20.79img/s]
# Validation round: 243760img [2:02:35, 25.65img/s]
# Validation round: 243776img [2:02:35, 25.35img/s]
# Validation round: 243792img [2:02:36, 29.45img/s]
# Validation round: 243808img [2:02:36, 28.74img/s]
# Validation round: 243824img [2:02:37, 33.58img/s]
# Validation round: 243840img [2:02:37, 39.42img/s]
# Validation round: 243856img [2:02:37, 35.51img/s]
# Validation round: 243872img [2:02:38, 34.93img/s]
# Validation round: 243888img [2:02:39, 25.95img/s]
# Validation round: 243904img [2:02:39, 31.26img/s]
# Validation round: 243920img [2:02:39, 35.30img/s]
# Validation round: 243936img [2:02:40, 40.84img/s]
# Validation round: 243952img [2:02:40, 41.35img/s]
# Validation round: 243968img [2:02:40, 44.51img/s]
# Validation round: 243984img [2:02:41, 43.49img/s]
# Validation round: 244000img [2:02:41, 44.50img/s]
# Validation round: 244016img [2:02:41, 44.29img/s]
# Validation round: 244032img [2:02:42, 42.12img/s]
# Validation round: 244048img [2:02:42, 40.01img/s]
# Validation round: 244064img [2:02:43, 43.91img/s]
# Validation round: 244080img [2:02:43, 42.21img/s]
# Validation round: 244096img [2:02:43, 38.76img/s]
# Validation round: 244112img [2:02:44, 40.15img/s]
# Validation round: 244128img [2:02:44, 40.24img/s]
# Validation round: 244144img [2:02:45, 38.21img/s]
# Validation round: 244160img [2:02:45, 41.04img/s]
# Validation round: 244176img [2:02:45, 40.07img/s]
# Validation round: 244192img [2:02:46, 36.69img/s]
# Validation round: 244208img [2:02:47, 32.07img/s]
# Validation round: 244224img [2:02:47, 29.63img/s]
# Validation round: 244240img [2:02:48, 27.17img/s]
# Validation round: 244256img [2:02:49, 24.57img/s]
# Validation round: 244272img [2:02:49, 26.90img/s]
# Validation round: 244288img [2:02:50, 27.05img/s]
# Validation round: 244304img [2:02:51, 25.00img/s]
# Validation round: 244320img [2:02:51, 28.04img/s]
# Validation round: 244336img [2:02:52, 20.84img/s]
# Validation round: 244352img [2:02:53, 22.26img/s]
# Validation round: 244368img [2:02:53, 25.97img/s]
# Validation round: 244384img [2:02:53, 31.45img/s]
# Validation round: 244400img [2:02:54, 37.54img/s]
# Validation round: 244416img [2:02:54, 35.03img/s]
# Validation round: 244432img [2:02:54, 39.50img/s]
# Validation round: 244448img [2:02:55, 43.24img/s]
# Validation round: 244464img [2:02:55, 43.88img/s]
# Validation round: 244480img [2:02:56, 35.47img/s]
# Validation round: 244496img [2:02:58, 16.34img/s]
# Validation round: 244512img [2:02:58, 20.27img/s]
# Validation round: 244528img [2:02:59, 22.53img/s]
# Validation round: 244544img [2:02:59, 24.43img/s]
# Validation round: 244560img [2:03:01, 16.51img/s]
# Validation round: 244576img [2:03:02, 18.95img/s]
# Validation round: 244592img [2:03:02, 23.46img/s]
# Validation round: 244608img [2:03:02, 29.21img/s]
# Validation round: 244624img [2:03:03, 32.68img/s]
# Validation round: 244640img [2:03:05, 14.23img/s]
# Validation round: 244656img [2:03:06, 17.55img/s]
# Validation round: 244672img [2:03:06, 19.68img/s]
# Validation round: 244688img [2:03:07, 22.18img/s]
# Validation round: 244704img [2:03:07, 26.26img/s]
# Validation round: 244720img [2:03:07, 28.08img/s]
# Validation round: 244736img [2:03:08, 32.86img/s]
# Validation round: 244752img [2:03:08, 34.32img/s]
# Validation round: 244768img [2:03:09, 33.91img/s]
# Validation round: 244784img [2:03:09, 37.93img/s]
# Validation round: 244800img [2:03:10, 34.28img/s]
# Validation round: 244816img [2:03:10, 40.13img/s]
# Validation round: 244832img [2:03:10, 38.89img/s]
# Validation round: 244848img [2:03:10, 44.44img/s]
# Validation round: 244864img [2:03:11, 48.74img/s]
# Validation round: 244880img [2:03:11, 35.49img/s]
# Validation round: 244896img [2:03:12, 38.94img/s]
# Validation round: 244912img [2:03:12, 43.17img/s]
# Validation round: 244928img [2:03:12, 41.00img/s]
# Validation round: 244944img [2:03:13, 44.30img/s]
# Validation round: 244960img [2:03:14, 21.70img/s]
# Validation round: 244976img [2:03:15, 21.48img/s]
# Validation round: 244992img [2:03:15, 25.87img/s]
# Validation round: 245008img [2:03:18, 14.55img/s]
# Validation round: 245024img [2:03:18, 17.18img/s]
# Validation round: 245040img [2:03:19, 21.67img/s]
# Validation round: 245056img [2:03:19, 24.49img/s]
# Validation round: 245072img [2:03:19, 28.35img/s]
# Validation round: 245088img [2:03:20, 27.97img/s]
# Validation round: 245104img [2:03:20, 31.34img/s]
# Validation round: 245120img [2:03:21, 34.32img/s]
# Validation round: 245136img [2:03:21, 38.72img/s]
# Validation round: 245152img [2:03:21, 41.03img/s]
# Validation round: 245168img [2:03:22, 33.17img/s]
# Validation round: 245184img [2:03:23, 22.32img/s]
# Validation round: 245200img [2:03:24, 26.77img/s]
# Validation round: 245216img [2:03:24, 25.15img/s]
# Validation round: 245232img [2:03:25, 27.91img/s]
# Validation round: 245248img [2:03:25, 31.98img/s]
# Validation round: 245264img [2:03:26, 31.34img/s]
# Validation round: 245280img [2:03:26, 36.77img/s]
# Validation round: 245296img [2:03:26, 39.09img/s]
# Validation round: 245312img [2:03:26, 42.46img/s]
# Validation round: 245328img [2:03:27, 47.75img/s]
# Validation round: 245344img [2:03:27, 44.98img/s]
# Validation round: 245360img [2:03:28, 44.29img/s]
# Validation round: 245376img [2:03:28, 40.03img/s]
# Validation round: 245392img [2:03:29, 31.76img/s]
# Validation round: 245408img [2:03:29, 36.01img/s]
# Validation round: 245424img [2:03:30, 31.51img/s]
# Validation round: 245440img [2:03:31, 21.66img/s]
# Validation round: 245456img [2:03:31, 26.13img/s]
# Validation round: 245472img [2:03:32, 31.65img/s]
# Validation round: 245488img [2:03:32, 36.82img/s]
# Validation round: 245504img [2:03:32, 37.19img/s]
# Validation round: 245520img [2:03:33, 37.55img/s]
# Validation round: 245536img [2:03:35, 15.82img/s]
# Validation round: 245552img [2:03:35, 20.07img/s]
# Validation round: 245568img [2:03:36, 21.52img/s]
# Validation round: 245584img [2:03:39, 11.09img/s]
# Validation round: 245600img [2:03:39, 14.62img/s]
# Validation round: 245616img [2:03:40, 16.90img/s]
# Validation round: 245632img [2:03:41, 17.40img/s]
# Validation round: 245648img [2:03:41, 22.37img/s]
# Validation round: 245664img [2:03:41, 27.72img/s]
# Validation round: 245680img [2:03:42, 33.33img/s]
# Validation round: 245696img [2:03:42, 36.29img/s]
# Validation round: 245712img [2:03:42, 37.22img/s]
# Validation round: 245728img [2:03:43, 34.41img/s]
# Validation round: 245744img [2:03:43, 39.22img/s]
# Validation round: 245760img [2:03:43, 44.60img/s]
# Validation round: 245776img [2:03:45, 19.90img/s]
# Validation round: 245792img [2:03:45, 25.15img/s]
# Validation round: 245808img [2:03:46, 30.27img/s]
# Validation round: 245824img [2:03:46, 32.69img/s]
# Validation round: 245840img [2:03:46, 36.31img/s]
# Validation round: 245856img [2:03:47, 39.98img/s]
# Validation round: 245872img [2:03:47, 43.62img/s]
# Validation round: 245888img [2:03:47, 47.76img/s]
# Validation round: 245904img [2:03:48, 52.16img/s]
# Validation round: 245920img [2:03:48, 47.03img/s]
# Validation round: 245936img [2:03:48, 48.35img/s]
# Validation round: 245952img [2:03:49, 42.13img/s]
# Validation round: 245968img [2:03:49, 46.94img/s]
# Validation round: 245984img [2:03:50, 35.84img/s]
# Validation round: 246000img [2:03:50, 35.90img/s]
# Validation round: 246016img [2:03:51, 37.60img/s]
# Validation round: 246032img [2:03:51, 34.22img/s]
# Validation round: 246048img [2:03:52, 32.64img/s]
# Validation round: 246064img [2:03:52, 33.73img/s]
# Validation round: 246080img [2:03:52, 35.83img/s]
# Validation round: 246096img [2:03:53, 36.23img/s]
# Validation round: 246112img [2:03:53, 42.09img/s]
# Validation round: 246128img [2:03:54, 40.75img/s]
# Validation round: 246144img [2:03:54, 35.09img/s]
# Validation round: 246160img [2:03:55, 36.63img/s]
# Validation round: 246176img [2:03:55, 35.45img/s]
# Validation round: 246192img [2:03:55, 37.60img/s]
# Validation round: 246208img [2:03:56, 41.62img/s]
# Validation round: 246224img [2:03:56, 42.98img/s]
# Validation round: 246240img [2:03:56, 42.65img/s]
# Validation round: 246256img [2:03:58, 20.79img/s]
# Validation round: 246272img [2:03:58, 25.19img/s]
# Validation round: 246288img [2:03:59, 24.12img/s]
# Validation round: 246304img [2:03:59, 28.12img/s]
# Validation round: 246320img [2:04:00, 34.11img/s]
# Validation round: 246336img [2:04:00, 33.35img/s]
# Validation round: 246352img [2:04:01, 28.86img/s]
# Validation round: 246368img [2:04:01, 33.43img/s]
# Validation round: 246384img [2:04:01, 39.37img/s]
# Validation round: 246400img [2:04:02, 34.72img/s]
# Validation round: 246416img [2:04:03, 25.59img/s]
# Validation round: 246432img [2:04:04, 27.27img/s]
# Validation round: 246448img [2:04:04, 31.50img/s]
# Validation round: 246464img [2:04:05, 25.98img/s]
# Validation round: 246480img [2:04:07, 15.99img/s]
# Validation round: 246496img [2:04:08, 16.82img/s]
# Validation round: 246512img [2:04:08, 21.19img/s]
# Validation round: 246528img [2:04:09, 17.71img/s]
# Validation round: 246544img [2:04:10, 16.65img/s]
# Validation round: 246560img [2:04:10, 21.16img/s]
# Validation round: 246576img [2:04:11, 26.34img/s]
# Validation round: 246592img [2:04:11, 30.95img/s]
# Validation round: 246608img [2:04:12, 30.87img/s]
# Validation round: 246624img [2:04:12, 34.17img/s]
# Validation round: 246640img [2:04:12, 32.08img/s]
# Validation round: 246656img [2:04:13, 36.79img/s]
# Validation round: 246672img [2:04:13, 40.96img/s]
# Validation round: 246688img [2:04:14, 34.43img/s]
# Validation round: 246704img [2:04:14, 35.68img/s]
# Validation round: 246720img [2:04:15, 35.49img/s]
# Validation round: 246736img [2:04:15, 38.86img/s]
# Validation round: 246752img [2:04:15, 40.27img/s]
# Validation round: 246768img [2:04:16, 41.80img/s]
# Validation round: 246784img [2:04:16, 40.23img/s]
# Validation round: 246800img [2:04:17, 34.90img/s]
# Validation round: 246816img [2:04:17, 37.66img/s]
# Validation round: 246832img [2:04:17, 37.64img/s]
# Validation round: 246848img [2:04:18, 43.41img/s]
# Validation round: 246864img [2:04:20, 18.46img/s]
# Validation round: 246880img [2:04:20, 19.71img/s]
# Validation round: 246896img [2:04:21, 22.14img/s]
# Validation round: 246912img [2:04:21, 23.33img/s]
# Validation round: 246928img [2:04:22, 26.17img/s]
# Validation round: 246944img [2:04:22, 29.43img/s]
# Validation round: 246960img [2:04:23, 30.75img/s]
# Validation round: 246976img [2:04:23, 35.86img/s]
# Validation round: 246992img [2:04:24, 31.83img/s]
# Validation round: 247008img [2:04:24, 33.47img/s]
# Validation round: 247024img [2:04:25, 30.48img/s]
# Validation round: 247040img [2:04:25, 26.56img/s]
# Validation round: 247056img [2:04:26, 29.74img/s]
# Validation round: 247072img [2:04:26, 30.98img/s]
# Validation round: 247088img [2:04:27, 36.39img/s]
# Validation round: 247104img [2:04:28, 27.08img/s]
# Validation round: 247120img [2:04:28, 33.08img/s]
# Validation round: 247136img [2:04:33,  8.98img/s]
# Validation round: 247152img [2:04:33, 12.11img/s]
# Validation round: 247168img [2:04:34, 13.51img/s]
# Validation round: 247184img [2:04:34, 15.60img/s]
# Validation round: 247200img [2:04:35, 18.85img/s]
# Validation round: 247216img [2:04:35, 24.07img/s]
# Validation round: 247232img [2:04:35, 29.06img/s]
# Validation round: 247248img [2:04:36, 24.86img/s]
# Validation round: 247264img [2:04:36, 28.70img/s]
# Validation round: 247280img [2:04:37, 34.48img/s]
# Validation round: 247296img [2:04:37, 40.12img/s]
# Precision: 0.07539161501114539    Recall: 0.5236257210722769    Accuracy: 0.07055253291880029
# train loss: 100%|██████████| 139104/139104 [2:56:31<00:00, 13.13img/s, loss=0.65860]
# train loss: 100%|██████████| 139104/139104 [52:47<00:00, 43.92img/s, loss=0.65426]
# train loss: 100%|██████████| 139104/139104 [52:26<00:00, 44.21img/s, loss=0.61582]
# train loss:  45%|████▌     | 62640/139104 [23:24<28:11, 45.20img/s, loss=0.65080]

# %%
# test

# %%
import argparse
import logging
import os
import sys
from tqdm import tqdm
import yaml

import numpy as np
import torch
from torch import optim
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
import torch.nn.functional as F


# todo: when we add more models, we should move these variables to another location
ALL_MODEL_NAMES = ["LogoDetection"]
ALL_DATASET_NAMES = ["FlickrLogos-32, TopLogos-10"]

with open(os.path.abspath("./config/config.yaml")) as config:
    config_list = yaml.load(config, Loader=yaml.FullLoader)

# def pred(model,
#          sample,
#          device,
#          threshold=0.5):
#     if(model.eval==False):
#         model.eval()

#     queries, targets = torch.from_numpy(BasicDataset.preprocess(index=index, file:files_path))
#     queries = queries.unsqueeze(0)
#     queries = queries.to(device=device, dtype=torch.float32)
#     targets = targets.unsqueeze(0)
#     targets = targets.to(device=device, dtype=torch.float32)


def test(model,
         device,
         dataset,
         batch_size,
        #   save_path,
         verbose: bool,
         threshold=0.5):
    
    model.eval()

    # #TODO dataset preprocessing
    # with torch.no_grad():
    #     output = model(queries, targets)

    #     probs = output.squeeze(0)
    
    logging.info("\nPredicting image{} ... ")

    with tqdm(total=len(dataset), desc=f'Testing dataset', unit='test-img', disable=not verbose) as bar:
            bar.set_description(f'model testing')

            for batch in test_loader:
                queries = batch['query']  # Correct dimensions?
                targets = batch['target']
                bboxes = batch['bbox']

                queries = queries.to(device=device, dtype=torch.float32)
                targets = targets.to(device=device, dtype=torch.float32)
                bboxes = bboxes.to(device=device, dtype=torch.float32)

                with torch.no_grad():
                    pred_masks = model(queries, targets)
                    # print(pred_masks.shape)

                bar.update(queries.shape[0])
                global_step += 1
                val_score += eval_net(model, batch, device)
                # writer.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], global_step)

                writer.add_images('query_images', queries, global_step)
                writer.add_images('target_images', targets, global_step)
                # writer.add_images('bboxes/true', bboxes, global_step)
                writer.add_images('masks/pred', pred_masks, global_step)
                writer.close()
    return val_score / global_step


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--dataset',
                        choices=ALL_DATASET_NAMES,
                        help="Dataset in {}".format(ALL_DATASET_NAMES),
                        required=True
                        )

    parser.add_argument('--model',
                        choices=ALL_MODEL_NAMES,
                        help="Model in {}".format(ALL_MODEL_NAMES)
                        )

    parser.add_argument('--batch_size',
                        default=32,
                        type=int,
                        help="Number of samples in each mini-batch in SGD and Adam optimization"
                        )

    parser.add_argument('--verbose',
                        default=True,
                        type=bool,
                        help="Verbose"
                        )

    parser.add_argument('--load',
                        type=str,
                        required=True,
                        help="Path to the model to load"
                        )

    return parser.parse_args()


if __name__ == '__main__':
    # Logging
    logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
    args = get_args()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    logging.info(f'Using device {device}')

    # Modularized paths with respect to the current Dataset
    imgs_dir = config_list['datasets'][args.dataset]['images']
    masks_dir = config_list['datasets'][args.dataset]['masks']
    # TODO: Controlla che ste due liste hanno le stesse sottocartelle
    imgs_classes = [f.name for f in os.scandir(imgs_dir) if f.is_dir()]
    mask_classes = [f.name for f in os.scandir(masks_dir) if f.is_dir()]
    # checkpoint_dir = config_list['models'][args.model]['train_cp']

    model_path = config_list['models'][args.model]['paths']['model']+ "_".join([args.model, args.dataset]) + ".pt"

    # print("Loading %s dataset..." % args.dataset)
    # dataset = BasicDataset(imgs_dir=imgs_dir, masks_dir=masks_dir)

    # Change here to adapt your data
    print("Initializing model...")
    model = LogoDetection(batch_norm=args.batch_norm,
                        vgg_cfg=args.vgg_cfg)

    model.load_state_dict(
        torch.load(model_path, map_location=device)
    )
    logging.info(f'Model loaded from {model_path}')
    model.to(device=device)

    # Neo, enter in Metrics
    metrics = []

    for img_class_idx, img_class_path in enumerate(imgs_classes):
        dataset = BasicDataset(imgs_dir=f"{imgs_dir}{os.path.sep}{img_class_path}", masks_dir=f"{masks_dir}{os.path.sep}{masks_dir[img_class_idx]}", dataset_name=args.dataset, skip_bbox_lines=1)
        test_loader = DataLoader(dataset, batch_size=args.batch_size, shuffle=True, num_workers=4, pin_memory=True)

        try:
            metrics.append(test(model=model,
                                device=device,
                                dataset=test_loader,
                                batch_size=args.batch_size,
                                verbose=args.verbose
                                ))
        except KeyboardInterrupt:
            # torch.save(model.state_dict(), 'INTERRUPTED.ph')
            # logging.info('Interrupt saved')
            logging.info("Test interrupted")
            try:
                sys.exit(0)
            except SystemExit:
                os._exit(0)

# %%
# !pip install nvgpu

# %%
import nvgpu

avail_gpus = nvgpu.available_gpus()
print(avail_gpus)
