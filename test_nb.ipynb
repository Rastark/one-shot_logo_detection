# %%
# !nvidia-smi
# Out:
# Mon Jan  4 20:31:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.48                 Driver Version: 410.48                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-SXM2...  Off  | 00000000:05:00.0 Off |                    0 |
# | N/A   30C    P0    42W / 300W |   8035MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla P100-SXM2...  Off  | 00000000:06:00.0 Off |                    0 |
# | N/A   29C    P0    57W / 300W |   6673MiB / 16280MiB |     26%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla P100-SXM2...  Off  | 00000000:84:00.0 Off |                    0 |
# | N/A   35C    P0    54W / 300W |    887MiB / 16280MiB |     19%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla P100-SXM2...  Off  | 00000000:85:00.0 Off |                    0 |
# | N/A   36C    P0    60W / 300W |   8339MiB / 16280MiB |     37%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     30814      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  2761MiB |
# |    0     48618      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  1921MiB |
# |    0     48784      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  3343MiB |
# |    1     79598      C   python                                      6663MiB |
# |    2     79938      C   python                                       877MiB |
# |    3     26354      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  1671MiB |
# |    3     64350      C   ...nvidia/anaconda3/envs/tf-gpu/bin/python  5781MiB |
# |    3     80089      C   python                                       875MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Model parts

# %%
""" Parts of the U-Net model """

import torch
import torch.nn as nn
import torch.nn.functional as F


class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None, batch_norm=True):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        if batch_norm:
            self.double_conv = nn.Sequential(
                nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(mid_channels),
                nn.ReLU(inplace=True),
                nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True),
            )
        else:
            self.double_conv = nn.Sequential(
                nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
                nn.ReLU(inplace=True),
            )

    def forward(self, x):
        return self.double_conv(x)


class Downscaler(nn.Module):
    """Double conv 3x3, then max pool 2x2 stride 2"""

    def __init__(self, in_channels, out_channels, batch_norm):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            DoubleConv(in_channels, out_channels, batch_norm=batch_norm),
            nn.MaxPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Upscaler(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, batch_norm=True):
        super().__init__()
        self.upscale = nn.Sequential(
            DoubleConv(in_channels, in_channels, batch_norm=batch_norm),
            nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2),
#            nn.BatchNorm2d(out_channels)
        )

    def forward(self, x):
        return self.upscale(x)        


# Conditioning Branch
class OneOneConv(nn.Module):
    def __init__(self, in_channels, out_channels, batch_norm=True):
        super(OneOneConv, self).__init__()
        if batch_norm:
            self.conv = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True)
            )
        else:
            self.conv = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1),
                nn.ReLU(inplace=True)
            )

    def forward(self, x):
        x = self.conv(x)
        return x

# class ConditioningConcat(nn.Module):
#     def __init__(self, tile_concat):
#         super(ConditioningConcat, self).__init__()
#         self.filtered_tile = OneOneConv(self.tile_concat)       # Here or in forward method?

#     def forward(self, x):
#         return torch.cat(x, self.filtered_tile, dim=-1)


class VGG16(nn.Module):
    def __init__(self, batch_norm=True, cfg='A', in_channels=3):
        super(VGG16, self).__init__()
        self.batch_norm = batch_norm

        self.cfgs = {
            'A': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M', 512, 512, 512, 'M'],     # 6 "evenly" distributed maxpools to reduce dims to 1x1x512 
            'B': [32, 32, 'M', 64, 64, 'M', 128, 'M', 256, 'M', 512, 'M', 'OutConv'], # From the paper's git
            'C': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M', 'M']     # 6 maxpools to reduce dims to 1x1x512
        }
        self.cfg = self.cfgs[cfg]

        self.layers = []
        for v in self.cfg:
            if v == 'M':
                self.layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            elif v == 'OutConv':
                outConv = nn.Conv2d(in_channels, 512, kernel_size=2, stride=1)
                if self.batch_norm:
                    self.layers += [outConv, nn.BatchNorm2d(512), nn.ReLU(inplace=True)]
                else:
                    self.layers += [outConv, nn.ReLU(inplace=True)]
            else:
                conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
                if self.batch_norm:
                    self.layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
                else:
                    self.layers += [conv2d, nn.ReLU(inplace=True)]
                in_channels = v
        self.vgg16 = nn.Sequential(*self.layers)

    def forward(self, x):
        return self.vgg16(x)

# %%
# Model

# %%
import torch
from torch import nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
import numpy as np
import logging


class LogoDetection(nn.Module):
    def __init__(self,
                 n_channels: int = 3,
                 batch_norm=True,
                 vgg_cfg: str = 'A'):
        super(LogoDetection, self).__init__()
        self.n_channels = n_channels

        # Encoder steps
        self.input_layer = Downscaler(self.n_channels, 64, batch_norm)
        self.down_layer1 = Downscaler(64, 128, batch_norm)
        self.down_layer2 = Downscaler(128, 256, batch_norm)
        self.down_layer3 = Downscaler(256, 512, batch_norm)
        self.down_layer4 = Downscaler(512, 512, batch_norm)  # 1/(2^5)*(width x height) x 512

        # Conditioning Module
        self.latent_repr = VGG16(batch_norm, vgg_cfg)
        self.one_conv1 = OneOneConv(576, 64, batch_norm)  # 64+512
        self.one_conv2 = OneOneConv(640, 128, batch_norm)  # 128+512
        self.one_conv3 = OneOneConv(768, 256, batch_norm)  # 256+512
        self.one_conv4 = OneOneConv(1024, 512, batch_norm)  # 512+512

        # Decoder steps
        self.up1 = Upscaler(1024, 512, batch_norm)  # 512+512
        self.up2 = Upscaler(1024, 256, batch_norm)  # 512*2
        self.up3 = Upscaler(512, 128, batch_norm)  # 256*2
        self.up4 = Upscaler(256, 64, batch_norm)  # 128*2
        self.output_layer = Upscaler(128, 1, batch_norm)  # 64*2
        # self.output_layer = OutSoftmax()

        # with torch.no_grad():
        #     self.input_layer.weight = torch.nn.Parameter()

    def forward(self, query, target):
        # query = samples[:, 0]
        # target = samples[:, 1]
#         logging.info(f"query: {query}")
#        print(f"query: {query}")
#         logging.info(f"target: {target}")
#        print(f"target: {target}")
        z = self.latent_repr(query)
#         logging.info(f"z: {z}")
#         print(f"z: {z}")
        # print(z.shape)

        # Encoder + Conditioning
        x = self.input_layer(target)
#         logging.info(f"input_layer: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 128, 128)
        # print(tile.shape)
#         logging.info(f"tile1: {tile}")
        x1 = torch.cat((x, tile), dim=1)
#         logging.info(f"x1: {x1}")
        x = self.down_layer1(x)
#         logging.info(f"down1: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 64, 64)
        x2 = torch.cat((x, tile), dim=1)
#         logging.info(f"x2: {x2}")
        x = self.down_layer2(x)
#         logging.info(f"down2: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 32, 32)
        x3 = torch.cat((x, tile), dim=1)
#         logging.info(f"x3: {x3}")
        x = self.down_layer3(x)
#         logging.info(f"down3: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 16, 16)
        x4 = torch.cat((x, tile), dim=1)
#         logging.info(f"x4: {x4}")
        x = self.down_layer4(x)
#         logging.info(f"down4: {x}")

        tile = z.expand(z.shape[0], z.shape[1], 8, 8)
        x5 = torch.cat((x, tile), dim=1)
#         logging.info(f"x5: {x5}")
        # print(x.shape)

        # Decoder + Conditioning
#        x = torch.cat((x, x5), dim=1)
#        logging.info(f"cond5: {x}")
        # print(x.shape)
        x = self.up1(x5)
#         logging.info(f"up1: {x}")
        # print(x.shape)

        x4 = self.one_conv4(x4)
#         logging.info(f"cnv4: {x4}")
        x = torch.cat((x, x4), dim=1)
#         logging.info(f"cond4: {x}")
        # del x4
        x = self.up2(x)
#         logging.info(f"up2: {x}")

        x3 = self.one_conv3(x3)
#         logging.info(f"cnv3: {x3}")
        x = torch.cat((x, x3), dim=1)
#         logging.info(f"cond3: {x}")
        # del x3
        x = self.up3(x)
#         logging.info(f"up3: {x}")

        x2 = self.one_conv2(x2)
#         logging.info(f"cnv2: {x2}")
        x = torch.cat((x, x2), dim=1)
#         logging.info(f"cond2: {x}")
        # del x2
        x = self.up4(x)
#         logging.info(f"up4: {x}")

        x1 = self.one_conv1(x1)
#         logging.info(f"cnv1: {x1}")
        x = torch.cat((x, x1), dim=1)
#         logging.info(f"cond1: {x}")
        # del x1
#        output = self.up5(x)
#         logging.info(f"up5: {x}")

        output = self.output_layer(x)
        logging.info(f"output: {output}")
        return output

    def predict_mask(self, query, target):
        y = self.forward(query, target)
        output_layer = nn.Sequential(
            nn.batchNorm2d(1),
            nn.ReLU(),
            nn.Sigmoid()
            )
        return output_layer(y)

# %%
# eval

# %%
import functools, operator, collections
import torch
import torch.nn.functional as F
import numpy as np

from sklearn.metrics import jaccard_score as jsc
from sklearn.metrics import average_precision_score as avg_pr
from sklearn.cluster import DBSCAN
from sklearn import metrics

import matplotlib.pyplot as plt

from tqdm import tqdm

from skimage.measure import label, regionprops


def eval_net(model,
         loader, 
         device, 
         bbox: bool, 
         verbose: bool,
         iou_thr: int = 0.5
         ):
#     logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s: %(message)s", filename='oneshot_eval.log')
    model.eval()
    logging.info("Validating")

    # Number of batches
    n_val = len(loader)

#     logging.info(f"n_val: {n_val}")
    
    matches = 0

    # Number of bboxes
    max_matches = 0

    if bbox:
        truth_type = "bbox"
    else:
        truth_type = "mask"
    
#     logging.info(f"type of ground truth: {truth_type}")

    precisions, recalls, accuracies = [], [], []

    batch_results = []

    with tqdm(total=n_val, desc='Validation round', unit='samples', disable=not verbose) as bar:
        for batch in loader:
#             logging.info(f"New batch!")
            queries, targets, truth = batch['query'], batch['target'], batch[truth_type]
            queries = queries.to(device=device, dtype=torch.float32)
            targets = targets.to(device=device, dtype=torch.float32)
            # truth = truth.to(device=device, dtype=torch.float32)

            with torch.no_grad():
                pred = model(queries, targets)
#                 logging.info(f"Masks predicted")
#                 print(f"pred: {pred}")
                pred_masks = pred.cpu().numpy()
#                 print(f"pred_masks: {pred_masks}")
#                 logging.info(f"Masks to CPU")
#                 print(f"pred_masks_shape_0: {pred_masks.shape[0]}")
#                 print(f"pred_masks: {pred_masks}")
                # assunzione: gli indici della true e pred masks sono gli stessi
                for mask_index in range(pred_masks.shape[0]):
                    pred_mask = np.asarray(pred_masks[mask_index])
#                     print(f"pred_mask: {pred_mask}")
                    pred_mask = masks_as_image([rle_encode(pred_mask)])
#                     print(f"pred_mask.mask_as_image: {pred_mask}")
                    
                    # mask labeling and conversion to bboxes
                    pred_labels = label(pred_mask)
#                     print(f"pred_labels: {pred_labels}")
                    pred_bboxes_coords = list(map(lambda x: x.bbox, regionprops(pred_labels)))
                    pred_bboxes = calc_bboxes_from_coords(pred_bboxes_coords)
#                     print("pred_bboxes: ", pred_bboxes)

                    # computes truth bboxes in the same way as the pred
                    if bbox:
                        truth_bboxes = np.array(truth[mask_index])
                    else:
                        truth_mask = np.asarray(truth[mask_index])
                        truth_mask = masks_as_image([rle_encode(truth_mask)])
                        true_mask_labels = label(truth_mask)
                        truth_bboxes_coords = list(map(lambda x: x.bbox, regionprops(true_mask_labels)))
                        truth_bboxes = calc_bboxes_from_coords(truth_bboxes_coords)
#                         print("truth_bboxes: ", truth_bboxes)

                    max_matches += len(truth_bboxes)
    
                    logging.info(f"pred_bboxes: {pred_bboxes}")
                    logging.info(f"truth_bboxes: {truth_bboxes}")
                    
                    b_result = get_pred_results(truth_bboxes, pred_bboxes, iou_thr)
                    logging.info(f"b_result: {b_result}")
#                     print(f"b_result: {b_result}")
                    batch_results.append(b_result)
                bar.update(queries.shape[0])
                
#               logging.info(f"Batch finished. batch_results: {batch_results}")

#     print(f"Validation from eval completed")
    # Should not be here, since the eval method is used in both validation and test -> TODO: better handling of the flag.
    model.train()
    
#     print(f"Batch results: {batch_results}")
    
    result = dict(functools.reduce(operator.add, map(collections.Counter, batch_results)))
    logging.info(f"result: {result}")
#     print("result: ", str(result))
    # TODO: KeyError è troppo generico
    try:
        true_pos = result['true_pos']
    except KeyError:
        true_pos = 0
    try:
        false_pos = result['false_pos']
    except KeyError:
        false_pos = 0
    try:
        false_neg = result['false_neg']
    except KeyError:
        false_neg = 0

    precision = calc_precision(true_pos, false_pos)
    recall = calc_recall(true_pos, false_neg)
    accuracy = calc_accuracy(true_pos, false_pos, false_neg)
    output = f"Precision: {precision}    Recall: {recall}    Accuracy: {accuracy}"
    print(output)
    logging.info(output)

    return accuracy


def calc_bboxes_from_coords(bboxes_coords):
    """Calculate all bounding boxes from a set of bounding boxes coordinates"""
    bboxes = []
#     print(f"bboxes_coords: {bboxes_coords}")
    for coord_idx in range(len(bboxes_coords)):
#         print(f"coord_idx: {coord_idx}")
        coord = bboxes_coords[coord_idx]
#         print(f"coord: {coord}")
        bbox = (coord[1], coord[0], int(coord[4])-int(coord[1]), int(coord[3])-int(coord[0]))
        bboxes.append(bbox)
    return bboxes


def get_pred_results(truth_bboxes, pred_bboxes, iou_thr = 0.5):
    """Calculates true_pos, false_pos and false_neg from the input bounding boxes. """
    n_pred_idxs = range(len(pred_bboxes))
    n_truth_idxs = range(len(truth_bboxes))
    if len(n_pred_idxs) == 0:
#         print(f"n_pred_idxs = 0")
        tp = 0
        fp = 0
        fn = len(truth_bboxes)
        return {'true_pos': tp, 'false_pos': fp, 'false_neg': fn}
    if len(n_truth_idxs) == 0:
#         print(f"n_truth_idxs = 0")
        tp = 0
        fp = len(pred_bboxes)
        fn = 0
        return {'true_pos': tp, 'false_pos': fp, 'false_neg': fn}

    truth_idx_thr = []
    pred_idx_thr = []
    ious = []
    for pred_idx, pred_bbox in enumerate(pred_bboxes):
        for truth_idx, truth_bbox in enumerate(truth_bboxes):
            iou = get_jaccard(pred_bbox, truth_bbox)
            if iou > iou_thr:
                truth_idx_thr.append(truth_idx)
                pred_idx_thr.append(pred_idx)
                ious.append(iou)
#     print(f"ious: {ious}")
    # ::-1 reverses the list
    ious_desc = np.argsort(ious)[::-1]
    if len(ious_desc) == 0:
        # No matches
        tp = 0
        fp = len(pred_bboxes)
        fn = len(truth_bboxes)
    else:
        truth_match_idxes = []
        pred_match_idxes = []
        for idx in ious_desc:
            truth_idx = truth_idx_thr[idx]
            pred_idx = pred_idx_thr[idx]
            # If the bboxes are unmatched, add them to matches
            if (truth_idx not in truth_match_idxes) and (pred_idx not in pred_match_idxes):
                truth_match_idxes.append(truth_idx)
                pred_match_idxes.append(pred_match_idxes)
        tp = len(truth_match_idxes)
        fp = len(pred_bboxes) - len(pred_match_idxes)
        fn = len(truth_bboxes) - len(truth_match_idxes)
    return {'true_pos': tp, 'false_pos': fp, 'false_neg': fn}


def calc_precision(true_pos, false_neg):
    try:
        precision = true_pos / (true_pos + false_neg)
    except ZeroDivisionError:
        precision = 0.0
    return precision


def calc_recall(true_pos, false_pos):
    try:
        recall = true_pos / (true_pos + false_pos)
    except ZeroDivisionError:
        recall = 0.0
    return recall


def calc_accuracy(true_pos, false_pos, false_neg):
    try:
        accuracy = true_pos / (true_pos + false_pos + false_neg)
    except ZeroDivisionError:
        accuracy = 0.0
    return accuracy 


def calc_mavg_precision(precision_array):
    return 


def get_jaccard(pred_bbox, truth_bbox):
    pred_mask = get_mask_from_bbox(pred_bbox)
    truth_mask = get_mask_from_bbox(truth_bbox)
    return get_jaccard_from_mask(pred_mask, truth_mask)


def get_jaccard_from_mask(pred_mask, truth):
#     print(f"jsc truth: {truth}")
#     print(f"jsc pred_mask: {pred_mask}")
    return jsc(y_true=truth, y_pred=pred_mask, average='micro')


def get_mask_from_bbox(bbox):
    mask = np.zeros((256, 256))
    x = bbox[0]
    y = bbox[1]
    for width in range(bbox[2]):
        for height in range(bbox[3]):
            mask[int(x) + int(width), int(y) + int(height)] = 1
    return mask


def get_bbox_batch(img):
    bbox = np.empty((img.shape[0], 4))
    for i in range(img.shape[0]):
        bbox[i] = get_bbox(img[i])
    return bbox


def get_bbox(img):
    # img.shape = [batch_size, 1, 256, 256]
    rows = np.any(img, axis=-1)
    cols = np.any(img, axis=-2)
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    # X, Y, Width, Height
    return [cmin, rmin, cmax-cmin, rmax-rmin]


def rle_encode(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    logging.info(f"pred_img: {img}")
    pixels_old = img.T.flatten()
    pixels = img.T.flatten()
    for x in range(len(pixels_old)):
        if pixels_old[x] > 0.5:
            pixels[x] = 1
        else:
            pixels[x] = 0
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)


def rle_decode(mask_rle, shape=(256, 256)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0] * shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction


def masks_as_image(in_mask_list, all_masks=None):
    """
    Take the complete rle_encoded mask and create a mask array of the single masks
    """
    if all_masks is None:
        all_masks = np.zeros((256, 256), dtype=np.int16)
    # if isinstance(in_mask_list, list):
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks += rle_decode(mask)
    return np.expand_dims(all_masks, -1)
# Out:
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
# dataset_loader

# %%
import os
import numpy as np
from torch.utils.data import Dataset
import logging
from PIL import Image

import torch

import gzip
import shutil
import h5py
import tables


# TODO: Deve preprocessare anche le immagini di test
# TODO: Ha da funzionà co TorchVision, se hai tempo
# TODO: Visto che le maschere ci servono solo per estrapolare le bbox e confrontarle con quelle stimate, ha senso portarsi tutta la maschera e non le singole bbox?
class BasicDataset(Dataset):
    TARGET_IMAGE_PATH = "target_image_path"
    MASK_IMAGE_PATH = "mask_image_path"
    BBOX_PATH = "bbox_path"
    TARGET_IMAGE_BBOX_PATH = "target_image_bbox_path"

    # TODO: Check if the values are empty
    def __init__(self, imgs_dir: str, masks_dir: str, dataset_name: str, mask_image_dim: int = 256, query_dim: int = 64,
                 bbox_suffix: str = '.bboxes.txt', save_to_disk: bool = False, skip_bbox_lines: int = 0):
        self.imgs_dir = fix_input_dir(imgs_dir)
        self.masks_dir = fix_input_dir(masks_dir)
        self.processed_img_dir = str(self.imgs_dir[:self.imgs_dir.rindex(os.path.sep) + 1]) + "preprocessed"
        self.mask_img_dim = mask_image_dim
        self.query_dim = query_dim
        self.bbox_suffix = bbox_suffix
        self.save_to_disk = save_to_disk
        self.skip_bbox_lines = skip_bbox_lines
        assert mask_image_dim > 1, 'The dimension of mask and image must be higher than 1'
        assert query_dim > 1, 'The dimension of query image must be higher than 1'

        assert os.path.isdir(imgs_dir), f"Bad path for images directory: {imgs_dir}"

        assert os.path.isdir(masks_dir), f"Bad path for masks directory: {masks_dir}"

        if save_to_disk:
            # create processed image's directory, if not exists yet
            try:
                os.mkdir(self.processed_img_dir)
            except FileExistsError:
                # some previous instance generate this directory, no need to raise an exception
                pass

        # list of dict with the path of the images, which contains the paths for the following images:
        #       target, mask, bbox, target's bbox
        # every dict is defined by 4 str keys which have a str value
        # key = type of image
        # value = path of the image

        # List of dict. Every dict refers to an image with 4 keys:
        #       target, mask, bbox, query_target_bbox
        self.images_path = []

        # TODO: Fai in modo che preprocess calcoli sia la maschera che il bbox e poi, in base al dataset, togline uno
        if "FlickrLogos" in dataset_name:
            self.flickrlogos32_load()
        elif dataset_name == "TopLogos-10":
            self.toplogos10_load()

    def __len__(self):
        return len(self.images_path)

    def toplogos10_load(self):

        # get bbox path
        bbox_path = None
        for bbox_paths, _, bbox_list in os.walk(self.masks_dir):
            for bbox_file in bbox_list:
                if self.bbox_suffix in bbox_file:
                    bbox_path = get_class_file_path(bbox_paths, bbox_file)
                    break
            if bbox_path:
                break

        # get query image path
        query_full_image_path = f"{bbox_path[:bbox_path.index(self.bbox_suffix)]}"

        # get target images path and fill "self.images_path"
        for target_images_paths, _, target_images_list in os.walk(self.imgs_dir):
            for target_image_name in target_images_list:
                target_image_root_path, target_image_extension = os.path.splitext(
                    os.path.join(target_images_paths, target_image_name))
                if target_image_extension == ".jpg":
                    self.images_path.append(
                        {self.TARGET_IMAGE_PATH: get_class_file_path(target_images_paths, target_image_name),
                         self.MASK_IMAGE_PATH: None,
                         self.BBOX_PATH: bbox_path,
                         self.TARGET_IMAGE_BBOX_PATH: query_full_image_path})

    def flickrlogos32_load(self):

        # dict with merged masks path
        # key = target image file name
        # value = merged mask's file path
        masks_dict = {}

        # put stuff into masks_dict
        for masks_paths, _, masks_files in os.walk(self.masks_dir):
            for mask_file_name in masks_files:
                _, mask_extension = os.path.splitext(os.path.join(masks_paths, mask_file_name))
                if mask_extension == ".png" and "merged" in mask_file_name:
                    masks_dict[mask_file_name[:mask_file_name.rindex(".mask")]] = get_class_file_path(masks_paths,
                                                                                                      mask_file_name)

        # dict with every image of every class
        # key = class name
        # value = dict with images type and path
        #       key = type of image (target, query, mask)
        #       value = path of the file
        image_path_element = {}

        # put stuff into image_path_element
        for target_images_paths, _, target_images_files in os.walk(self.imgs_dir):
            # TODO: Compare come classe la cartella padre "jpg", trova un modo per risolvere
            target_image_class = target_images_paths[target_images_paths.rindex(os.path.sep) + 1:]
            for target_image_name in target_images_files:
                target_image_root_path, target_image_extension = os.path.splitext(
                    os.path.join(target_images_paths, target_image_name))
                if target_image_extension == ".jpg" and "no-logo" not in target_image_root_path:
                    x = {self.TARGET_IMAGE_PATH: get_class_file_path(target_images_paths, target_image_name),
                         self.MASK_IMAGE_PATH: masks_dict[target_image_name],
                         self.BBOX_PATH: f'{masks_dict[target_image_name][:masks_dict[target_image_name].rindex(".mask")]}{self.bbox_suffix}'}
                    try:
                        image_path_element[target_image_class].append(x)
                    except KeyError:
                        image_path_element[target_image_class] = [x]

        # fill "images_path" variable. it generate every couple (target image, query image) for the same class
        # for now, it only skips couple (target, query) of the same image
        for target_image_class in image_path_element:
            items_class = image_path_element[target_image_class]
            for outer_image in items_class:
                bbox_path = outer_image[self.BBOX_PATH]
                outer_target_image_path = outer_image[self.TARGET_IMAGE_PATH]
                for inner_image in items_class:
                    if not outer_image == inner_image:
                        target_image_path = inner_image[self.TARGET_IMAGE_PATH]
                        mask_image_path = inner_image[self.MASK_IMAGE_PATH]
                        self.images_path.append({self.TARGET_IMAGE_PATH: target_image_path,
                                                 self.MASK_IMAGE_PATH: mask_image_path,
                                                 self.BBOX_PATH: bbox_path,
                                                 self.TARGET_IMAGE_BBOX_PATH: outer_target_image_path})
        print(f"You have {len(self.images_path)} triplets")

    # preprocess the images. then save in file and return a list triplet [query image, target image, mask image]. how?
    # stretch the target image
    # stretch, crop and stretch again the query image
    # stretch the mask image
    # TODO: Check if the values are empty
    @classmethod
    def preprocess(cls, target_img_path: str, bbox_path: str, query_full_img_path: str, skip_bbox_lines: int = 0,
                   img_dim: int = 256, query_img_dim: int = 64, mask_img_path: str = None) -> dict:

        # Target image

        pil_target_img = Image.open(target_img_path)
        # stretch the image
        pil_resized_target_img = pil_target_img.resize((img_dim, img_dim))

        # Query image

        pil_target_img_bbox = Image.open(query_full_img_path)
        pil_resized_target_img_bbox = pil_target_img_bbox.resize((img_dim, img_dim))

        # we will resize, crop and resize again the image but we have the coordinates of the non resized bounding box
        target_img_width, target_img_height = pil_target_img_bbox.size
        resized_target_img_width, resized_target_img_height = pil_resized_target_img_bbox.size
        percent_width = round(100 * int(resized_target_img_width) / (int(target_img_width)), 2) / 100
        percent_height = round(100 * int(resized_target_img_height) / (int(target_img_height)), 2) / 100

        # open the bounding box file
        with open(bbox_path) as bbox_file:
            # read only the first line of the bbox file
            bbox_lines = bbox_file.readlines()
            first_line_bbox = bbox_lines[1 - skip_bbox_lines].split(' ')
            # check if we correctly skipped the first line of the file, the one with no number,
            # and if all the elements are numeric, like every coordinate should be ;)
            if first_line_bbox[0].isnumeric() and first_line_bbox[1].isnumeric() and \
                    first_line_bbox[2].isnumeric() and first_line_bbox[3].rstrip().isnumeric():
                x, y, width, height = first_line_bbox
                # adapt the old coordinates to the new stretched dimension
                left = int(x.strip()) * percent_width
                upper = int(y.strip()) * percent_height
                right = int(int(x.strip()) + int(width)) * percent_width
                lower = int(int(y.strip()) + int(height)) * percent_height
                # crop and resize the query image
                pil_query_img = pil_resized_target_img_bbox.crop((left, upper, right, lower))
                pil_resized_query_img = pil_query_img.resize((query_img_dim, query_img_dim))
            else:
                # TODO: nel traceback compare "error_string" e poi successivamente spiega l'eccezione. Trova un modo per togliere quel "error_string"
                error_string = f"Bounding box file's first line should have 4 groups of integers with whitespace " \
                               f"separator. Check {bbox_path}"
                raise Exception(error_string)

        # Mask

        if mask_img_path:
            pil_mask = Image.open(mask_img_path)
            pil_resized_mask = pil_mask.resize((img_dim, img_dim))
        else:
            pil_resized_mask = None

        # get the size of the images
        # print(f"query image dim: {pil_resized_query_img.size}")
        # print(f"target image dim: {pil_resized_target_img.size}")
        # if pil_resized_mask:
        #     print(f"mask image dim: {pil_resized_mask.size}")

        # just to test if everything works. don't look at these :)
        # if pil_resized_target_img:
        #     pil_resized_target_img.save('target.jpg')
        # if pil_resized_query_img:
        #     pil_resized_query_img.save('query.jpg')
        # if pil_resized_mask:
        #     pil_resized_mask.save('mask.jpg')

        # return the triplet (Dq, Dt, Dm) where Dq is the query image, Dt is the target image and Dm is the mask image
        return create_triplet_with_torch_representation(pil_resized_query_img,
                                                        pil_resized_target_img,
                                                        pil_resized_mask)

    # def h5py_with_pytorch(self, pil_img, index, type):
    #     x = self.h5py_compression(to_pytorch(pil_img), index, type)
    #     return x
    #
    # def h5py_without_pytorch(self, pil_img, index, type):
    #     x = self.h5py_compression(pil_img, index, type)
    #     return x

    # def store_hdf5_file_with_compression(self, image, image_index, image_type):
    #     file_name = f'{self.processed_img_dir}{os.path.sep}{image_index}_{image_type}.hdf5'
    #     f = h5py.File(file_name, "w")
    #     # TODO: Esistono altri algoritmi di compressione come Mafisc. Una roba figa che puoi usare è Bitshuffle
    #     f.create_dataset("init", compression="gzip", compression_opts=9, data=image)
    #     f.close()
    #     return file_name

    def store_hdf5_file_with_compression(self, images, image_index):
        image_type = ["query", "target", "mask"]
        image_type_index = 0
        for image in images:
            file_name = f'{self.processed_img_dir}{os.path.sep}{image_index}_{image}.hdf5'
            f = h5py.File(file_name, "w")
            # TODO: Esistono altri algoritmi di compressione come Mafisc. Una roba figa che puoi usare è Bitshuffle
            f.create_dataset("init", compression="gzip", compression_opts=9, data=images[image])
            f.close()
            image_type_index += 1
        # for image in images:
        #     file_name = f'{self.processed_img_dir}{os.path.sep}{image_index}_{image_type[image_type_index]}.hdf5'
        #     f = h5py.File(file_name, "w")
        #     # TODO: Esistono altri algoritmi di compressione come Mafisc. Una roba figa che puoi usare è Bitshuffle
        #     f.create_dataset("init", compression="gzip", compression_opts=9, data=image)
        #     f.close()
        #     image_type_index += 1
        # return file_name

    # def gzip_compress(self, index, input_file):
    #     # input_file = f'{self.processed_img_dir}{os.path.sep}{index}.npz'
    #     with open(input_file, 'rb') as f_in:
    #         output_file = f'{input_file}.gz'
    #         with gzip.open(output_file, 'wb', compresslevel=9) as f_out:
    #             shutil.copyfileobj(f_in, f_out)
    #     # if os.path.exists(input_file):
    #     #     os.remove(input_file)
    #     return output_file

    # def gzip_compress(self, index, input_file):
    #     # input_file = f'{self.processed_img_dir}{os.path.sep}{index}.npz'
    #     output_file = f'{input_file}.gz'
    #     with gzip.open(output_file, 'wb', compresslevel=1) as f_out:
    #         with open(input_file, 'rb') as f_in:
    #             shutil.copyfileobj(f_in, f_out)
    #     # if os.path.exists(input_file):
    #     #     os.remove(input_file)
    #     return output_file

    # def gzip_uncompress(self, input_file):
    #     with gzip.open(input_file, 'rb') as f:
    #         file_content = f.read()
    #     output_file = input_file[:input_file.rindex('.')]
    #     with open(output_file, mode='wb') as fp:
    #         fp.write(file_content)
    #     return output_file

    def read_hdf5_file(self, hdf5_file):
        with h5py.File(hdf5_file, 'r') as hf:
            data = hf.get('init')
            data = np.array(data)
        return data

    # def np_save_compressed(self, index, triplet_list_in_torch_representation):
    #     file_name = f'{self.processed_img_dir}{os.path.sep}{index}'
    #     # save the file so the next time you don't have to preprocess again
    #     np.savez_compressed(file_name,
    #                         query=triplet_list_in_torch_representation[0],
    #                         target=triplet_list_in_torch_representation[1],
    #                         mask=triplet_list_in_torch_representation[2])
    #     return f'{file_name}.npz'

    def __getitem__(self, item_index):
#         print(f"Getting item {item_index}")
        # get the path of the preprocessed file, if exists
        mask_file_path = f'{self.processed_img_dir}{os.path.sep}{item_index}_mask.hdf5'
        query_file_path = f'{self.processed_img_dir}{os.path.sep}{item_index}_query.hdf5'
        target_file_path = f'{self.processed_img_dir}{os.path.sep}{item_index}_target.hdf5'

        correct_order_triplet = [query_file_path, target_file_path, mask_file_path]
        triplet_element_order = ["query", "target", "mask"]

        return_dict = {}
        for file in correct_order_triplet:
            if not os.path.exists(file):
                # triplet = self.preprocess(item_index, self.images_path[item_index])
                return_dict = self.preprocess(
                    target_img_path=get_full_path(self.imgs_dir, self.images_path[item_index][self.TARGET_IMAGE_PATH]),
                    bbox_path=get_full_path(self.masks_dir, self.images_path[item_index][self.BBOX_PATH]),
                    query_full_img_path=get_full_path(self.imgs_dir,
                                                      self.images_path[item_index][self.TARGET_IMAGE_BBOX_PATH]),
                    mask_img_path=get_full_path(self.masks_dir, self.images_path[item_index][self.MASK_IMAGE_PATH]),
                    skip_bbox_lines=self.skip_bbox_lines)
                if self.save_to_disk:
                    self.store_hdf5_file_with_compression(return_dict, item_index)
                break
        else:
            triplet_index = 0
            for file in correct_order_triplet:
                if os.path.exists(file):
                    hdf5_file = self.read_hdf5_file(file)
                    return_dict[triplet_element_order[triplet_index]] = to_pytorch(hdf5_file)
                triplet_index += 1
#         print(f"Ciao, sono un fantastico {return_dict}")
        return return_dict

        # for file in correct_order_triplet:
        # # check if preprocessed file exists. if not, he will generate it. then return the triplet
        #     if os.path.exists(file):
        #         data = np.load(file, mmap_mode='r')
        #         return_tuple = np.array([data['query'], data['target'], data['mask']])
        #     else:
        #         return_tuple = self.preprocess(i, self.images_path[i])
        # return return_tuple


# something that will be deleted
# class CarvanaBasicDataset(BasicDataset):
#     def __init__(self, imgs_dir, masks_dir, scale=1):
#         super().__init__(imgs_dir, masks_dir, scale, mask_suffix='_mask')


def to_pytorch(image):
    if image:
        image_np = np.array(image)
        # mask image has only one channel, we need to explicit it
        if len(image_np.shape) == 2:
            image_np = np.expand_dims(image_np, axis=2)
        # HWC to CHW for pytorch
        img_trans = image_np.transpose((2, 0, 1))
        if img_trans.max() > 1:
            img_trans = img_trans / 255
        return torch.from_numpy(img_trans).type(torch.FloatTensor)
        # return img_trans
    else:
        return None


# dude, the name says all. just read it :/
# def create_triplet_without_torch_representation(pil_query, pil_target, pil_mask):
#     # return [np.array(pil_query), np.array(pil_target), np.array(pil_mask)]
#     # return np.array([np.array(pil_query), np.array(pil_target), np.array(pil_mask)])
#     return {
#         "query": np.array(pil_query),
#         "target": np.array(pil_target),
#         "mask": np.array(pil_mask)
#     }

def create_triplet_with_torch_representation(pil_query, pil_target, pil_mask):
    # return [to_pytorch(pil_query), to_pytorch(pil_target), to_pytorch(pil_mask)]
    # return np.array([to_pytorch(pil_query), to_pytorch(pil_target), to_pytorch(pil_mask)])
    return {
        "query": to_pytorch(pil_query),
        "target": to_pytorch(pil_target),
        "mask": to_pytorch(pil_mask)
    }


def get_class_file_path(class_name, file_name):
    class_file = f"{class_name[class_name.rindex(os.path.sep):]}{os.path.sep}{file_name}"
    if os.path.sep not in class_file[0:2]:
        class_file = f"{os.path.sep}{class_file}"
    return class_file


def get_full_path(root, file):
    try:
        if root[root.rindex(os.path.sep) + 1:].strip() == file[1:file.index(os.path.sep, 1)].strip():
            path = f"{root[:root.rindex(os.path.sep)]}{file}"
        else:
            path = f"{root}{file}"
        return path
    except AttributeError:
        return None


def fix_input_dir(dir):
    if not dir.strip()[-1:] == os.path.sep:
        return dir.strip()
    return dir.strip()[:-1]

# %%
# train

# %%
import argparse
import logging
import os
import sys
from tqdm import tqdm
import yaml

import numpy as np
import torch
from torch import optim
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
import torch.nn.functional as F

# from model.model import LogoDetection
# from utils.dataset_loader import BasicDataset

# todo: when we add more models, we should move these variables to another location
MODEL_HOME = os.path.abspath("./stored_models/")
ALL_MODEL_NAMES = ["LogoDetection"]
ALL_DATASET_NAMES = ["FlickrLogos-32", "FlickrLogos-32-test", "TopLogos-10"]

with open(os.path.abspath("./config/config.yaml")) as config:
    config_list = yaml.load(config, Loader=yaml.FullLoader)


# # Appl.load_aly Gaussian normalization to the model
# def weights_init(model):
#     if isinstance(model, nn.Module):
#         nn.init.normal_(model.weight.data, mean=0.0, std=0.01)

def train(model,
          device,
          train_loader,
          val_loader,
          max_epochs,
          optimizer,
          vgg_cfg,
          verbose,
          checkpoint_dir,
          model_path,
          save_cp,
          n_train,
          n_val,
          step_eval
          ):
    batch_size = train_loader.batch_size

    # Logging for TensorBoard
    writer = SummaryWriter(
        comment=f'LR__BS_{batch_size}_OPT_{type(optimizer).__name__}')  # does optimizer.lr work? we're gonne find out
    global_step = 0

    ### ERROR: n_train e n_val? ###
    logging.info(f'''Starting training:
        Epochs:             {max_epochs}
        Batch size:         {batch_size}
        Learning rate:      
        Training size:      {n_train}
        Validation size:    {n_val}
        Device:             {device.type}
    ''')

    #    def criterion(pred, true):
    #        return torch.div(nn.BCELoss()(pred, true), 1*1) # L = (1/(H*W)) * BCELoss
    #        return nn.BCELoss()(pred, true)
    # TypeError: unsupported operand type(s) for /: 'BCELoss' and 'int'
    """    
    # now we don't want to train every time to save some minutes. we'll skip the train if there is a model file
    if os.path.exists(checkpoint_dir) and os.path.isdir(checkpoint_dir):
        if os.listdir(checkpoint_dir):
            model.load_state_dict(torch.load(checkpoint_dir + os.path.sep + "model.pt", map_location=device))
            return eval_net(model, val_loader, device, bbox=False, verbose=True)
    """
    criterion = nn.BCEWithLogitsLoss()
    
    last_epoch_val_score = 0
    for epoch in range(max_epochs):
        logging.info(f"Epoch number {epoch}")
        model.train()  # set the model in training flag to True
        epoch_loss = 0  # resets the loss for the current epoch
        # epoch(batch_size, train_samples)

        # TODO
        with tqdm(total=n_train, desc=f'Epoch {epoch + 1}/{max_epochs}', unit='img', disable=not verbose) as bar:
            bar.set_description(f'train loss')

            for batch in train_loader:
#                 np.set_printoptions(threshold=sys.maxsize)
#                 print(f"Batch: {batch}")
#                 logging.info(f"Batch number #")
                queries = batch['query']  # Correct dimensions?
                targets = batch['target']
                true_masks = batch['mask']

                queries = queries.to(device=device, dtype=torch.float32)
                targets = targets.to(device=device, dtype=torch.float32)
                true_masks = true_masks.to(device=device, dtype=torch.float32)

#                 logging.info(f"Sending imgs to model")
#                 logging.info(f"queries: {queries}")
#                 logging.info(f"targets: {targets}")
                pred_masks = model(queries, targets)
#                 logging.info(f"model: {model}")
#                 logging.info(f"Mask predicted")
                # print(pred_masks.shape)
                loss = criterion(pred_masks, true_masks)
                epoch_loss += loss.detach().item()  # is the .detach() needed?

                # TensorBoard logging
                writer.add_scalar('Loss/train', loss.item(), global_step)

                bar.set_postfix(loss=f'{loss.item():.5f}')
                logging.info(f"Loss: {loss.item()}")

                optimizer.zero_grad()
                loss.backward()
                # nn.utils.clip_grad_value_(net.parameters(), 0.1) Gradient Clipping
                optimizer.step()

                bar.update(queries.shape[0])
                global_step += 1

                # if n_train % batch_size == 0: 
                #     n_batch = n_train // batch_size
                # else:
                #     n_batch = n_train // batch_size + 1

                ### DOMANDA: Dove lo volevamo usare? ###
                ### ALTRA DOMANDA: Non conviene farlo fuori dai cicli? ###
#                 n_batch = len(train_loader)
                # Deve farlo sia in mezzo ai batch che a fine epoca. Modifica la condizione dell'if
#                 if global_step % (n_train // (10 * batch_size)) == 0 or global_step == n_batch:
#                     for tag, value in model.named_parameters():
#                         tag = tag.replace('.', '/')
#                         writer.add_histogram('weights/' + tag, value.data.cpu().numpy(), global_step)
#                         writer.add_histogram('grads/' + tag, value.grad.cpu().numpy(), global_step)
#                     writer.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], global_step)

#                     writer.add_images('query_images', queries, global_step)
#                     writer.add_images('target_images', targets, global_step)
#                     writer.add_images('masks/true', true_masks, global_step)
#                     writer.add_images('masks/pred', pred_masks, global_step)

            # TODO: Se save_cp è false e non viene cambiato il val_split di default non va in train il 10% del dataset. Si potrebbe fare in modo che non sia così
            if save_cp and (epoch + 1) % step_eval == 0:
                """
                logging.info("Saving model")
                try:
                    os.mkdir(checkpoint_dir)
                    logging.info('Created checkpoint directory')
                except OSError:  # Maybe FileExistsError ?
                    pass
                model_files = [f for f in os.listdir(checkpoint_dir) if
                               os.path.isfile(os.path.join(checkpoint_dir, f))]
                torch.save(model.state_dict(), checkpoint_dir + os.path.sep + f'model.pt')
                for model_file in model_files:
                    os.remove(f'{checkpoint_dir}{os.path.sep}{model_file}')
                """
#                 logging.info(f"Next operation is validation")
#                 print(f"starting validation from train")
                logging.info(f"Validating")
                val_score = eval_net(model, val_loader, device, bbox=False, verbose=True)
#                 print(f"validation completed")
#                 logging.info(f"Validation complete")
                if val_score > last_epoch_val_score:
                    logging.info(f"This model is better the last one, I'm gonna save it")
                    try:
                        os.mkdir(checkpoint_dir)
                        logging.info('Created checkpoint directory')
                    except OSError:  # Maybe FileExistsError ?
                        pass
                    model_files = [f for f in os.listdir(checkpoint_dir) if
                                   os.path.isfile(os.path.join(checkpoint_dir, f))]
                    torch.save(model.state_dict(), checkpoint_dir + os.path.sep + f'CP_epoch{epoch + 1}.pt')
                    logging.info(f'Checkpoint {epoch + 1} saved!')
                    for model_file in model_files:
                        os.remove(f'{checkpoint_dir}{os.path.sep}{model_file}')
                    last_epoch_val_score = val_score

    writer.close()
    torch.save(model.state_dict(), model_path)

    # # WIP
    # # Launches evaluation on the model every evaluate_every steps.
    # # We need to change to appropriate evaluation metrics.
    # if evaluate_every > 0 and valid_samples is not None and (e + 1) % evaluate_every == 0:
    #     self.model.eval()
    #     with torch.no_grad():
    #         mrr, h1 = self.evaluator.eval(samples=valid_samples, write_output= False)

    #     # Metrics printing
    #     print("\tValidation: %f" % h1)

    # if save_path is not None:
    #     print("\tSaving model...")
    #     torch.save(self.model.state_dict(), save_path)
    # print("\tDone.")


# print("\nEvaluating model...")
# model.eval()
# mrr, h1 = Evaluator(model=model).eval(samples=dataset.test_samples, write_output=False)
# print("\tTest Hits@1: %f" % h1)
# print("\tTest Mean Reciprocal Rank: %f" % mrr)


# def get_args():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--dataset',
#                         choices=ALL_DATASET_NAMES,
#                         default="FlickrLogos-32",
#                         type=str,
#                         help="Dataset in {}".format(ALL_DATASET_NAMES)
#                         )

#     parser.add_argument('--model',
#                         choices=ALL_MODEL_NAMES,
#                         default="LogoDetection",
#                         type=str,
#                         help="Model in {}".format(ALL_MODEL_NAMES)
#                         )

#     optimizers = ['Adam', 'SGD']
#     parser.add_argument('--optimizer',
#                         choices=optimizers,
#                         default='Adam',
#                         help="Optimizer in {}".format(optimizers)
#                         )

#     parser.add_argument('--max_epochs',
#                         default=500,
#                         type=int,
#                         help="Number of epochs"
#                         )

#     parser.add_argument('--valid',
#                         default=-1,
#                         type=float,
#                         help="Number of epochs before valid"
#                         )

#     parser.add_argument('--batch_size',
#                         default=32,
#                         type=int,
#                         help="Number of samples in each mini-batch in SGD and Adam optimization"
#                         )

#     parser.add_argument('--weight_decay',
#                         default=5e-4,
#                         type=float,
#                         help="L2 weight regularization of the optimizer"
#                         )

#     parser.add_argument('--learning_rate',
#                         default=4e-4,
#                         type=float,
#                         help="Learning rate of the optimizer"
#                         )

#     parser.add_argument('--label_smooth',
#                         default=0.1,
#                         type=float,
#                         help="Label smoothing for true labels"
#                         )

#     parser.add_argument('--decay1',
#                         default=0.9,
#                         type=float,
#                         help="Decay rate for the first momentum estimate in Adam"
#                         )

#     parser.add_argument('--decay2',
#                         default=0.999,
#                         type=float,
#                         help="Decay rate for second momentum estimate in Adam"
#                         )

#     parser.add_argument('--verbose',
#                         default=True,
#                         type=bool,
#                         help="Verbose"
#                         )

#     parser.add_argument('--load',
#                         type=str,
#                         required=False,
#                         help="Path to the model to load"
#                         )

#     parser.add_argument('--batch_norm',
#                         default=False,
#                         type=bool,
#                         help="If True, apply batch normalization",
#                         )

#     parser.add_argument('--vgg_cfg',
#                         type=str,
#                         default='A',
#                         help="VGG architecture config",
#                         )

#     parser.add_argument('--step_eval',
#                         type=int,
#                         default=0,
#                         help="Enables automatic evaluation checks every X step",
#                         )

#     parser.add_argument('--val_split',
#                         type=float,
#                         default=0.1,
#                         help="Forces the validation subset to be split according to the set value. Must a value in the [0-1] or the sofware WILL break",
#                         )

#     parser.add_argument('--save_cp',
#                         type=bool,
#                         default=True,
#                         help="If True, saves model checkponts",
#                         )

#     return parser.parse_args()


def train_main(dataset='FlickrLogos-32',
     model='LogoDetection',
     optimizer='Adam',
     vgg_cfg='A',
     max_epochs=1, 
     batch_size=4,
     weight_decay=5e-4,
     learning_rate=4e-4,
     decay1=0.9, 
     decay2=0.999,
     verbose=True,
     batch_norm=True,
     load=None,
     val_split=0.1,
     step_eval=10,
     save_cp=True,
     ):
    # TODO: Add filename
    logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s: %(message)s", filename='oneshot.log', filemode='w')
#     args = get_args()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    logging.info(f'Using device {device}')

    # Modularized paths with respect to the current Dataset
    imgs_dir = config_list['datasets'][dataset]['paths']['images']
    masks_dir = config_list['datasets'][dataset]['paths']['masks']
    checkpoint_dir = config_list['models'][model]['paths']['train_cp']

    model_path = config_list['models'][model]['paths']['model']+ os.path.sep + "_".join([model, dataset]) + ".pt"
    
    # create checkpoint dir
    try:
        os.makedirs(checkpoint_dir, exist_ok=True)
    except FileExistsError:
        pass
    
    # create the model dir
    try:
        os.makedirs(config_list['models'][model]['paths']['model'], exist_ok=True)
    except FileExistsError:
        pass

    print("Loading %s dataset..." % dataset)
    # you can delete this "save_to_disk" to preserve the ssd :like:
    dataset = BasicDataset(imgs_dir=imgs_dir, masks_dir=masks_dir, dataset_name=dataset)

    # Splitting dataset
    n_val = int(len(dataset) * val_split)
    n_train = len(dataset) - n_val
    # TODO: Il validation set dovrebbe avere il 10% di ogni classe e non il 10% del totale altrimenti verrebbe sbilanciato
    train_set, val_set = random_split(dataset, [n_train, n_val])

    # Loading dataset
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True,
                            drop_last=True)

    # Change here to adapt your data
    print("Initializing model...")
    model = LogoDetection(batch_norm=batch_norm, vgg_cfg=vgg_cfg)

    # Optimizer selection
    # build all the supported optimizers using the passed params (learning rate and decays if Adam)
    supported_optimizers = {
        'Adam': optim.Adam(params=model.parameters(), lr=learning_rate, betas=(decay1, decay2),
                           weight_decay=weight_decay),
        'SGD': optim.SGD(params=model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    }
    # Choose which Torch Optimizer object to use, based on the passed name
    optimizer = supported_optimizers[optimizer]

    # stiamo dando ad "args.load" due compiti, quello di dirci il path e quello di dirci se caricare vecchi checkpoint
    if load is not None:
        model.load_state_dict(
            torch.load(load, map_location=device)
        )
        logging.info(f'Model loaded from {load}')
    model.to(device=device)

    try:
        train(model=model,
              device=device,
              train_loader=train_loader,
              val_loader=val_loader,
              max_epochs=max_epochs,
              optimizer=optimizer,
              vgg_cfg=vgg_cfg,
              verbose=verbose,
              checkpoint_dir=checkpoint_dir,
              model_path=model_path,
              save_cp=save_cp,
              n_train=n_train,
              step_eval=step_eval,
              n_val=n_val
              )
    except KeyboardInterrupt:
        torch.save(model.state_dict(), config_list['models'][model]['paths']['model'] + os.path.sep + 'INTERRUPTED.pt')
        logging.info('Interrupt saved')
        try:
            sys.exit(0)
        except SystemExit:
            os._exit(0)
# Out:
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/nvidia/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
train_main(dataset='FlickrLogos-32',
     model='LogoDetection',
     optimizer='Adam',
     vgg_cfg='B',
     max_epochs=500, 
     batch_size=16, 
     weight_decay=5e-4,
     learning_rate=4e-5,
     decay1=0.9, 
     decay2=0.999,
     verbose=True,
     batch_norm=True,
     load=None,
     val_split=0.1,
     step_eval=1,
     save_cp=True,
     )
# Out:
# Loading FlickrLogos-32 dataset...
# You have 154560 triplets
# Initializing model...
# train loss: 100%|██████████| 139104/139104 [1:08:40<00:00, 43.99img/s, loss=0.01473]
# train loss: 100%|██████████| 139104/139104 [1:08:51<00:00, 43.99img/s, loss=0.01473]
# Validation round:   2%|▏         | 16/966 [00:12<12:44,  1.24samples/s]
# Validation round:   3%|▎         | 32/966 [00:22<11:34,  1.34samples/s]
# Validation round:   5%|▍         | 48/966 [00:32<10:43,  1.43samples/s]
# Validation round:   7%|▋         | 64/966 [00:40<09:52,  1.52samples/s]
# Validation round:   8%|▊         | 80/966 [00:52<09:57,  1.48samples/s]
# Validation round:  10%|▉         | 96/966 [01:03<09:59,  1.45samples/s]
# Validation round:  12%|█▏        | 112/966 [01:14<09:35,  1.48samples/s]
# Validation round:  13%|█▎        | 128/966 [01:23<09:07,  1.53samples/s]
# Validation round:  15%|█▍        | 144/966 [01:33<08:48,  1.55samples/s]
# Validation round:  17%|█▋        | 160/966 [01:43<08:34,  1.57samples/s]
# Validation round:  18%|█▊        | 176/966 [01:54<08:31,  1.55samples/s]
# Validation round:  20%|█▉        | 192/966 [02:04<08:09,  1.58samples/s]
# Validation round:  22%|██▏       | 208/966 [02:15<08:10,  1.55samples/s]
# Validation round:  23%|██▎       | 224/966 [02:25<08:01,  1.54samples/s]
# Validation round:  25%|██▍       | 240/966 [02:35<07:43,  1.56samples/s]
# Validation round:  27%|██▋       | 256/966 [02:44<07:18,  1.62samples/s]
# Validation round:  28%|██▊       | 272/966 [02:54<07:14,  1.60samples/s]
# Validation round:  30%|██▉       | 288/966 [03:04<07:02,  1.60samples/s]
# Validation round:  31%|███▏      | 304/966 [03:14<06:45,  1.63samples/s]
# Validation round:  33%|███▎      | 320/966 [03:23<06:29,  1.66samples/s]
# Validation round:  35%|███▍      | 336/966 [03:32<06:14,  1.68samples/s]
# Validation round:  36%|███▋      | 352/966 [03:42<06:07,  1.67samples/s]
# Validation round:  38%|███▊      | 368/966 [03:51<05:55,  1.68samples/s]
# Validation round:  40%|███▉      | 384/966 [04:01<05:47,  1.67samples/s]
# Validation round:  41%|████▏     | 400/966 [04:11<05:43,  1.65samples/s]
# Validation round:  43%|████▎     | 416/966 [04:20<05:33,  1.65samples/s]
# Validation round:  45%|████▍     | 432/966 [04:30<05:18,  1.68samples/s]
# Validation round:  46%|████▋     | 448/966 [04:39<05:08,  1.68samples/s]
# Validation round:  48%|████▊     | 464/966 [04:49<05:03,  1.66samples/s]
# Validation round:  50%|████▉     | 480/966 [04:59<04:59,  1.62samples/s]
# Validation round:  51%|█████▏    | 496/966 [05:11<05:04,  1.54samples/s]
# Validation round:  53%|█████▎    | 512/966 [05:21<04:49,  1.57samples/s]
# Validation round:  55%|█████▍    | 528/966 [05:30<04:34,  1.59samples/s]
# Validation round:  56%|█████▋    | 544/966 [05:40<04:19,  1.63samples/s]
# Validation round:  58%|█████▊    | 560/966 [05:50<04:08,  1.63samples/s]
# Validation round:  60%|█████▉    | 576/966 [05:59<03:59,  1.63samples/s]
# Validation round:  61%|██████▏   | 592/966 [06:36<06:59,  1.12s/samples]
# Validation round:  63%|██████▎   | 608/966 [06:46<05:47,  1.03samples/s]
# Validation round:  65%|██████▍   | 624/966 [06:57<04:59,  1.14samples/s]
# Validation round:  66%|██████▋   | 640/966 [07:07<04:21,  1.25samples/s]
# Validation round:  68%|██████▊   | 656/966 [07:17<03:51,  1.34samples/s]
# Validation round:  70%|██████▉   | 672/966 [07:27<03:31,  1.39samples/s]
# Validation round:  71%|███████   | 688/966 [07:37<03:12,  1.44samples/s]
# Validation round:  73%|███████▎  | 704/966 [07:47<02:55,  1.49samples/s]
# Validation round:  75%|███████▍  | 720/966 [07:57<02:40,  1.53samples/s]
# Validation round:  76%|███████▌  | 736/966 [08:06<02:25,  1.58samples/s]
# Validation round:  78%|███████▊  | 752/966 [08:16<02:15,  1.58samples/s]
# Validation round:  80%|███████▉  | 768/966 [08:27<02:06,  1.57samples/s]
# Validation round:  81%|████████  | 784/966 [08:36<01:54,  1.60samples/s]
# Validation round:  83%|████████▎ | 800/966 [08:46<01:42,  1.61samples/s]
# Validation round:  84%|████████▍ | 816/966 [08:56<01:33,  1.61samples/s]
# Validation round:  86%|████████▌ | 832/966 [09:06<01:22,  1.63samples/s]
# Validation round:  88%|████████▊ | 848/966 [09:16<01:14,  1.59samples/s]
# Validation round:  89%|████████▉ | 864/966 [09:27<01:05,  1.55samples/s]
# Validation round:  91%|█████████ | 880/966 [09:37<00:54,  1.59samples/s]
# Validation round:  93%|█████████▎| 896/966 [09:46<00:43,  1.60samples/s]
# Validation round:  94%|█████████▍| 912/966 [09:56<00:32,  1.64samples/s]
# Validation round:  96%|█████████▌| 928/966 [10:05<00:22,  1.65samples/s]
# Validation round:  98%|█████████▊| 944/966 [10:16<00:13,  1.58samples/s]
# Validation round:  99%|█████████▉| 960/966 [10:26<00:03,  1.59samples/s]
# Validation round: 976samples [10:36,  1.60samples/s]
# Validation round: 992samples [10:46,  1.59samples/s]
# Validation round: 1008samples [10:56,  1.59samples/s]
# Validation round: 1024samples [11:06,  1.59samples/s]
# Validation round: 1040samples [11:16,  1.60samples/s]
# Validation round: 1056samples [11:23,  1.77samples/s]
# Validation round: 1072samples [11:30,  1.92samples/s]
# Validation round: 1088samples [11:34,  2.21samples/s]
# Validation round: 1104samples [11:39,  2.46samples/s]
# Validation round: 1120samples [11:44,  2.62samples/s]
# Validation round: 1136samples [11:49,  2.77samples/s]
# Validation round: 1152samples [11:54,  2.93samples/s]
# Validation round: 1168samples [11:59,  2.96samples/s]
# Validation round: 1184samples [12:04,  3.02samples/s]
# Validation round: 1200samples [12:11,  2.88samples/s]
# Validation round: 1216samples [12:15,  3.02samples/s]
# Validation round: 1232samples [12:20,  3.09samples/s]
# Validation round: 1248samples [12:25,  3.17samples/s]
# Validation round: 1264samples [12:30,  3.10samples/s]
# Validation round: 1280samples [12:35,  3.17samples/s]
# Validation round: 1296samples [12:40,  3.22samples/s]
# Validation round: 1312samples [12:45,  3.26samples/s]
# Validation round: 1328samples [12:50,  3.29samples/s]
# Validation round: 1344samples [12:55,  3.22samples/s]
# Validation round: 1360samples [13:00,  3.24samples/s]
# Validation round: 1376samples [13:04,  3.28samples/s]
# Validation round: 1392samples [13:09,  3.27samples/s]
# Validation round: 1408samples [13:14,  3.28samples/s]
# Validation round: 1424samples [13:19,  3.33samples/s]
# Validation round: 1440samples [13:23,  3.35samples/s]
# Validation round: 1456samples [13:28,  3.30samples/s]
# Validation round: 1472samples [13:34,  3.15samples/s]
# Validation round: 1488samples [13:39,  3.13samples/s]
# Validation round: 1504samples [13:44,  3.14samples/s]
# Validation round: 1520samples [13:49,  3.18samples/s]
# Validation round: 1536samples [13:54,  3.25samples/s]
# Validation round: 1552samples [13:59,  3.25samples/s]
# Validation round: 1568samples [14:04,  3.25samples/s]
# Validation round: 1584samples [14:09,  3.25samples/s]
# Validation round: 1600samples [14:14,  3.19samples/s]
# Validation round: 1616samples [14:19,  3.21samples/s]
# Validation round: 1632samples [14:23,  3.29samples/s]
# Validation round: 1648samples [14:29,  3.09samples/s]
# Validation round: 1664samples [14:34,  3.16samples/s]
# Validation round: 1680samples [14:39,  3.22samples/s]
# Validation round: 1696samples [14:44,  3.27samples/s]
# Validation round: 1712samples [14:50,  2.98samples/s]
# Validation round: 1728samples [14:56,  2.93samples/s]
# Validation round: 1744samples [15:00,  3.07samples/s]
# Validation round: 1760samples [15:06,  2.93samples/s]
# Validation round: 1776samples [15:13,  2.75samples/s]
# Validation round: 1792samples [15:18,  2.87samples/s]
# Validation round: 1808samples [15:24,  2.88samples/s]
# Validation round: 1824samples [15:28,  2.99samples/s]
# Validation round: 1840samples [15:33,  3.08samples/s]
# Validation round: 1856samples [15:38,  3.15samples/s]
# Validation round: 1872samples [15:43,  3.22samples/s]
# Validation round: 1888samples [15:48,  3.26samples/s]
# Validation round: 1904samples [15:52,  3.30samples/s]
# Validation round: 1920samples [15:58,  3.13samples/s]
# Validation round: 1936samples [16:03,  3.21samples/s]
# Validation round: 1952samples [16:07,  3.28samples/s]
# Validation round: 1968samples [16:12,  3.27samples/s]
# Validation round: 1984samples [16:17,  3.25samples/s]
# Validation round: 2000samples [16:22,  3.30samples/s]
# Validation round: 2016samples [16:27,  3.33samples/s]
# Validation round: 2032samples [16:32,  3.28samples/s]
# Validation round: 2048samples [16:36,  3.32samples/s]
# Validation round: 2064samples [16:41,  3.34samples/s]
# Validation round: 2080samples [16:46,  3.30samples/s]
# Validation round: 2096samples [16:51,  3.33samples/s]
# Validation round: 2112samples [16:55,  3.37samples/s]
# Validation round: 2128samples [17:01,  3.26samples/s]
# Validation round: 2144samples [17:05,  3.32samples/s]
# Validation round: 2160samples [17:11,  3.21samples/s]
# Validation round: 2176samples [17:16,  3.21samples/s]
# Validation round: 2192samples [17:22,  2.97samples/s]
# Validation round: 2208samples [17:27,  2.94samples/s]
# Validation round: 2224samples [17:32,  3.04samples/s]
# Validation round: 2240samples [17:37,  3.07samples/s]
# Validation round: 2256samples [17:43,  3.08samples/s]
# Validation round: 2272samples [17:48,  3.12samples/s]
# Validation round: 2288samples [17:52,  3.22samples/s]
# Validation round: 2304samples [17:57,  3.24samples/s]
# Validation round: 2320samples [18:02,  3.25samples/s]
# Validation round: 2336samples [18:08,  3.03samples/s]
# Validation round: 2352samples [18:28,  1.64samples/s]
# Validation round: 2368samples [18:35,  1.81samples/s]
# Validation round: 2384samples [18:40,  2.10samples/s]
# Validation round: 2400samples [18:44,  2.36samples/s]
# Validation round: 2416samples [18:49,  2.56samples/s]
# Validation round: 2432samples [18:54,  2.77samples/s]
# Validation round: 2448samples [18:59,  2.86samples/s]
# Validation round: 2464samples [19:05,  2.91samples/s]
# Validation round: 2480samples [19:09,  3.03samples/s]
# Validation round: 2496samples [19:14,  3.15samples/s]
# Validation round: 2512samples [19:19,  3.22samples/s]
# Validation round: 2528samples [19:23,  3.24samples/s]
# Validation round: 2544samples [19:28,  3.30samples/s]
# Validation round: 2560samples [19:34,  3.16samples/s]
# Validation round: 2576samples [19:39,  3.15samples/s]
# Validation round: 2592samples [19:44,  3.13samples/s]
# Validation round: 2608samples [19:49,  3.06samples/s]
# Validation round: 2624samples [19:55,  3.07samples/s]
# Validation round: 2640samples [19:59,  3.16samples/s]
# Validation round: 2656samples [20:05,  2.99samples/s]
# Validation round: 2672samples [20:10,  3.05samples/s]
# Validation round: 2688samples [20:15,  3.09samples/s]
# Validation round: 2704samples [20:21,  3.03samples/s]
# Validation round: 2720samples [20:26,  3.14samples/s]
# Validation round: 2736samples [20:30,  3.24samples/s]
# Validation round: 2752samples [20:36,  3.05samples/s]
# Validation round: 2768samples [20:41,  3.12samples/s]
# Validation round: 2784samples [20:46,  3.22samples/s]
# Validation round: 2800samples [20:51,  3.12samples/s]
# Validation round: 2816samples [20:56,  3.14samples/s]
# Validation round: 2832samples [21:01,  3.13samples/s]
# Validation round: 2848samples [21:06,  3.17samples/s]
# Validation round: 2864samples [21:11,  3.20samples/s]
# Validation round: 2880samples [21:16,  3.25samples/s]
# Validation round: 2896samples [21:21,  3.18samples/s]
# Validation round: 2912samples [21:26,  3.26samples/s]
# Validation round: 2928samples [21:30,  3.32samples/s]
# Validation round: 2944samples [21:35,  3.35samples/s]
# Validation round: 2960samples [21:40,  3.29samples/s]
# Validation round: 2976samples [21:47,  2.98samples/s]
# Validation round: 2992samples [21:52,  3.04samples/s]
# Validation round: 3008samples [21:56,  3.11samples/s]
# Validation round: 3024samples [22:02,  3.01samples/s]
# Validation round: 3040samples [22:08,  2.90samples/s]
# Validation round: 3056samples [22:13,  3.07samples/s]
# Validation round: 3072samples [22:18,  3.08samples/s]
# Validation round: 3088samples [22:23,  3.14samples/s]
# Validation round: 3104samples [22:27,  3.21samples/s]
# Validation round: 3120samples [22:32,  3.26samples/s]
# Validation round: 3136samples [22:37,  3.23samples/s]
# Validation round: 3152samples [22:42,  3.19samples/s]
# Validation round: 3168samples [22:47,  3.22samples/s]
# Validation round: 3184samples [22:52,  3.28samples/s]
# Validation round: 3200samples [22:57,  3.21samples/s]
# Validation round: 3216samples [23:02,  3.26samples/s]
# Validation round: 3232samples [23:07,  3.30samples/s]
# Validation round: 3248samples [23:13,  3.01samples/s]
# Validation round: 3264samples [23:18,  3.07samples/s]
# Validation round: 3280samples [23:23,  3.12samples/s]
# Validation round: 3296samples [23:28,  3.18samples/s]
# Validation round: 3312samples [23:33,  3.20samples/s]
# Validation round: 3328samples [23:37,  3.26samples/s]
# Validation round: 3344samples [23:42,  3.21samples/s]
# Validation round: 3360samples [24:03,  1.63samples/s]
# Validation round: 3376samples [24:08,  1.93samples/s]
# Validation round: 3392samples [24:13,  2.20samples/s]
# Validation round: 3408samples [24:19,  2.37samples/s]
# Validation round: 3424samples [24:23,  2.60samples/s]
# Validation round: 3440samples [24:28,  2.78samples/s]
# Validation round: 3456samples [24:33,  2.92samples/s]
# Validation round: 3472samples [24:38,  3.05samples/s]
# Validation round: 3488samples [24:44,  2.83samples/s]
# Validation round: 3504samples [24:50,  2.91samples/s]
# Validation round: 3520samples [24:54,  3.02samples/s]
# Validation round: 3536samples [24:59,  3.07samples/s]
# Validation round: 3552samples [25:04,  3.12samples/s]
# Validation round: 3568samples [25:09,  3.19samples/s]
# Validation round: 3584samples [25:14,  3.26samples/s]
# Validation round: 3600samples [25:19,  3.18samples/s]
# Validation round: 3616samples [25:24,  3.19samples/s]
# Validation round: 3632samples [25:29,  3.20samples/s]
# Validation round: 3648samples [25:34,  3.24samples/s]
# Validation round: 3664samples [25:38,  3.30samples/s]
# Validation round: 3680samples [25:43,  3.33samples/s]
# Validation round: 3696samples [25:50,  3.00samples/s]
# Validation round: 3712samples [25:55,  3.06samples/s]
# Validation round: 3728samples [25:59,  3.18samples/s]
# Validation round: 3744samples [26:04,  3.24samples/s]
# Validation round: 3760samples [26:10,  2.98samples/s]
# Validation round: 3776samples [26:17,  2.79samples/s]
# Validation round: 3792samples [26:22,  2.95samples/s]
# Validation round: 3808samples [26:27,  2.96samples/s]
# Validation round: 3824samples [26:32,  3.00samples/s]
# Validation round: 3840samples [26:37,  3.06samples/s]
# Validation round: 3856samples [26:42,  3.16samples/s]
# Validation round: 3872samples [26:46,  3.25samples/s]
# Validation round: 3888samples [26:52,  3.20samples/s]
# Validation round: 3904samples [26:56,  3.25samples/s]
# Validation round: 3920samples [27:01,  3.30samples/s]
# Validation round: 3936samples [27:06,  3.18samples/s]
# Validation round: 3952samples [27:12,  3.15samples/s]
# Validation round: 3968samples [27:16,  3.20samples/s]
# Validation round: 3984samples [27:22,  3.11samples/s]
# Validation round: 4000samples [27:27,  3.08samples/s]
# Validation round: 4016samples [27:34,  2.83samples/s]
# Validation round: 4032samples [27:39,  2.97samples/s]
# Validation round: 4048samples [27:44,  3.00samples/s]
# Validation round: 4064samples [27:49,  3.11samples/s]
# Validation round: 4080samples [27:53,  3.18samples/s]
# Validation round: 4096samples [27:58,  3.19samples/s]
# Validation round: 4112samples [28:05,  2.92samples/s]
# Validation round: 4128samples [28:10,  2.96samples/s]
# Validation round: 4144samples [28:15,  3.02samples/s]
# Validation round: 4160samples [28:20,  3.09samples/s]
# Validation round: 4176samples [28:25,  3.06samples/s]
# Validation round: 4192samples [28:30,  3.15samples/s]
# Validation round: 4208samples [28:39,  2.54samples/s]
# Validation round: 4224samples [28:44,  2.77samples/s]
# Validation round: 4240samples [28:49,  2.91samples/s]
# Validation round: 4256samples [28:53,  3.03samples/s]
# Validation round: 4272samples [28:58,  3.16samples/s]
# Validation round: 4288samples [29:03,  3.24samples/s]
# Validation round: 4304samples [29:07,  3.29samples/s]
# Validation round: 4320samples [29:13,  3.23samples/s]
# Validation round: 4336samples [29:17,  3.27samples/s]
# Validation round: 4352samples [29:22,  3.31samples/s]
# Validation round: 4368samples [29:27,  3.32samples/s]
# Validation round: 4384samples [29:32,  3.33samples/s]
# Validation round: 4400samples [29:37,  3.12samples/s]
# Validation round: 4416samples [29:42,  3.15samples/s]
# Validation round: 4432samples [29:47,  3.23samples/s]
# Validation round: 4448samples [29:53,  3.02samples/s]
# Validation round: 4464samples [29:58,  3.14samples/s]
# Validation round: 4480samples [30:02,  3.23samples/s]
# Validation round: 4496samples [30:07,  3.25samples/s]
# Validation round: 4512samples [30:14,  2.96samples/s]
# Validation round: 4528samples [30:19,  3.06samples/s]
# Validation round: 4544samples [30:24,  3.12samples/s]
# Validation round: 4560samples [30:28,  3.25samples/s]
# Validation round: 4576samples [30:34,  3.13samples/s]
# Validation round: 4592samples [30:39,  3.00samples/s]
# Validation round: 4608samples [30:45,  2.98samples/s]
# Validation round: 4624samples [30:50,  2.97samples/s]
# Validation round: 4640samples [30:56,  2.94samples/s]
# Validation round: 4656samples [31:01,  3.06samples/s]
# Validation round: 4672samples [31:05,  3.16samples/s]
# Validation round: 4688samples [31:10,  3.20samples/s]
# Validation round: 4704samples [31:15,  3.19samples/s]
# Validation round: 4720samples [31:21,  3.02samples/s]
# Validation round: 4736samples [31:27,  2.91samples/s]
# Validation round: 4752samples [31:32,  3.03samples/s]
# Validation round: 4768samples [31:36,  3.15samples/s]
# Validation round: 4784samples [31:43,  2.83samples/s]
# Validation round: 4800samples [31:48,  3.02samples/s]
# Validation round: 4816samples [31:53,  3.12samples/s]
# Validation round: 4832samples [31:57,  3.19samples/s]
# Validation round: 4848samples [32:04,  2.91samples/s]
# Validation round: 4864samples [32:09,  3.02samples/s]
# Validation round: 4880samples [32:13,  3.14samples/s]
# Validation round: 4896samples [32:19,  3.01samples/s]
# Validation round: 4912samples [32:25,  2.92samples/s]
# Validation round: 4928samples [32:30,  3.06samples/s]
# Validation round: 4944samples [32:35,  3.07samples/s]
# Validation round: 4960samples [32:40,  3.16samples/s]
# Validation round: 4976samples [32:45,  3.16samples/s]
# Validation round: 4992samples [32:52,  2.76samples/s]
# Validation round: 5008samples [32:57,  2.88samples/s]
# Validation round: 5024samples [33:02,  3.01samples/s]
# Validation round: 5040samples [33:08,  2.86samples/s]
# Validation round: 5056samples [33:13,  3.01samples/s]
# Validation round: 5072samples [33:18,  3.10samples/s]
# Validation round: 5088samples [33:22,  3.20samples/s]
# Validation round: 5104samples [33:27,  3.24samples/s]
# Validation round: 5120samples [33:32,  3.25samples/s]
# Validation round: 5136samples [33:37,  3.21samples/s]
# Validation round: 5152samples [33:42,  3.26samples/s]
# Validation round: 5168samples [33:47,  3.27samples/s]
# Validation round: 5184samples [33:52,  3.20samples/s]
# Validation round: 5200samples [33:57,  3.21samples/s]
# Validation round: 5216samples [34:02,  3.12samples/s]
# Validation round: 5232samples [34:07,  3.19samples/s]
# Validation round: 5248samples [34:14,  2.93samples/s]
# Validation round: 5264samples [34:19,  2.96samples/s]
# Validation round: 5280samples [34:24,  3.09samples/s]
# Validation round: 5296samples [34:28,  3.17samples/s]
# Validation round: 5312samples [34:33,  3.22samples/s]
# Validation round: 5328samples [34:38,  3.17samples/s]
# Validation round: 5344samples [34:44,  2.97samples/s]
# Validation round: 5360samples [35:01,  1.85samples/s]
# Validation round: 5376samples [35:05,  2.15samples/s]
# Validation round: 5392samples [35:10,  2.38samples/s]
# Validation round: 5408samples [35:16,  2.54samples/s]
# Validation round: 5424samples [35:21,  2.74samples/s]
# Validation round: 5440samples [35:25,  2.91samples/s]
# Validation round: 5456samples [35:30,  3.03samples/s]
# Validation round: 5472samples [35:35,  3.08samples/s]
# Validation round: 5488samples [35:40,  3.07samples/s]
# Validation round: 5504samples [35:46,  2.95samples/s]
# Validation round: 5520samples [35:51,  3.01samples/s]
# Validation round: 5536samples [35:56,  3.08samples/s]
# Validation round: 5552samples [36:01,  3.20samples/s]
# Validation round: 5568samples [36:06,  3.17samples/s]
# Validation round: 5584samples [36:11,  3.20samples/s]
# Validation round: 5600samples [36:16,  3.16samples/s]
# Validation round: 5616samples [36:21,  3.14samples/s]
# Validation round: 5632samples [36:26,  3.15samples/s]
# Validation round: 5648samples [36:31,  3.24samples/s]
# Validation round: 5664samples [36:35,  3.30samples/s]
# Validation round: 5680samples [36:40,  3.39samples/s]
# Validation round: 5696samples [36:47,  2.88samples/s]
# Validation round: 5712samples [36:52,  2.99samples/s]
# Validation round: 5728samples [36:57,  3.07samples/s]
# Validation round: 5744samples [37:02,  3.10samples/s]
# Validation round: 5760samples [37:09,  2.75samples/s]
# Validation round: 5776samples [37:14,  2.91samples/s]
# Validation round: 5792samples [37:19,  3.01samples/s]
# Validation round: 5808samples [37:24,  3.09samples/s]
# Validation round: 5824samples [37:30,  2.99samples/s]
# Validation round: 5840samples [37:34,  3.09samples/s]
# Validation round: 5856samples [37:40,  2.97samples/s]
# Validation round: 5872samples [37:45,  3.06samples/s]
# Validation round: 5888samples [37:50,  3.16samples/s]
# Validation round: 5904samples [37:55,  3.21samples/s]
# Validation round: 5920samples [37:59,  3.26samples/s]
# Validation round: 5936samples [38:04,  3.25samples/s]
# Validation round: 5952samples [38:09,  3.27samples/s]
# Validation round: 5968samples [38:14,  3.32samples/s]
# Validation round: 5984samples [38:30,  1.96samples/s]
# Validation round: 6000samples [38:35,  2.16samples/s]
# Validation round: 6016samples [38:41,  2.34samples/s]
# Validation round: 6032samples [38:46,  2.58samples/s]
# Validation round: 6048samples [38:50,  2.81samples/s]
# Validation round: 6064samples [39:12,  1.52samples/s]
# Validation round: 6080samples [39:22,  1.56samples/s]
# Validation round: 6096samples [39:31,  1.58samples/s]
# Validation round: 6112samples [39:38,  1.77samples/s]
# Validation round: 6128samples [39:43,  2.03samples/s]
# Validation round: 6144samples [39:53,  1.90samples/s]
# Validation round: 6160samples [40:03,  1.80samples/s]
# Validation round: 6176samples [40:12,  1.77samples/s]
# Validation round: 6192samples [40:22,  1.74samples/s]
# Validation round: 6208samples [40:31,  1.72samples/s]
# Validation round: 6224samples [40:42,  1.65samples/s]
# Validation round: 6240samples [40:52,  1.65samples/s]
# Validation round: 6256samples [41:02,  1.62samples/s]
# Validation round: 6272samples [41:15,  1.48samples/s]
# Validation round: 6288samples [41:24,  1.53samples/s]
# Validation round: 6304samples [41:34,  1.59samples/s]
# Validation round: 6320samples [41:43,  1.60samples/s]
# Validation round: 6336samples [41:53,  1.64samples/s]
# Validation round: 6352samples [42:02,  1.66samples/s]
# Validation round: 6368samples [42:13,  1.58samples/s]
# Validation round: 6384samples [42:22,  1.62samples/s]
# Validation round: 6400samples [42:32,  1.66samples/s]
# Validation round: 6416samples [42:43,  1.55samples/s]
# Validation round: 6432samples [42:53,  1.60samples/s]
# Validation round: 6448samples [43:02,  1.63samples/s]
# Validation round: 6464samples [43:13,  1.58samples/s]
# Validation round: 6480samples [43:24,  1.53samples/s]
# Validation round: 6496samples [43:36,  1.47samples/s]
# Validation round: 6512samples [43:45,  1.54samples/s]
# Validation round: 6528samples [43:56,  1.54samples/s]
# Validation round: 6544samples [44:06,  1.54samples/s]
# Validation round: 6560samples [44:17,  1.53samples/s]
# Validation round: 6576samples [44:28,  1.51samples/s]
# Validation round: 6592samples [44:37,  1.55samples/s]
# Validation round: 6608samples [44:48,  1.52samples/s]
# Validation round: 6624samples [44:59,  1.53samples/s]
# Validation round: 6640samples [45:09,  1.54samples/s]
# Validation round: 6656samples [45:19,  1.55samples/s]
# Validation round: 6672samples [45:30,  1.54samples/s]
# Validation round: 6688samples [45:39,  1.57samples/s]
# Validation round: 6704samples [45:49,  1.62samples/s]
# Validation round: 6720samples [46:01,  1.52samples/s]
# Validation round: 6736samples [46:10,  1.57samples/s]
# Validation round: 6752samples [46:21,  1.54samples/s]
# Validation round: 6768samples [46:32,  1.51samples/s]
# Validation round: 6784samples [46:41,  1.56samples/s]
# Validation round: 6800samples [46:51,  1.61samples/s]
# Validation round: 6816samples [47:00,  1.62samples/s]
# Validation round: 6832samples [47:10,  1.64samples/s]
# Validation round: 6848samples [47:19,  1.65samples/s]
# Validation round: 6864samples [47:29,  1.64samples/s]
# Validation round: 6880samples [47:39,  1.62samples/s]
# Validation round: 6896samples [47:48,  1.66samples/s]
# Validation round: 6912samples [47:58,  1.65samples/s]
# Validation round: 6928samples [48:08,  1.65samples/s]
# Validation round: 6944samples [48:17,  1.66samples/s]
# Validation round: 6960samples [48:29,  1.58samples/s]
# Validation round: 6976samples [48:39,  1.58samples/s]
# Validation round: 6992samples [48:49,  1.57samples/s]
# Validation round: 7008samples [48:59,  1.57samples/s]
# Validation round: 7024samples [49:09,  1.58samples/s]
# Validation round: 7040samples [49:20,  1.54samples/s]
# Validation round: 7056samples [49:30,  1.59samples/s]
# Validation round: 7072samples [49:39,  1.62samples/s]
# Validation round: 7088samples [49:49,  1.63samples/s]
# Validation round: 7104samples [49:59,  1.60samples/s]
# Validation round: 7120samples [50:10,  1.58samples/s]
# Validation round: 7136samples [50:22,  1.47samples/s]
# Validation round: 7152samples [50:33,  1.49samples/s]
# Validation round: 7168samples [50:43,  1.51samples/s]
# Validation round: 7184samples [50:52,  1.56samples/s]
# Validation round: 7200samples [51:02,  1.60samples/s]
# Validation round: 7216samples [51:12,  1.60samples/s]
# Validation round: 7232samples [51:21,  1.62samples/s]
# Validation round: 7248samples [51:31,  1.62samples/s]
# Validation round: 7264samples [51:41,  1.62samples/s]
# Validation round: 7280samples [51:51,  1.62samples/s]
# Validation round: 7296samples [52:01,  1.63samples/s]
# Validation round: 7312samples [52:13,  1.49samples/s]
# Validation round: 7328samples [52:24,  1.52samples/s]
# Validation round: 7344samples [52:33,  1.56samples/s]
# Validation round: 7360samples [52:44,  1.55samples/s]
# Validation round: 7376samples [52:56,  1.45samples/s]
# Validation round: 7392samples [53:06,  1.52samples/s]
# Validation round: 7408samples [53:15,  1.56samples/s]
# Validation round: 7424samples [53:26,  1.54samples/s]
# Validation round: 7440samples [53:37,  1.52samples/s]
# Validation round: 7456samples [53:47,  1.53samples/s]
# Validation round: 7472samples [53:57,  1.55samples/s]
# Validation round: 7488samples [54:08,  1.54samples/s]
# Validation round: 7504samples [54:17,  1.58samples/s]
# Validation round: 7520samples [54:27,  1.59samples/s]
# Validation round: 7536samples [54:39,  1.52samples/s]
# Validation round: 7552samples [54:49,  1.55samples/s]
# Validation round: 7568samples [55:26,  1.15s/samples]
# Validation round: 7584samples [55:36,  1.01samples/s]
# Validation round: 7600samples [55:46,  1.13samples/s]
# Validation round: 7616samples [55:56,  1.23samples/s]
# Validation round: 7632samples [56:05,  1.35samples/s]
# Validation round: 7648samples [56:22,  1.21samples/s]
# Validation round: 7664samples [56:32,  1.31samples/s]
# Validation round: 7680samples [56:44,  1.32samples/s]
# Validation round: 7696samples [56:54,  1.39samples/s]
# Validation round: 7712samples [57:03,  1.47samples/s]
# Validation round: 7728samples [57:13,  1.52samples/s]
# Validation round: 7744samples [57:23,  1.52samples/s]
# Validation round: 7760samples [57:33,  1.54samples/s]
# Validation round: 7776samples [57:43,  1.59samples/s]
# Validation round: 7792samples [57:53,  1.59samples/s]
# Validation round: 7808samples [58:02,  1.62samples/s]
# Validation round: 7824samples [58:12,  1.63samples/s]
# Validation round: 7840samples [58:22,  1.63samples/s]
# Validation round: 7856samples [58:33,  1.58samples/s]
# Validation round: 7872samples [58:43,  1.57samples/s]
# Validation round: 7888samples [58:53,  1.60samples/s]
# Validation round: 7904samples [58:59,  1.80samples/s]
# Validation round: 7920samples [59:04,  2.06samples/s]
# Validation round: 7936samples [59:09,  2.31samples/s]
# Validation round: 7952samples [59:14,  2.56samples/s]
# Validation round: 7968samples [59:20,  2.59samples/s]
# Validation round: 7984samples [59:26,  2.60samples/s]
# Validation round: 8000samples [59:30,  2.80samples/s]
# Validation round: 8016samples [59:35,  2.95samples/s]
# Validation round: 8032samples [59:40,  3.10samples/s]
# Validation round: 8048samples [59:44,  3.18samples/s]
# Validation round: 8064samples [59:50,  3.02samples/s]
# Validation round: 8080samples [59:55,  3.16samples/s]
# Validation round: 8096samples [1:00:00,  3.22samples/s]
# Validation round: 8112samples [1:00:05,  3.18samples/s]
# Validation round: 8128samples [1:00:10,  3.24samples/s]
# Validation round: 8144samples [1:00:15,  3.15samples/s]
# Validation round: 8160samples [1:00:20,  3.15samples/s]
# Validation round: 8176samples [1:00:26,  2.99samples/s]
# Validation round: 8192samples [1:00:31,  3.08samples/s]
# Validation round: 8208samples [1:00:36,  3.08samples/s]
# Validation round: 8224samples [1:00:41,  3.16samples/s]
# Validation round: 8240samples [1:00:45,  3.24samples/s]
# Validation round: 8256samples [1:00:50,  3.31samples/s]
# Validation round: 8272samples [1:00:55,  3.33samples/s]
# Validation round: 8288samples [1:01:00,  3.34samples/s]
# Validation round: 8304samples [1:01:05,  3.23samples/s]
# Validation round: 8320samples [1:01:11,  3.09samples/s]
# Validation round: 8336samples [1:01:15,  3.17samples/s]
# Validation round: 8352samples [1:01:20,  3.25samples/s]
# Validation round: 8368samples [1:01:26,  3.05samples/s]
# Validation round: 8384samples [1:01:31,  3.11samples/s]
# Validation round: 8400samples [1:01:36,  3.19samples/s]
# Validation round: 8416samples [1:01:41,  3.18samples/s]
# Validation round: 8432samples [1:01:46,  3.18samples/s]
# Validation round: 8448samples [1:01:50,  3.22samples/s]
# Validation round: 8464samples [1:01:55,  3.28samples/s]
# Validation round: 8480samples [1:02:00,  3.25samples/s]
# Validation round: 8496samples [1:02:05,  3.27samples/s]
# Validation round: 8512samples [1:02:10,  3.30samples/s]
# Validation round: 8528samples [1:02:14,  3.32samples/s]
# Validation round: 8544samples [1:02:21,  3.01samples/s]
# Validation round: 8560samples [1:02:26,  3.10samples/s]
# Validation round: 8576samples [1:02:31,  3.10samples/s]
# Validation round: 8592samples [1:02:36,  3.18samples/s]
# Validation round: 8608samples [1:02:41,  3.16samples/s]
# Validation round: 8624samples [1:02:45,  3.27samples/s]
# Validation round: 8640samples [1:02:50,  3.28samples/s]
# Validation round: 8656samples [1:02:55,  3.32samples/s]
# Validation round: 8672samples [1:02:59,  3.36samples/s]
# Validation round: 8688samples [1:03:04,  3.34samples/s]
# Validation round: 8704samples [1:03:09,  3.32samples/s]
# Validation round: 8720samples [1:03:14,  3.25samples/s]
# Validation round: 8736samples [1:03:19,  3.25samples/s]
# Validation round: 8752samples [1:03:24,  3.22samples/s]
# Validation round: 8768samples [1:03:29,  3.21samples/s]
# Validation round: 8784samples [1:03:34,  3.24samples/s]
# Validation round: 8800samples [1:03:40,  3.03samples/s]
# Validation round: 8816samples [1:03:45,  3.15samples/s]
# Validation round: 8832samples [1:03:50,  3.09samples/s]
# Validation round: 8848samples [1:03:55,  3.17samples/s]
# Validation round: 8864samples [1:04:00,  3.24samples/s]
# Validation round: 8880samples [1:04:05,  3.23samples/s]
# Validation round: 8896samples [1:04:09,  3.31samples/s]
# Validation round: 8912samples [1:04:14,  3.33samples/s]
# Validation round: 8928samples [1:04:19,  3.21samples/s]
# Validation round: 8944samples [1:04:24,  3.26samples/s]
# Validation round: 8960samples [1:04:29,  3.30samples/s]
# Validation round: 8976samples [1:04:34,  3.29samples/s]
# Validation round: 8992samples [1:04:38,  3.32samples/s]
# Validation round: 9008samples [1:04:43,  3.33samples/s]
# Validation round: 9024samples [1:04:48,  3.34samples/s]
# Validation round: 9040samples [1:04:54,  3.05samples/s]
# Validation round: 9056samples [1:04:59,  3.13samples/s]
# Validation round: 9072samples [1:05:06,  2.81samples/s]
# Validation round: 9088samples [1:05:11,  2.87samples/s]
# Validation round: 9104samples [1:05:16,  2.99samples/s]
# Validation round: 9120samples [1:05:23,  2.84samples/s]
# Validation round: 9136samples [1:05:27,  3.01samples/s]
# Validation round: 9152samples [1:05:32,  3.08samples/s]
# Validation round: 9168samples [1:05:37,  3.11samples/s]
# Validation round: 9184samples [1:05:43,  2.99samples/s]
# Validation round: 9200samples [1:05:48,  3.11samples/s]
# Validation round: 9216samples [1:05:52,  3.20samples/s]
# Validation round: 9232samples [1:05:57,  3.25samples/s]
# Validation round: 9248samples [1:06:03,  3.00samples/s]
# Validation round: 9264samples [1:06:08,  3.10samples/s]
# Validation round: 9280samples [1:06:13,  3.06samples/s]
# Validation round: 9296samples [1:06:18,  3.17samples/s]
# Validation round: 9312samples [1:06:23,  3.24samples/s]
# Validation round: 9328samples [1:06:28,  3.26samples/s]
# Validation round: 9344samples [1:06:33,  3.10samples/s]
# Validation round: 9360samples [1:06:38,  3.19samples/s]
# Validation round: 9376samples [1:06:43,  3.23samples/s]
# Validation round: 9392samples [1:06:48,  3.27samples/s]
# Validation round: 9408samples [1:06:52,  3.33samples/s]
# Validation round: 9424samples [1:06:59,  2.95samples/s]
# Validation round: 9440samples [1:07:04,  3.02samples/s]
# Validation round: 9456samples [1:07:09,  3.09samples/s]
# Validation round: 9472samples [1:07:15,  2.92samples/s]
# Validation round: 9488samples [1:07:20,  2.99samples/s]
# Validation round: 9504samples [1:07:25,  3.10samples/s]
# Validation round: 9520samples [1:07:30,  3.17samples/s]
# Validation round: 9536samples [1:07:34,  3.24samples/s]
# Validation round: 9552samples [1:07:40,  3.09samples/s]
# Validation round: 9568samples [1:07:45,  3.14samples/s]
# Validation round: 9584samples [1:07:50,  3.16samples/s]
# Validation round: 9600samples [1:07:55,  3.22samples/s]
# Validation round: 9616samples [1:08:04,  2.57samples/s]
# Validation round: 9632samples [1:08:09,  2.75samples/s]
# Validation round: 9648samples [1:08:13,  2.91samples/s]
# Validation round: 9664samples [1:08:19,  2.98samples/s]
# Validation round: 9680samples [1:08:23,  3.09samples/s]
# Validation round: 9696samples [1:08:28,  3.15samples/s]
# Validation round: 9712samples [1:08:33,  3.21samples/s]
# Validation round: 9728samples [1:08:38,  3.26samples/s]
# Validation round: 9744samples [1:08:42,  3.30samples/s]
# Validation round: 9760samples [1:08:47,  3.34samples/s]
# Validation round: 9776samples [1:08:52,  3.37samples/s]
# Validation round: 9792samples [1:08:56,  3.36samples/s]
# Validation round: 9808samples [1:09:02,  3.18samples/s]
# Validation round: 9824samples [1:09:07,  3.22samples/s]
# Validation round: 9840samples [1:09:12,  3.28samples/s]
# Validation round: 9856samples [1:09:17,  3.21samples/s]
# Validation round: 9872samples [1:09:22,  3.26samples/s]
# Validation round: 9888samples [1:09:27,  3.14samples/s]
# Validation round: 9904samples [1:09:32,  3.18samples/s]
# Validation round: 9920samples [1:09:37,  3.27samples/s]
# Validation round: 9936samples [1:09:41,  3.30samples/s]
# Validation round: 9952samples [1:09:46,  3.31samples/s]
# Validation round: 9968samples [1:09:51,  3.24samples/s]
# Validation round: 9984samples [1:09:56,  3.19samples/s]
# Validation round: 10000samples [1:10:01,  3.23samples/s]
# Validation round: 10016samples [1:10:06,  3.25samples/s]
# Validation round: 10032samples [1:10:11,  3.25samples/s]
# Validation round: 10048samples [1:10:16,  3.24samples/s]
# Validation round: 10064samples [1:10:21,  3.30samples/s]
# Validation round: 10080samples [1:10:26,  3.23samples/s]
# Validation round: 10096samples [1:10:31,  3.26samples/s]
# Validation round: 10112samples [1:10:36,  3.19samples/s]
# Validation round: 10128samples [1:10:41,  3.15samples/s]
# Validation round: 10144samples [1:10:47,  3.10samples/s]
# Validation round: 10160samples [1:10:52,  3.06samples/s]
# Validation round: 10176samples [1:10:57,  3.07samples/s]
# Validation round: 10192samples [1:11:02,  3.11samples/s]
# Validation round: 10208samples [1:11:07,  3.21samples/s]
# Validation round: 10224samples [1:11:13,  2.95samples/s]
# Validation round: 10240samples [1:11:18,  2.96samples/s]
# Validation round: 10256samples [1:11:23,  3.08samples/s]
# Validation round: 10272samples [1:11:28,  3.10samples/s]
# Validation round: 10288samples [1:11:45,  1.88samples/s]
# Validation round: 10304samples [1:11:49,  2.18samples/s]
# Validation round: 10320samples [1:11:55,  2.32samples/s]
# Validation round: 10336samples [1:12:00,  2.56samples/s]
# Validation round: 10352samples [1:12:04,  2.79samples/s]
# Validation round: 10368samples [1:12:09,  2.91samples/s]
# Validation round: 10384samples [1:12:16,  2.79samples/s]
# Validation round: 10400samples [1:12:22,  2.72samples/s]
# Validation round: 10416samples [1:12:26,  2.89samples/s]
# Validation round: 10432samples [1:12:31,  3.06samples/s]
# Validation round: 10448samples [1:12:36,  3.14samples/s]
# Validation round: 10464samples [1:12:42,  2.93samples/s]
# Validation round: 10480samples [1:12:47,  3.08samples/s]
# Validation round: 10496samples [1:12:52,  3.10samples/s]
# Validation round: 10512samples [1:12:58,  2.94samples/s]
# Validation round: 10528samples [1:13:03,  3.03samples/s]
# Validation round: 10544samples [1:13:07,  3.13samples/s]
# Validation round: 10560samples [1:13:12,  3.18samples/s]
# Validation round: 10576samples [1:13:17,  3.22samples/s]
# Validation round: 10592samples [1:13:22,  3.21samples/s]
# Validation round: 10608samples [1:13:27,  3.19samples/s]
# Validation round: 10624samples [1:13:32,  3.16samples/s]
# Validation round: 10640samples [1:13:37,  3.25samples/s]
# Validation round: 10656samples [1:13:43,  3.11samples/s]
# Validation round: 10672samples [1:13:48,  3.07samples/s]
# Validation round: 10688samples [1:13:53,  3.09samples/s]
# Validation round: 10704samples [1:13:58,  3.15samples/s]
# Validation round: 10720samples [1:14:03,  3.10samples/s]
# Validation round: 10736samples [1:14:08,  3.20samples/s]
# Validation round: 10752samples [1:14:14,  2.99samples/s]
# Validation round: 10768samples [1:14:20,  2.97samples/s]
# Validation round: 10784samples [1:14:25,  3.03samples/s]
# Validation round: 10800samples [1:14:30,  3.05samples/s]
# Validation round: 10816samples [1:14:34,  3.19samples/s]
# Validation round: 10832samples [1:14:39,  3.25samples/s]
# Validation round: 10848samples [1:14:44,  3.27samples/s]
# Validation round: 10864samples [1:14:51,  2.90samples/s]
# Validation round: 10880samples [1:14:56,  3.01samples/s]
# Validation round: 10896samples [1:15:01,  3.07samples/s]
# Validation round: 10912samples [1:15:06,  3.05samples/s]
# Validation round: 10928samples [1:15:11,  3.12samples/s]
# Validation round: 10944samples [1:15:16,  3.16samples/s]
# Validation round: 10960samples [1:15:20,  3.23samples/s]
# Validation round: 10976samples [1:15:25,  3.22samples/s]
# Validation round: 10992samples [1:15:31,  3.19samples/s]
# Validation round: 11008samples [1:15:35,  3.27samples/s]
# Validation round: 11024samples [1:15:40,  3.28samples/s]
# Validation round: 11040samples [1:15:45,  3.30samples/s]
# Validation round: 11056samples [1:15:50,  3.28samples/s]
# Validation round: 11072samples [1:15:55,  3.27samples/s]
# Validation round: 11088samples [1:16:00,  3.26samples/s]
# Validation round: 11104samples [1:16:04,  3.27samples/s]
# Validation round: 11120samples [1:16:09,  3.26samples/s]
# Validation round: 11136samples [1:16:14,  3.30samples/s]
# Validation round: 11152samples [1:16:19,  3.35samples/s]
# Validation round: 11168samples [1:16:24,  3.31samples/s]
# Validation round: 11184samples [1:16:29,  3.23samples/s]
# Validation round: 11200samples [1:16:34,  3.26samples/s]
# Validation round: 11216samples [1:16:38,  3.28samples/s]
# Validation round: 11232samples [1:16:44,  3.17samples/s]
# Validation round: 11248samples [1:16:49,  3.25samples/s]
# Validation round: 11264samples [1:16:53,  3.26samples/s]
# Validation round: 11280samples [1:16:59,  3.22samples/s]
# Validation round: 11296samples [1:17:04,  3.19samples/s]
# Validation round: 11312samples [1:17:10,  2.93samples/s]
# Validation round: 11328samples [1:17:15,  3.01samples/s]
# Validation round: 11344samples [1:17:20,  3.04samples/s]
# Validation round: 11360samples [1:17:29,  2.57samples/s]
# Validation round: 11376samples [1:17:35,  2.55samples/s]
# Validation round: 11392samples [1:17:42,  2.44samples/s]
# Validation round: 11408samples [1:17:50,  2.38samples/s]
# Validation round: 11424samples [1:17:56,  2.45samples/s]
# Validation round: 11440samples [1:18:04,  2.21samples/s]
# Validation round: 11456samples [1:18:11,  2.33samples/s]
# Validation round: 11472samples [1:18:18,  2.27samples/s]
# Validation round: 11488samples [1:18:38,  1.47samples/s]
# Validation round: 11504samples [1:18:46,  1.58samples/s]
# Validation round: 11520samples [1:18:53,  1.73samples/s]
# Validation round: 11536samples [1:19:02,  1.75samples/s]
# Validation round: 11552samples [1:19:11,  1.79samples/s]
# Validation round: 11568samples [1:19:17,  1.94samples/s]
# Validation round: 11584samples [1:19:25,  2.01samples/s]
# Validation round: 11600samples [1:19:31,  2.13samples/s]
# Validation round: 11616samples [1:19:39,  2.12samples/s]
# Validation round: 11632samples [1:19:46,  2.18samples/s]
# Validation round: 11648samples [1:19:53,  2.15samples/s]
# Validation round: 11664samples [1:20:00,  2.25samples/s]
# Validation round: 11680samples [1:20:07,  2.26samples/s]
# Validation round: 11696samples [1:20:13,  2.33samples/s]
# Validation round: 11712samples [1:20:21,  2.19samples/s]
# Validation round: 11728samples [1:20:29,  2.18samples/s]
# Validation round: 11744samples [1:20:36,  2.22samples/s]
# Validation round: 11760samples [1:20:43,  2.23samples/s]
# Validation round: 11776samples [1:20:52,  2.06samples/s]
# Validation round: 11792samples [1:20:59,  2.15samples/s]
# Validation round: 11808samples [1:21:06,  2.19samples/s]
# Validation round: 11824samples [1:21:13,  2.21samples/s]
# Validation round: 11840samples [1:21:20,  2.22samples/s]
# Validation round: 11856samples [1:21:27,  2.21samples/s]
# Validation round: 11872samples [1:21:35,  2.17samples/s]
# Validation round: 11888samples [1:21:44,  2.00samples/s]
# Validation round: 11904samples [1:21:52,  2.04samples/s]
# Validation round: 11920samples [1:21:58,  2.15samples/s]
# Validation round: 11936samples [1:22:06,  2.14samples/s]
# Validation round: 11952samples [1:22:15,  1.99samples/s]
# Validation round: 11968samples [1:22:22,  2.04samples/s]
# Validation round: 11984samples [1:22:29,  2.12samples/s]
# Validation round: 12000samples [1:22:37,  2.14samples/s]
# Validation round: 12016samples [1:22:45,  2.11samples/s]
# Validation round: 12032samples [1:22:53,  2.02samples/s]
# Validation round: 12048samples [1:23:04,  1.82samples/s]
# Validation round: 12064samples [1:23:11,  1.92samples/s]
# Validation round: 12080samples [1:23:23,  1.74samples/s]
# Validation round: 12096samples [1:23:30,  1.87samples/s]
# Validation round: 12112samples [1:23:39,  1.79samples/s]
# Validation round: 12128samples [1:23:49,  1.76samples/s]
# Validation round: 12144samples [1:23:57,  1.84samples/s]
# Validation round: 12160samples [1:24:06,  1.83samples/s]
# Validation round: 12176samples [1:24:16,  1.75samples/s]
# Validation round: 12192samples [1:24:25,  1.75samples/s]
# Validation round: 12208samples [1:24:34,  1.73samples/s]
# Validation round: 12224samples [1:24:41,  1.85samples/s]
# Validation round: 12240samples [1:24:50,  1.85samples/s]
# Validation round: 12256samples [1:24:58,  1.89samples/s]
# Validation round: 12272samples [1:25:08,  1.82samples/s]
# Validation round: 12288samples [1:25:16,  1.84samples/s]
# Validation round: 12304samples [1:25:25,  1.83samples/s]
# Validation round: 12320samples [1:25:31,  2.04samples/s]
# Validation round: 12336samples [1:25:39,  2.03samples/s]
# Validation round: 12352samples [1:25:48,  1.96samples/s]
# Validation round: 12368samples [1:25:56,  1.93samples/s]
# Validation round: 12384samples [1:26:04,  1.99samples/s]
# Validation round: 12400samples [1:26:12,  2.00samples/s]
# Validation round: 12416samples [1:26:20,  1.98samples/s]
# Validation round: 12432samples [1:26:29,  1.92samples/s]
# Validation round: 12448samples [1:26:38,  1.88samples/s]
# Validation round: 12464samples [1:26:45,  1.93samples/s]
# Validation round: 12480samples [1:26:53,  1.96samples/s]
# Validation round: 12496samples [1:27:01,  1.96samples/s]
# Validation round: 12512samples [1:27:08,  2.06samples/s]
# Validation round: 12528samples [1:27:16,  2.03samples/s]
# Validation round: 12544samples [1:27:25,  1.97samples/s]
# Validation round: 12560samples [1:27:35,  1.82samples/s]
# Validation round: 12576samples [1:27:45,  1.79samples/s]
# Validation round: 12592samples [1:27:54,  1.80samples/s]
# Validation round: 12608samples [1:28:05,  1.66samples/s]
# Validation round: 12624samples [1:28:14,  1.68samples/s]
# Validation round: 12640samples [1:28:23,  1.71samples/s]
# Validation round: 12656samples [1:28:31,  1.77samples/s]
# Validation round: 12672samples [1:28:42,  1.71samples/s]
# Validation round: 12688samples [1:28:50,  1.73samples/s]
# Validation round: 12704samples [1:28:59,  1.74samples/s]
# Validation round: 12720samples [1:29:09,  1.74samples/s]
# Validation round: 12736samples [1:29:17,  1.79samples/s]
# Validation round: 12752samples [1:29:26,  1.77samples/s]
# Validation round: 12768samples [1:29:36,  1.72samples/s]
# Validation round: 12784samples [1:29:46,  1.67samples/s]
# Validation round: 12800samples [1:29:53,  1.87samples/s]
# Validation round: 12816samples [1:29:59,  2.03samples/s]
# Validation round: 12832samples [1:30:04,  2.29samples/s]
# Validation round: 12848samples [1:30:09,  2.43samples/s]
# Validation round: 12864samples [1:30:16,  2.43samples/s]
# Validation round: 12880samples [1:30:23,  2.42samples/s]
# Validation round: 12896samples [1:30:28,  2.54samples/s]
# Validation round: 12912samples [1:30:35,  2.47samples/s]
# Validation round: 12928samples [1:30:43,  2.34samples/s]
# Validation round: 12944samples [1:30:51,  2.25samples/s]
# Validation round: 12960samples [1:31:01,  2.01samples/s]
# Validation round: 12976samples [1:31:10,  1.89samples/s]
# Validation round: 12992samples [1:31:20,  1.83samples/s]
# Validation round: 13008samples [1:31:28,  1.83samples/s]
# Validation round: 13024samples [1:31:38,  1.78samples/s]
# Validation round: 13040samples [1:31:47,  1.75samples/s]
# Validation round: 13056samples [1:32:00,  1.59samples/s]
# Validation round: 13072samples [1:32:09,  1.63samples/s]
# Validation round: 13088samples [1:32:18,  1.66samples/s]
# Validation round: 13104samples [1:32:27,  1.68samples/s]
# Validation round: 13120samples [1:32:38,  1.63samples/s]
# Validation round: 13136samples [1:32:48,  1.61samples/s]
# Validation round: 13152samples [1:32:58,  1.64samples/s]
# Validation round: 13168samples [1:33:09,  1.58samples/s]
# Validation round: 13184samples [1:33:18,  1.59samples/s]
# Validation round: 13200samples [1:33:28,  1.60samples/s]
# Validation round: 13216samples [1:33:38,  1.60samples/s]
# Validation round: 13232samples [1:33:48,  1.59samples/s]
# Validation round: 13248samples [1:33:58,  1.60samples/s]
# Validation round: 13264samples [1:34:09,  1.59samples/s]
# Validation round: 13280samples [1:34:18,  1.62samples/s]
# Validation round: 13296samples [1:34:28,  1.64samples/s]
# Validation round: 13312samples [1:34:37,  1.63samples/s]
# Validation round: 13328samples [1:34:48,  1.58samples/s]
# Validation round: 13344samples [1:34:58,  1.62samples/s]
# Validation round: 13360samples [1:35:07,  1.62samples/s]
# Validation round: 13376samples [1:35:17,  1.64samples/s]
# Validation round: 13392samples [1:35:28,  1.56samples/s]
# Validation round: 13408samples [1:35:39,  1.53samples/s]
# Validation round: 13424samples [1:35:49,  1.57samples/s]
# Validation round: 13440samples [1:36:27,  1.15s/samples]
# Validation round: 13456samples [1:36:38,  1.02s/samples]
# Validation round: 13472samples [1:36:48,  1.11samples/s]
# Validation round: 13488samples [1:37:00,  1.18samples/s]
# Validation round: 13504samples [1:37:10,  1.27samples/s]
# Validation round: 13520samples [1:37:20,  1.36samples/s]
# Validation round: 13536samples [1:37:30,  1.41samples/s]
# ...
# Validation round: 4304samples [34:49,  1.43samples/s]
# Validation round: 4320samples [34:59,  1.49samples/s]
# Validation round: 4336samples [35:09,  1.51samples/s]
# Validation round: 4352samples [35:22,  1.43samples/s]
# Validation round: 4368samples [35:32,  1.48samples/s]
# Validation round: 4384samples [35:39,  1.65samples/s]
# Validation round: 4400samples [35:45,  1.89samples/s]
# Validation round: 4416samples [35:54,  1.82samples/s]
# Validation round: 4432samples [36:08,  1.54samples/s]
# Validation round: 4448samples [36:18,  1.58samples/s]
# Validation round: 4464samples [36:28,  1.60samples/s]
# Validation round: 4480samples [36:38,  1.59samples/s]
# Validation round: 4496samples [36:49,  1.53samples/s]
# Validation round: 4512samples [37:00,  1.52samples/s]
# Validation round: 4528samples [37:06,  1.76samples/s]
# Validation round: 4544samples [37:18,  1.57samples/s]
# Validation round: 4560samples [37:30,  1.51samples/s]
# Validation round: 4576samples [37:40,  1.55samples/s]
# Validation round: 4592samples [37:49,  1.58samples/s]
# Validation round: 4608samples [37:59,  1.60samples/s]
# Validation round: 4624samples [38:09,  1.60samples/s]
# Validation round: 4640samples [38:19,  1.61samples/s]
# Validation round: 4656samples [38:26,  1.76samples/s]
# Validation round: 4672samples [38:32,  1.94samples/s]
# Validation round: 4688samples [38:42,  1.83samples/s]
# Validation round: 4704samples [38:52,  1.78samples/s]
# Validation round: 4720samples [39:01,  1.76samples/s]
# Validation round: 4736samples [39:12,  1.68samples/s]
# Validation round: 4752samples [39:21,  1.68samples/s]
# Validation round: 4768samples [39:32,  1.62samples/s]
# Validation round: 4784samples [39:42,  1.58samples/s]
# Validation round: 4800samples [39:49,  1.78samples/s]
# Validation round: 4816samples [39:56,  1.87samples/s]
# Validation round: 4832samples [40:07,  1.74samples/s]
# Validation round: 4848samples [40:17,  1.71samples/s]
# Validation round: 4864samples [40:29,  1.58samples/s]
# Validation round: 4880samples [40:39,  1.59samples/s]
# Validation round: 4896samples [40:50,  1.52samples/s]
# Validation round: 4912samples [41:00,  1.55samples/s]
# Validation round: 4928samples [41:12,  1.50samples/s]
# Validation round: 4944samples [41:22,  1.53samples/s]
# Validation round: 4960samples [41:34,  1.45samples/s]
# Validation round: 4976samples [41:45,  1.45samples/s]
# Validation round: 4992samples [41:55,  1.48samples/s]
# Validation round: 5008samples [42:05,  1.52samples/s]
# Validation round: 5024samples [42:15,  1.55samples/s]
# Validation round: 5040samples [42:25,  1.56samples/s]
# Validation round: 5056samples [42:35,  1.58samples/s]
# Validation round: 5072samples [42:45,  1.58samples/s]
# Validation round: 5088samples [42:55,  1.57samples/s]
# Validation round: 5104samples [43:05,  1.59samples/s]
# Validation round: 5120samples [43:14,  1.62samples/s]
# Validation round: 5136samples [43:24,  1.65samples/s]
# Validation round: 5152samples [43:33,  1.67samples/s]
# Validation round: 5168samples [43:44,  1.62samples/s]
# Validation round: 5184samples [43:55,  1.54samples/s]
# Validation round: 5200samples [44:05,  1.59samples/s]
# Validation round: 5216samples [44:15,  1.59samples/s]
# Validation round: 5232samples [44:27,  1.47samples/s]
# Validation round: 5248samples [44:40,  1.38samples/s]
# Validation round: 5264samples [44:48,  1.54samples/s]
# Validation round: 5280samples [44:55,  1.74samples/s]
# Validation round: 5296samples [45:04,  1.73samples/s]
# Validation round: 5312samples [45:13,  1.71samples/s]
# Validation round: 5328samples [45:23,  1.70samples/s]
# Validation round: 5344samples [45:33,  1.68samples/s]
# Validation round: 5360samples [45:42,  1.68samples/s]
# Validation round: 5376samples [45:52,  1.67samples/s]
# Validation round: 5392samples [46:01,  1.68samples/s]
# Validation round: 5408samples [46:12,  1.62samples/s]
# Validation round: 5424samples [46:18,  1.82samples/s]
# Validation round: 5440samples [46:28,  1.79samples/s]
# Validation round: 5456samples [46:37,  1.74samples/s]
# Validation round: 5472samples [46:50,  1.59samples/s]
# Validation round: 5488samples [46:59,  1.61samples/s]
# Validation round: 5504samples [47:09,  1.62samples/s]
# Validation round: 5520samples [47:18,  1.65samples/s]
# Validation round: 5536samples [47:29,  1.57samples/s]
# Validation round: 5552samples [47:39,  1.60samples/s]
# Validation round: 5568samples [47:50,  1.58samples/s]
# Validation round: 5584samples [47:59,  1.60samples/s]
# Validation round: 5600samples [48:05,  1.82samples/s]
# Validation round: 5616samples [48:13,  1.89samples/s]
# Validation round: 5632samples [48:22,  1.86samples/s]
# Validation round: 5648samples [48:33,  1.69samples/s]
# Validation round: 5664samples [48:46,  1.55samples/s]
# Validation round: 5680samples [49:02,  1.32samples/s]
# Validation round: 5696samples [49:12,  1.38samples/s]
# Validation round: 5712samples [49:17,  1.68samples/s]
# Validation round: 5728samples [49:22,  1.99samples/s]
# Validation round: 5744samples [49:26,  2.27samples/s]
# Validation round: 5760samples [49:31,  2.56samples/s]
# Validation round: 5776samples [49:37,  2.61samples/s]
# Validation round: 5792samples [49:41,  2.88samples/s]
# Validation round: 5808samples [49:45,  3.08samples/s]
# Validation round: 5824samples [49:50,  3.12samples/s]
# Validation round: 5840samples [49:55,  3.23samples/s]
# Validation round: 5856samples [49:59,  3.32samples/s]
# Validation round: 5872samples [50:04,  3.33samples/s]
# Validation round: 5888samples [50:08,  3.41samples/s]
# Validation round: 5904samples [50:13,  3.42samples/s]
# Validation round: 5920samples [50:18,  3.45samples/s]
# Validation round: 5936samples [50:22,  3.47samples/s]
# Validation round: 5952samples [50:27,  3.46samples/s]
# Validation round: 5968samples [50:33,  3.19samples/s]
# Validation round: 5984samples [50:37,  3.31samples/s]
# Validation round: 6000samples [50:42,  3.26samples/s]
# Validation round: 6016samples [50:47,  3.31samples/s]
# Validation round: 6032samples [50:52,  3.23samples/s]
# Validation round: 6048samples [50:57,  3.29samples/s]
# Validation round: 6064samples [51:01,  3.42samples/s]
# Validation round: 6080samples [51:05,  3.54samples/s]
# Validation round: 6096samples [51:10,  3.49samples/s]
# Validation round: 6112samples [51:15,  3.41samples/s]
# Validation round: 6128samples [51:20,  3.40samples/s]
# Validation round: 6144samples [51:24,  3.43samples/s]
# Validation round: 6160samples [51:29,  3.35samples/s]
# Validation round: 6176samples [51:35,  3.17samples/s]
# Validation round: 6192samples [51:40,  3.21samples/s]
# Validation round: 6208samples [51:44,  3.26samples/s]
# Validation round: 6224samples [51:50,  3.15samples/s]
# Validation round: 6240samples [51:56,  3.03samples/s]
# Validation round: 6256samples [52:00,  3.22samples/s]
# Validation round: 6272samples [52:07,  2.86samples/s]
# Validation round: 6288samples [52:17,  2.33samples/s]
# Validation round: 6304samples [52:26,  2.10samples/s]
# Validation round: 6320samples [52:35,  2.00samples/s]
# Validation round: 6336samples [52:44,  1.91samples/s]
# Validation round: 6352samples [52:49,  2.20samples/s]
# Validation round: 6368samples [52:56,  2.23samples/s]
# Validation round: 6384samples [53:03,  2.28samples/s]
# Validation round: 6400samples [53:11,  2.13samples/s]
# Validation round: 6416samples [53:22,  1.89samples/s]
# Validation round: 6432samples [53:32,  1.80samples/s]
# Validation round: 6448samples [53:42,  1.75samples/s]
# Validation round: 6464samples [53:52,  1.71samples/s]
# Validation round: 6480samples [54:02,  1.65samples/s]
# Validation round: 6496samples [54:10,  1.73samples/s]
# Validation round: 6512samples [54:18,  1.84samples/s]
# Validation round: 6528samples [54:28,  1.77samples/s]
# Validation round: 6544samples [54:39,  1.65samples/s]
# Validation round: 6560samples [54:56,  1.35samples/s]
# Validation round: 6576samples [55:05,  1.46samples/s]
# Validation round: 6592samples [55:15,  1.48samples/s]
# Validation round: 6608samples [55:25,  1.51samples/s]
# Validation round: 6624samples [55:37,  1.44samples/s]
# Validation round: 6640samples [55:46,  1.54samples/s]
# Validation round: 6656samples [55:52,  1.76samples/s]
# Validation round: 6672samples [56:05,  1.57samples/s]
# Validation round: 6688samples [56:15,  1.58samples/s]
# Validation round: 6704samples [56:27,  1.48samples/s]
# Validation round: 6720samples [56:37,  1.52samples/s]
# Validation round: 6736samples [56:47,  1.57samples/s]
# Validation round: 6752samples [56:56,  1.59samples/s]
# Validation round: 6768samples [57:05,  1.65samples/s]
# Validation round: 6784samples [57:12,  1.84samples/s]
# Validation round: 6800samples [57:21,  1.80samples/s]
# Validation round: 6816samples [57:31,  1.75samples/s]
# Validation round: 6832samples [57:42,  1.65samples/s]
# Validation round: 6848samples [57:52,  1.61samples/s]
# Validation round: 6864samples [58:02,  1.63samples/s]
# Validation round: 6880samples [58:11,  1.64samples/s]
# Validation round: 6896samples [58:21,  1.66samples/s]
# Validation round: 6912samples [58:30,  1.67samples/s]
# Validation round: 6928samples [58:39,  1.69samples/s]
# Validation round: 6944samples [58:50,  1.64samples/s]
# Validation round: 6960samples [58:56,  1.84samples/s]
# Validation round: 6976samples [59:03,  1.93samples/s]
# Validation round: 6992samples [59:13,  1.85samples/s]
# Validation round: 7008samples [59:22,  1.79samples/s]
# Validation round: 7024samples [59:32,  1.72samples/s]
# Validation round: 7040samples [59:42,  1.71samples/s]
# Validation round: 7056samples [59:52,  1.70samples/s]
# Validation round: 7072samples [1:00:01,  1.71samples/s]
# Validation round: 7088samples [1:00:11,  1.65samples/s]
# Validation round: 7104samples [1:00:21,  1.65samples/s]
# Validation round: 7120samples [1:00:33,  1.56samples/s]
# Validation round: 7136samples [1:00:45,  1.45samples/s]
# Validation round: 7152samples [1:00:55,  1.52samples/s]
# Validation round: 7168samples [1:01:06,  1.50samples/s]
# Validation round: 7184samples [1:01:15,  1.56samples/s]
# Validation round: 7200samples [1:01:25,  1.57samples/s]
# Validation round: 7216samples [1:01:35,  1.60samples/s]
# Validation round: 7232samples [1:01:46,  1.56samples/s]
# Validation round: 7248samples [1:01:55,  1.59samples/s]
# Validation round: 7264samples [1:02:04,  1.66samples/s]
# Validation round: 7280samples [1:02:10,  1.88samples/s]
# Validation round: 7296samples [1:02:17,  1.96samples/s]
# Validation round: 7312samples [1:02:27,  1.85samples/s]
# Validation round: 7328samples [1:02:39,  1.62samples/s]
# Validation round: 7344samples [1:02:50,  1.60samples/s]
# Validation round: 7360samples [1:03:02,  1.48samples/s]
# Validation round: 7376samples [1:03:12,  1.51samples/s]
# Validation round: 7392samples [1:03:21,  1.60samples/s]
# Validation round: 7408samples [1:03:35,  1.45samples/s]
# Validation round: 7424samples [1:03:45,  1.48samples/s]
# Validation round: 7440samples [1:03:54,  1.53samples/s]
# Validation round: 7456samples [1:04:05,  1.55samples/s]
# Validation round: 7472samples [1:04:15,  1.55samples/s]
# Validation round: 7488samples [1:04:24,  1.59samples/s]
# Validation round: 7504samples [1:04:32,  1.70samples/s]
# Validation round: 7520samples [1:04:41,  1.72samples/s]
# Validation round: 7536samples [1:04:51,  1.71samples/s]
# Validation round: 7552samples [1:04:56,  1.96samples/s]
# Validation round: 7568samples [1:05:05,  1.92samples/s]
# Validation round: 7584samples [1:05:14,  1.87samples/s]
# Validation round: 7600samples [1:05:23,  1.81samples/s]
# Validation round: 7616samples [1:05:32,  1.82samples/s]
# Validation round: 7632samples [1:05:42,  1.77samples/s]
# Validation round: 7648samples [1:05:53,  1.66samples/s]
# Validation round: 7664samples [1:06:02,  1.69samples/s]
# Validation round: 7680samples [1:06:11,  1.70samples/s]
# Validation round: 7696samples [1:06:26,  1.46samples/s]
# Validation round: 7712samples [1:06:36,  1.47samples/s]
# Validation round: 7728samples [1:06:47,  1.50samples/s]
# Validation round: 7744samples [1:06:57,  1.53samples/s]
# Validation round: 7760samples [1:07:07,  1.52samples/s]
# Validation round: 7776samples [1:07:17,  1.56samples/s]
# Validation round: 7792samples [1:07:27,  1.55samples/s]
# Validation round: 7808samples [1:07:36,  1.65samples/s]
# Validation round: 7824samples [1:07:41,  1.90samples/s]
# Validation round: 7840samples [1:07:50,  1.89samples/s]
# Validation round: 7856samples [1:07:59,  1.83samples/s]
# Validation round: 7872samples [1:08:11,  1.62samples/s]
# Validation round: 7888samples [1:08:21,  1.63samples/s]
# Validation round: 7904samples [1:08:32,  1.60samples/s]
# Validation round: 7920samples [1:09:14,  1.24s/samples]
# Validation round: 7936samples [1:09:20,  1.03samples/s]
# Validation round: 7952samples [1:09:29,  1.19samples/s]
# Validation round: 7968samples [1:09:38,  1.29samples/s]
# Validation round: 7984samples [1:09:52,  1.27samples/s]
# Validation round: 8000samples [1:10:01,  1.37samples/s]
# Validation round: 8016samples [1:10:10,  1.45samples/s]
# Validation round: 8032samples [1:10:15,  1.77samples/s]
# Validation round: 8048samples [1:10:20,  2.05samples/s]
# Validation round: 8064samples [1:10:24,  2.33samples/s]
# Validation round: 8080samples [1:10:29,  2.60samples/s]
# Validation round: 8096samples [1:10:35,  2.56samples/s]
# Validation round: 8112samples [1:10:40,  2.78samples/s]
# Validation round: 8128samples [1:10:44,  2.98samples/s]
# Validation round: 8144samples [1:10:49,  3.12samples/s]
# Validation round: 8160samples [1:10:54,  3.12samples/s]
# Validation round: 8176samples [1:10:58,  3.33samples/s]
# Validation round: 8192samples [1:11:02,  3.48samples/s]
# Validation round: 8208samples [1:11:07,  3.49samples/s]
# Validation round: 8224samples [1:11:13,  3.13samples/s]
# Validation round: 8240samples [1:11:20,  2.92samples/s]
# Validation round: 8256samples [1:11:27,  2.65samples/s]
# Validation round: 8272samples [1:11:32,  2.73samples/s]
# Validation round: 8288samples [1:11:38,  2.82samples/s]
# Validation round: 8304samples [1:11:42,  2.99samples/s]
# Validation round: 8320samples [1:11:47,  3.14samples/s]
# Validation round: 8336samples [1:11:51,  3.23samples/s]
# Validation round: 8352samples [1:11:56,  3.26samples/s]
# Validation round: 8368samples [1:12:01,  3.20samples/s]
# Validation round: 8384samples [1:12:06,  3.21samples/s]
# Validation round: 8400samples [1:12:11,  3.29samples/s]
# Validation round: 8416samples [1:12:16,  3.33samples/s]
# Validation round: 8432samples [1:12:20,  3.33samples/s]
# Validation round: 8448samples [1:12:26,  3.20samples/s]
# Validation round: 8464samples [1:12:30,  3.27samples/s]
# Validation round: 8480samples [1:12:36,  3.20samples/s]
# Validation round: 8496samples [1:12:40,  3.27samples/s]
# Validation round: 8512samples [1:12:46,  3.12samples/s]
# Validation round: 8528samples [1:12:51,  3.18samples/s]
# Validation round: 8544samples [1:12:55,  3.27samples/s]
# Validation round: 8560samples [1:13:00,  3.40samples/s]
# Validation round: 8576samples [1:13:07,  2.95samples/s]
# Validation round: 8592samples [1:13:17,  2.30samples/s]
# Validation round: 8608samples [1:13:27,  2.09samples/s]
# Validation round: 8624samples [1:13:37,  1.87samples/s]
# Validation round: 8640samples [1:13:49,  1.70samples/s]
# Validation round: 8656samples [1:13:57,  1.75samples/s]
# Validation round: 8672samples [1:14:03,  1.94samples/s]
# Validation round: 8688samples [1:14:11,  2.01samples/s]
# Validation round: 8704samples [1:14:18,  2.06samples/s]
# Validation round: 8720samples [1:14:24,  2.21samples/s]
# Validation round: 8736samples [1:14:35,  1.94samples/s]
# Validation round: 8752samples [1:15:17,  1.16s/samples]
# Validation round: 8768samples [1:15:31,  1.07s/samples]
# Validation round: 8784samples [1:15:38,  1.13samples/s]
# Validation round: 8800samples [1:15:44,  1.38samples/s]
# Validation round: 8816samples [1:15:54,  1.43samples/s]
# Validation round: 8832samples [1:16:04,  1.50samples/s]
# Validation round: 8848samples [1:16:14,  1.53samples/s]
# Validation round: 8864samples [1:16:23,  1.57samples/s]
# Validation round: 8880samples [1:16:33,  1.59samples/s]
# Validation round: 8896samples [1:16:42,  1.63samples/s]
# Validation round: 8912samples [1:16:52,  1.60samples/s]
# Validation round: 8928samples [1:16:59,  1.80samples/s]
# Validation round: 8944samples [1:17:07,  1.86samples/s]

# %%
# test

# %%
import argparse
import logging
import os
import sys
from tqdm import tqdm
import yaml

import numpy as np
import torch
from torch import optim
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
import torch.nn.functional as F


# todo: when we add more models, we should move these variables to another location
ALL_MODEL_NAMES = ["LogoDetection"]
ALL_DATASET_NAMES = ["FlickrLogos-32, TopLogos-10"]

with open(os.path.abspath("./config/config.yaml")) as config:
    config_list = yaml.load(config, Loader=yaml.FullLoader)

# def pred(model,
#          sample,
#          device,
#          threshold=0.5):
#     if(model.eval==False):
#         model.eval()

#     queries, targets = torch.from_numpy(BasicDataset.preprocess(index=index, file:files_path))
#     queries = queries.unsqueeze(0)
#     queries = queries.to(device=device, dtype=torch.float32)
#     targets = targets.unsqueeze(0)
#     targets = targets.to(device=device, dtype=torch.float32)


def test(model,
         device,
         dataset,
         batch_size,
        #   save_path,
         verbose: bool,
         threshold=0.5):
    
    model.eval()

    # #TODO dataset preprocessing
    # with torch.no_grad():
    #     output = model(queries, targets)

    #     probs = output.squeeze(0)
    
    logging.info("\nPredicting image{} ... ")

    with tqdm(total=len(dataset), desc=f'Testing dataset', unit='test-img', disable=not verbose) as bar:
            bar.set_description(f'model testing')

            for batch in test_loader:
                queries = batch['query']  # Correct dimensions?
                targets = batch['target']
                bboxes = batch['bbox']

                queries = queries.to(device=device, dtype=torch.float32)
                targets = targets.to(device=device, dtype=torch.float32)
                bboxes = bboxes.to(device=device, dtype=torch.float32)

                with torch.no_grad():
                    pred_masks = model(queries, targets)
                    # print(pred_masks.shape)

                bar.update(queries.shape[0])
                global_step += 1
                val_score += eval_net(model, batch, device)
                # writer.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], global_step)

                writer.add_images('query_images', queries, global_step)
                writer.add_images('target_images', targets, global_step)
                # writer.add_images('bboxes/true', bboxes, global_step)
                writer.add_images('masks/pred', pred_masks, global_step)
                writer.close()
    return val_score / global_step


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--dataset',
                        choices=ALL_DATASET_NAMES,
                        help="Dataset in {}".format(ALL_DATASET_NAMES),
                        required=True
                        )

    parser.add_argument('--model',
                        choices=ALL_MODEL_NAMES,
                        help="Model in {}".format(ALL_MODEL_NAMES)
                        )

    parser.add_argument('--batch_size',
                        default=32,
                        type=int,
                        help="Number of samples in each mini-batch in SGD and Adam optimization"
                        )

    parser.add_argument('--verbose',
                        default=True,
                        type=bool,
                        help="Verbose"
                        )

    parser.add_argument('--load',
                        type=str,
                        required=True,
                        help="Path to the model to load"
                        )

    return parser.parse_args()


if __name__ == '__main__':
    # Logging
    logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
    args = get_args()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    logging.info(f'Using device {device}')

    # Modularized paths with respect to the current Dataset
    imgs_dir = config_list['datasets'][args.dataset]['images']
    masks_dir = config_list['datasets'][args.dataset]['masks']
    # TODO: Controlla che ste due liste hanno le stesse sottocartelle
    imgs_classes = [f.name for f in os.scandir(imgs_dir) if f.is_dir()]
    mask_classes = [f.name for f in os.scandir(masks_dir) if f.is_dir()]
    # checkpoint_dir = config_list['models'][args.model]['train_cp']

    model_path = config_list['models'][args.model]['paths']['model']+ "_".join([args.model, args.dataset]) + ".pt"

    # print("Loading %s dataset..." % args.dataset)
    # dataset = BasicDataset(imgs_dir=imgs_dir, masks_dir=masks_dir)

    # Change here to adapt your data
    print("Initializing model...")
    model = LogoDetection(batch_norm=args.batch_norm,
                        vgg_cfg=args.vgg_cfg)

    model.load_state_dict(
        torch.load(model_path, map_location=device)
    )
    logging.info(f'Model loaded from {model_path}')
    model.to(device=device)

    # Neo, enter in Metrics
    metrics = []

    for img_class_idx, img_class_path in enumerate(imgs_classes):
        dataset = BasicDataset(imgs_dir=f"{imgs_dir}{os.path.sep}{img_class_path}", masks_dir=f"{masks_dir}{os.path.sep}{masks_dir[img_class_idx]}", dataset_name=args.dataset, skip_bbox_lines=1)
        test_loader = DataLoader(dataset, batch_size=args.batch_size, shuffle=True, num_workers=4, pin_memory=True)

        try:
            metrics.append(test(model=model,
                                device=device,
                                dataset=test_loader,
                                batch_size=args.batch_size,
                                verbose=args.verbose
                                ))
        except KeyboardInterrupt:
            # torch.save(model.state_dict(), 'INTERRUPTED.ph')
            # logging.info('Interrupt saved')
            logging.info("Test interrupted")
            try:
                sys.exit(0)
            except SystemExit:
                os._exit(0)

# %%
# !pip install nvgpu

# %%
import nvgpu

avail_gpus = nvgpu.available_gpus()
print(avail_gpus)
